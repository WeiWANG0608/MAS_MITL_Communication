# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification, print_specs
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Initial the environment
Get the number robots: num_agent_heavy, num_agent_light
Get the size of the work region: region_row, region_col
Get the whole map with obstacles: 2*(N/2) work regions, obs_percentage, obs_list
Get the map and state space of the env: map_original, map_obstacle, states_original
Get the map and state space of work regions for each heavy-duty robot: work_region, map_work_region, states_work_region
Get initial position of all robots: agents_heavy, agents_light
"""
num_agent_heavy = random.choice([2, 4, 6])
num_agent_light = 1
region_row, region_col = [random.randint(10, 15), random.randint(10, 15)]
map_row, map_col = [region_row * 2, int(region_col * (num_agent_heavy / 2))]
obs_percentage = 10
obs_list = initial_env(region_row * 2, region_col * (num_agent_heavy / 2), obs_percentage)
map_original = np.zeros((map_row, map_col), dtype=int)
map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs_list)):
    map_obstacle[obs_list[i][0]][obs_list[i][1]] = 1
states_original = total_states(map_obstacle)
work_region = initial_work_region(num_agent_heavy, region_row, region_col)
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

agents_heavy, [agents_light] = initial_agents(work_region, obs_list, num_agent_heavy, num_agent_light)
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)

# get the MITL task specification
specifications = initial_specification(obs_list, agents_heavy, agents_light, work_region, states_work_region)

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [[10, 0], [12, 20], [7, 41], [15, 43], [22, 23], [24, 0]] . Init light_duty agent:  [5, 12]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 2
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2]) + h_a) * v_heavy) /
    ((2 * r_0) - h_a)) for i in range(num_agent_heavy)])

# %%
"""
--------------- Mission decomposition ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = [[] for i in range(num_agent_heavy)]
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w124
# The initial position is  w124
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 175
# Edge in WTS:  747
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 124
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w124, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w114, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w100, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w101, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w77, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w65, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w51, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w52, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w58, l1, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w58, l1, w=38, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w58, l1, w=39, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w58, l1, w=40, veri1=0, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w58, l1, w=41, veri1=0, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w58, l1, w=42, veri1=0, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w58, l1, w=43, veri1=0, veri2=0, ProcessTA.cl1=6, ProcessTA.cl2=0)
#
# (w58, l1, w=44, veri1=0, veri2=0, ProcessTA.cl1=7, ProcessTA.cl2=0)
#
# (w58, l1, w=45, veri1=0, veri2=0, ProcessTA.cl1=8, ProcessTA.cl2=0)
#
# (w58, l1, w=46, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w45, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w33, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w32, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w21, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w7, l0, w=51, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w21, l0, w=52, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w32, l0, w=53, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w44, l0, w=54, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w57, l0, w=55, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w70, l0, w=56, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w81, l0, w=57, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w82, l0, w=58, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w94, l0, w=59, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w108, l0, w=60, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w120, l0, w=61, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w132, l0, w=62, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w133, l0, w=63, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w134, l2, w=64, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=0)
#
# (w134, l2, w=65, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=1)
#
# (w134, l2, w=66, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=2)
#
# (w134, l2, w=67, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=3)
#
# (w134, l2, w=68, veri1=1, veri2=0, ProcessTA.cl1=9, ProcessTA.cl2=4)
#
# (w134, l2, w=69, veri1=1, veri2=1, ProcessTA.cl1=9, ProcessTA.cl2=5)
#
# The initial position is  w153
# The initial position is  w153
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 176
# Edge in WTS:  764
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 153
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w153, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w141, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w129, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w117, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w106, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w105, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w104, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w93, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w80, l1, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w80, l1, w=11, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w80, l1, w=12, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w80, l1, w=13, veri1=0, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w80, l1, w=14, veri1=0, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w80, l1, w=15, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w69, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w57, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w44, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w30, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w18, l0, w=20, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w4, l0, w=21, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w3, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w2, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w1, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w0, l0, w=25, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w14, l0, w=26, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w0, l0, w=27, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w14, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w0, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w14, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w15, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w27, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w41, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w54, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w55, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w56, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w68, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w79, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w93, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w104, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w115, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w127, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w139, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w152, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w165, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w166, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w167, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w168, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w169, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w170, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w171, l2, w=51, veri1=1, veri2=1, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# The initial position is  w98
# The initial position is  w98
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R2
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR2.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 179
# Edge in WTS:  781
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 98
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-29T16:04:58.336353203
# False
# ========There is no path satisfying the specification!========
# The initial position is  w11
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# The initial position is  w11
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 181
# Edge in WTS:  801
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 11
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-29T16:05:08.441813982
# False
# ========There is no path satisfying the specification!========
# The initial position is  w92
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# The initial position is  w92
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R4
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR4.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 172
# Edge in WTS:  732
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 92
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w92, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w82, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w70, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w45, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w34, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w22, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w8, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w22, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w34, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w45, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w70, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w82, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w92, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w105, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w117, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w127, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w140, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w140, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=4, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=5, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=7, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=8, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l1, w=30, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w140, l0, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w127, l0, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w117, l0, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w127, l0, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w126, l0, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w125, l0, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w124, l0, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w123, l0, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w136, l0, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w135, l2, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w135, l2, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w135, l2, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w135, l2, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w135, l2, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w135, l2, w=45, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w134, l0, w=46, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w122, l0, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w112, l0, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w100, l0, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w99, l0, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w98, l0, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w88, l0, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w76, l0, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w64, l0, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w63, l0, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w75, l0, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w76, l0, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w88, l0, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w98, l0, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w99, l0, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w100, l0, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w101, l0, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w89, l0, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w78, l0, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w79, l0, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w80, l0, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w81, l0, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w82, l0, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w83, l0, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w84, l0, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w85, l0, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w86, l3, w=72, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=9, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# The initial position is  w113
# The initial position is  w113
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R5
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR5.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 174
# Edge in WTS:  754
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 113
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w113, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w86, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w73, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w61, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w73, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w86, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w113, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w127, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w128, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w129, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w130, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w131, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w132, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w133, l3, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w135, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w146, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w157, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w158, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w169, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w170, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w171, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w172, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=4, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=30, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=5, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w173, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w172, l0, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w161, l0, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w150, l0, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w149, l0, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w148, l0, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w137, l0, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w123, l0, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w109, l0, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w96, l0, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w82, l0, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w69, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l0, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w34, l0, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=47, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=48, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l2, w=49, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l2, w=50, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w58, l2, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w48, l0, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w35, l0, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w21, l0, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w9, l0, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w8, l0, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w7, l0, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w6, l0, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w5, l0, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w4, l0, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w3, l0, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w17, l0, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w29, l0, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w42, l0, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w52, l0, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w64, l0, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w65, l0, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w77, l0, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w91, l0, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w92, l0, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w105, l0, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w119, l0, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w119, l0, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w133, l3, w=74, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=6, ProcessTA.cl2=2, ProcessTA.cl3=0)

# %%
# save all the info of Mission Decomposition
info = ''
for i in range(num_agent_heavy):
    info = info + str(agents_heavy[i])+';' + ','.join(str(j) for j in specifications[i]) + ';' + ','.join(
        str(j) for j in independent_task[i]) + ';' + ','.join(str(j) for j in independent_request[i]) + '&'
text_file = open(file_folder + "/" + 'initialization_info' + ".txt", "w")
text_file.write(info)
text_file.close()

# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['G', '37', '46', 'w58'], ['G', '64', '69', 'w134']], [['G', '10', '15', 'w80', 'R3', 'col'], ['E', '51', '52', 'w171']], [['E', '7', '8', 'w3'], ['E', '20', '21', 'w170']], [['G', '5', '11', 'w3'], ['G', '66', '68', 'w67']], [['G', '21', '30', 'w154', 'R5', 'col'], ['G', '40', '45', 'w135'], ['E', '72', '77', 'w86']], [['G', '25', '31', 'w173'], ['G', '49', '51', 'w58'], ['E', '74', '83', 'w133', 'R4', 'meet']]]
# ------------ If all the paths exist ------------
# [True, True, False, False, True, True]

# %%
"The execution stop here because heavy-duty robot R3 and R4 cannot synthesize a timed run satisfies its independent task."
