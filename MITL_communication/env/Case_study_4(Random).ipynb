# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification, print_specs
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Initial the environment
Get the number robots: num_agent_heavy, num_agent_light
Get the size of the work region: region_row, region_col
Get the whole map with obstacles: 2*(N/2) work regions, obs_percentage, obs_list
Get the map and state space of the env: map_original, map_obstacle, states_original
Get the map and state space of work regions for each heavy-duty robot: work_region, map_work_region, states_work_region
Get initial position of all robots: agents_heavy, agents_light
"""
num_agent_heavy = random.choice([2,4,6])
num_agent_light = 1
region_row, region_col = [random.randint(10, 15), random.randint(10, 15)]
map_row, map_col = [region_row * 2, int(region_col * (num_agent_heavy / 2))]
obs_percentage = 10
obs_list = initial_env(region_row * 2, region_col * (num_agent_heavy / 2), obs_percentage)
map_original = np.zeros((map_row, map_col), dtype=int)
map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs_list)):
    map_obstacle[obs_list[i][0]][obs_list[i][1]] = 1
states_original = total_states(map_obstacle)
work_region = initial_work_region(num_agent_heavy, region_row, region_col)
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

agents_heavy, [agents_light] = initial_agents(work_region, obs_list, num_agent_heavy, num_agent_light)
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)

# get the MITL task specification
specifications = initial_specification(obs_list, agents_heavy, agents_light, work_region, states_work_region)
specification_print = print_specs(specifications)
for i in range(num_agent_heavy):
    print("MITL Specification of R", i + 1, ": ", specification_print[i])

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [[6, 8], [15, 2]] . Init light_duty agent:  [10, 0]
# MITL Specification of R 1 :  [['G', '25', '31', 'w62'], ['E', '69', '79', 'w104'], ['G', '95', '101', 'w99', 'R2', 'meet']]
# MITL Specification of R 2 :  [['E', '25', '33', 'w57'], ['E', '48', '57', 'w97', 'R1', 'col']]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 2
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2]) + h_a) * v_heavy) /
    ((2 * r_0) - h_a)) for i in range(num_agent_heavy)])

# %%
"""
--------------- Mission decomposition ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = [[] for i in range(num_agent_heavy)]
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w76
# The initial position is  w76
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 128
# Edge in WTS:  552
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 76
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w76, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w63, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=4, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=30, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=5, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w39, l0, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w16, l0, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l0, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=47, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=48, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=49, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=50, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=51, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=52, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=53, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=54, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=55, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=56, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=57, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=58, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=59, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=60, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=61, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=62, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=63, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=64, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w36, l0, w=65, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=66, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l0, w=67, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w71, l0, w=68, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w82, l0, w=69, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w83, l0, w=70, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w84, l0, w=71, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w85, l0, w=72, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w86, l0, w=73, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w87, l0, w=74, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=75, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w101, l0, w=76, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w102, l0, w=77, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w103, l0, w=78, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=79, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=80, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=81, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=82, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=83, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=84, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=85, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=86, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=87, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=88, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=89, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=90, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w103, l0, w=91, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w102, l0, w=92, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w101, l0, w=93, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=94, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l3, w=95, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l3, w=96, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=1)
#
# (w99, l3, w=97, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=2)
#
# (w99, l3, w=98, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=3)
#
# (w99, l3, w=99, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=4)
#
# (w99, l3, w=100, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=5)
#
# (w99, l3, w=101, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=6)
#
# The initial position is  w37
# The initial position is  w37
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 131
# Edge in WTS:  567
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 37
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w37, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w26, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w14, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w24, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w25, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w26, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w37, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w38, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w39, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w40, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w41, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=33, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=34, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=35, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=36, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w66, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w78, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w77, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w76, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w75, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w74, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w86, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w97, l2, w=48, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The initial position is  w76
# The initial position is  w76
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 128
# Edge in WTS:  552
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 76
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w76, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w64, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w63, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=4, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=30, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=5, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w62, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w39, l0, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w16, l0, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l0, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=47, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=48, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=49, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=50, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=51, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=52, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=53, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=54, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=55, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=56, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=57, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=58, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=59, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=60, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=61, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=62, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=63, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=64, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w36, l0, w=65, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=66, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l0, w=67, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w71, l0, w=68, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w82, l0, w=69, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w83, l0, w=70, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w84, l0, w=71, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w85, l0, w=72, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w86, l0, w=73, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w87, l0, w=74, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=75, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w101, l0, w=76, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w102, l0, w=77, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w103, l0, w=78, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=79, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=80, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=81, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=82, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=83, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=84, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=85, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=86, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=87, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=88, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=89, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w104, l2, w=90, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w103, l0, w=91, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w102, l0, w=92, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w101, l0, w=93, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l0, w=94, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l3, w=95, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l3, w=96, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=1)
#
# (w99, l3, w=97, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=2)
#
# (w99, l3, w=98, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=3)
#
# (w99, l3, w=99, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=4)
#
# (w99, l3, w=100, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=5)
#
# (w99, l3, w=101, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=6)
#
# The initial position is  w37
# The initial position is  w37
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1;
# bool veri1;
# ===== Templates declarations =====
# null
# int cl1;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 131
# Edge in WTS:  567
# State in TA:  2
# Edge in TA:   3
# ===== Initial State =====
# Initial state in WTS: 37
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w37, l0, w=0, veri1=0, ProcessTA.cl1=0)
#
# (w26, l0, w=1, veri1=0, ProcessTA.cl1=0)
#
# (w14, l0, w=2, veri1=0, ProcessTA.cl1=0)
#
# (w2, l0, w=3, veri1=0, ProcessTA.cl1=0)
#
# (w1, l0, w=4, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=5, veri1=0, ProcessTA.cl1=0)
#
# (w12, l0, w=6, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=7, veri1=0, ProcessTA.cl1=0)
#
# (w12, l0, w=8, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=9, veri1=0, ProcessTA.cl1=0)
#
# (w12, l0, w=10, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=11, veri1=0, ProcessTA.cl1=0)
#
# (w12, l0, w=12, veri1=0, ProcessTA.cl1=0)
#
# (w24, l0, w=13, veri1=0, ProcessTA.cl1=0)
#
# (w25, l0, w=14, veri1=0, ProcessTA.cl1=0)
#
# (w26, l0, w=15, veri1=0, ProcessTA.cl1=0)
#
# (w37, l0, w=16, veri1=0, ProcessTA.cl1=0)
#
# (w38, l0, w=17, veri1=0, ProcessTA.cl1=0)
#
# (w39, l0, w=18, veri1=0, ProcessTA.cl1=0)
#
# (w40, l0, w=19, veri1=0, ProcessTA.cl1=0)
#
# (w41, l0, w=20, veri1=0, ProcessTA.cl1=0)
#
# (w53, l0, w=21, veri1=0, ProcessTA.cl1=0)
#
# (w54, l0, w=22, veri1=0, ProcessTA.cl1=0)
#
# (w55, l0, w=23, veri1=0, ProcessTA.cl1=0)
#
# (w56, l0, w=24, veri1=0, ProcessTA.cl1=0)
#
# (w57, l1, w=25, veri1=1, ProcessTA.cl1=0)

# %%
# save all the info of Mission Decomposition
info = ''
for i in range(num_agent_heavy):
    info = info + str(agents_heavy[i])+';' + ','.join(str(j) for j in specifications[i]) + ';' + ','.join(
        str(j) for j in independent_task[i]) + ';' + ','.join(str(j) for j in independent_request[i]) + '&'
text_file = open(file_folder + "/" + 'initialization_info' + ".txt", "w")
text_file.write(info)
text_file.close()

# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['G', '25', '31', 'w62'], ['E', '69', '79', 'w104'], ['G', '95', '101', 'w99', 'R1', 'meet']], [['E', '25', '33', 'w57'], ['E', '48', '57', 'w97', 'R0', 'col']]]
# ------------ If all the paths exist ------------
# [True, True]
# ---- The Independent Task Specification ----
# [[['G', '25', '31', 'w62'], ['E', '69', '79', 'w104'], ['G', '95', '101', 'w99']], [['E', '25', '33', 'w57']]]
# --------- The Independent Request ---------
# [[[], [['G', '95', '101', 'w99', 'R1', 'meet']]], [[['E', '48', '57', 'w97', 'R0', 'col']], []]]

# %%
# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
"""
Start two round SWEEP
"""
# start sweeping
# maximum 2 rounds to guarantee the requests exchange

num_round_exchange = 2

path_detect_round, independent_path_2d, record_working_region, record_task_left = \
    collect_deliver(world, map_obs_work, num_round_exchange, num_agent_heavy, work_region, states_work_region,
                    independent_path_2d, h_a, r_0, v_light, file_folder)
# Out:
# Round  0  Region 0
# The closest start location is  [8 0]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [2 0]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [10  0]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [9 0]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [8 0]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [8 1]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [8 2]
# Step  0 Robot 0 Pos [6 8] R0 pos:  [8 3]
# Step  1 Robot 0 Pos [6 8] R0 pos:  [8 4]
# Step  1 Robot 0 Pos [6 8] R0 pos:  [8 5]
# Step  1 Robot 0 Pos [6 8] R0 pos:  [8 6]
# Step  1 Robot 0 Pos [6 8] R0 pos:  [8 7]
# len() 1
# kl:  0
# The heavy duty agent  0  is detected at step:  0 . Pos_heavy:  [6, 8] . Pos_light:  [8, 8] . Distance is:  2
# Stop sweep at Region 1  at position  [8 8]
# The closest start location is  [14 12]
# Step  1 Robot 0 Task left:  ['w62', 'w104', 'w99']
# Step  1 Robot 1 Task left:  ['w57']
# Step :  1 Light:  [10, 8] Heavy  1 :  [14, 2] Distance is:  10
# Round  0  Region 1
# The closest start location is  [14 12]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [20 12]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [13 12]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [14 12]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [14 11]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [14 10]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [14  9]
# Step  2 Robot 1 Pos [14, 2] R0 pos:  [14  8]
# Step  2 Robot 0 Task left:  ['w62', 'w104', 'w99']
# Step  2 Robot 1 Task left:  ['w57']
# Step :  2 Light:  [14, 7] Heavy 1 :  [13, 2] Distance is:  6
# Step  2 Robot 1 Pos [13, 2] R0 pos:  [14  7]
# Step  2 Robot 1 Pos [13, 2] R0 pos:  [14  6]
# Step  2 Robot 1 Pos [13, 2] R0 pos:  [14  5]
# Step  2 Robot 1 Pos [13, 2] R0 pos:  [14  4]
# len() 1
# kl:  0
# The heavy duty agent  1  is detected at step:  2 . Pos_heavy:  [13, 2] . Pos_light:  [14, 3] . Distance is:  2
# Stop sweep at Region 2  at position  [14  3]
# The closest start location is  [8 0]
# Round  1  Region 0
# The closest start location is  [8 0]
# Step  3 Robot 0 Pos [4, 8] R0 pos:  [2 0]
# Step  3 Robot 0 Task left:  ['w62', 'w104', 'w99']
# Step  3 Robot 1 Task left:  ['w57']
# Step :  3 Light:  [9, 0] Heavy 0 :  [5, 8] Distance is:  12
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [9 0]
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [8 0]
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [8 1]
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [8 2]
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [8 3]
# Step  3 Robot 0 Pos [5, 8] R0 pos:  [8 4]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [8 5]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [8 6]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [8 7]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [8 8]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [8 9]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [ 8 10]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [ 8 11]
# Step  4 Robot 0 Pos [5, 8] R0 pos:  [ 8 12]
# Step  4 Robot 0 Task left:  ['w62', 'w104', 'w99']
# Step  4 Robot 1 Task left:  ['w57']
# Step :  4 Light:  [7, 12] Heavy 0 :  [4, 8] Distance is:  7
# Step  4 Robot 0 Pos [4, 8] R0 pos:  [ 7 12]
# Step  4 Robot 0 Pos [4, 8] R0 pos:  [ 6 12]
# Step  4 Robot 0 Pos [4, 8] R0 pos:  [ 6 11]
# Step  4 Robot 0 Pos [4, 8] R0 pos:  [ 6 10]
# Step  4 Robot 0 Pos [4, 8] R0 pos:  [6 9]
# The cooperative task is in region  [1]  the needed robot is  0
# The current map contains the follow task regions  [1] 0
# The new specification without time updating is  [['G', '25', '31', 'w67'], ['E', '69', '79', 'w112'], ['G', '95', '101', 'w107'], ['E', '48', '57', 'w252', '1', 'col']]
# The current position before updating is  w51 after updating is  w55
# The new specification after the time update is  [['G', '21', '27', 'w67'], ['E', '65', '75', 'w112'], ['G', '91', '97', 'w107'], ['E', '44', '53', 'w252', '1', 'col']]
# The initial position is  w55
# The initial position is  w55
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoCR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3,p4,np4;
# bool veri1,veri2,veri3,veri4;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3,cl4;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 302
# Edge in WTS:  1322
# State in TA:  5
# Edge in TA:   12
# ===== Initial State =====
# Initial state in WTS: 55
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3&&veri4) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w55, l0, w=0, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=1, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=2, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=3, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=4, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=5, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=6, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=7, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=8, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=9, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=10, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=11, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=12, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=13, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=14, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=15, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=16, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=17, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w55, l0, w=18, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w69, l0, w=19, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w68, l0, w=20, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=21, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=22, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=23, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=24, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=25, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=4, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=26, veri1=0, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=5, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w67, l1, w=27, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w54, l0, w=28, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w42, l0, w=29, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w30, l0, w=30, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w29, l0, w=31, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w41, l0, w=32, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w40, l0, w=33, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w52, l0, w=34, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w51, l0, w=35, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w50, l0, w=36, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w63, l0, w=37, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w77, l0, w=38, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w89, l0, w=39, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w103, l0, w=40, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w117, l0, w=41, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w129, l0, w=42, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w140, l0, w=43, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w152, l0, w=44, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w164, l0, w=45, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w177, l0, w=46, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w189, l0, w=47, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w202, l0, w=48, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w215, l0, w=49, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w228, l0, w=50, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w240, l0, w=51, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w240, l0, w=52, veri1=1, veri2=0, veri3=0, veri4=0, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w252, l4, w=53, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w252, l4, w=54, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w240, l0, w=55, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w228, l0, w=56, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w215, l0, w=57, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w202, l0, w=58, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w189, l0, w=59, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w177, l0, w=60, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w164, l0, w=61, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w152, l0, w=62, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w140, l0, w=63, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w141, l0, w=64, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w142, l0, w=65, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w130, l0, w=66, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w118, l0, w=67, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w119, l0, w=68, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w120, l0, w=69, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w121, l0, w=70, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w108, l0, w=71, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w109, l0, w=72, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w110, l0, w=73, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w111, l0, w=74, veri1=1, veri2=0, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=75, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=76, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=77, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=78, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=79, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=80, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=81, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=82, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=83, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=84, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=85, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w112, l2, w=86, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w111, l0, w=87, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w110, l0, w=88, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w109, l0, w=89, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w108, l0, w=90, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w107, l3, w=91, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=0, ProcessTA.cl4=0)
#
# (w107, l3, w=92, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=1, ProcessTA.cl4=0)
#
# (w107, l3, w=93, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=2, ProcessTA.cl4=0)
#
# (w107, l3, w=94, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=3, ProcessTA.cl4=0)
#
# (w107, l3, w=95, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=4, ProcessTA.cl4=0)
#
# (w107, l3, w=96, veri1=1, veri2=1, veri3=0, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=5, ProcessTA.cl4=0)
#
# (w107, l3, w=97, veri1=1, veri2=1, veri3=1, veri4=1, ProcessTA.cl1=6, ProcessTA.cl2=0, ProcessTA.cl3=6, ProcessTA.cl4=0)
#
# The cooperation can be achieved!
# The robot  0  is updating the path since time  4
# The heavy duty agent  0  is detected at step:  4 . Pos_heavy:  [4, 8] . Pos_light:  [6, 8] . Distance is:  2
# Stop sweep at Region 1  at position  [6 8]
# The closest start location is  [14 12]
# Step  5 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  5 Robot 1 Task left:  ['w57']
# Step :  5 Light:  [12, 10] Heavy  1 :  [12, 0] Distance is:  10
# Round  1  Region 1
# The closest start location is  [14 12]
# Step  5 Robot 1 Pos [12, 0] R0 pos:  [20 12]
# Step  5 Robot 1 Pos [12, 0] R0 pos:  [13 12]
# Step  5 Robot 1 Pos [12, 0] R0 pos:  [14 12]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14 11]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14 10]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  9]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  8]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  7]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  6]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  5]
# Step  6 Robot 1 Pos [12, 0] R0 pos:  [14  4]
# Step  6 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  6 Robot 1 Task left:  ['w57']
# Step :  6 Light:  [14, 3] Heavy 1 :  [13, 0] Distance is:  4
# Step  6 Robot 1 Pos [13, 0] R0 pos:  [14  3]
# Step  6 Robot 1 Pos [13, 0] R0 pos:  [14  2]
# The cooperative task is in region  [0]  the needed robot is  1
# The current map contains the follow task regions  [0] 1
# The new specification without time updating is  [['E', '25', '33', 'w209'], ['G', '95', '101', 'w99', '0', 'meet']]
# The current position before updating is  w12 after updating is  w162
# The new specification after the time update is  [['E', '19', '27', 'w209'], ['G', '89', '95', 'w99', '0', 'meet']]
# The initial position is  w162
# The initial position is  w162
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoCR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 302
# Edge in WTS:  1322
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 162
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w162, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w150, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w138, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w115, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w101, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w87, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w75, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w87, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w101, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w115, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w138, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w150, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w162, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w175, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w176, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w177, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w189, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w190, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w191, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w192, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w193, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w205, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w206, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w207, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w208, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=27, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=28, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=29, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=30, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=31, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=32, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=33, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=34, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=35, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=36, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=37, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=38, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=39, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=40, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=41, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=45, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=46, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w209, l1, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w197, l0, w=79, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w185, l0, w=80, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w171, l0, w=81, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w159, l0, w=82, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w160, l0, w=83, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w161, l0, w=84, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w148, l0, w=85, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w136, l0, w=86, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w126, l0, w=87, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w113, l0, w=88, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w99, l2, w=89, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w99, l2, w=90, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w99, l2, w=91, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w99, l2, w=92, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w99, l2, w=93, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w99, l2, w=94, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w99, l2, w=95, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# The cooperation can be achieved!
# The robot  1  is updating the path since time  6
# The heavy duty agent  1  is detected at step:  6 . Pos_heavy:  [13, 0] . Pos_light:  [14, 1] . Distance is:  2
# Stop sweep at Region 2  at position  [14  1]
# The closest start location is  [8 0]

# %%
"""
Path of agile light-duty robot
"""
path_detect_round[1] = path_detect_round[1][len(path_detect_round[0]): len(path_detect_round[1])]
for n in range(len(path_detect_round)):
    mm = copy.deepcopy(map_original)
    draw_path(mm, path_detect_round[n], fig_folder, "Trajectory of R0 Round " + str(n + 1))

# %%
"""
Get the data ready for plot and video
"""

independent_path_2d, record_working_region, record_task_left = \
    complete_path(world, v_light, independent_path_2d, states_work_region, record_working_region, record_task_left)

record_path_all = world.agents_light.path
for i in range(num_agent_heavy):
    record_path_all = np.concatenate((record_path_all, world.agents_heavy[i].path), axis=1)
    draw_path(map_obs_work, independent_path_2d[i], fig_folder, "Trajectory of heavy-duty robot R" + str(i + 1))

st = len(record_working_region[0])
for i in range(st, len(record_path_all)):
    for j in range(num_agent_heavy):
        record_working_region[j].append(record_working_region[j][-1])
        record_task_left[j].append(record_task_left[j][-1])

# animate_solution(map_obs_work, record_path_all, record_working_region, record_task_left, r_0, r_i, v_light,
#                  fig_folder, video=True)
# Out:
# The current step is  7
# The current positions are [array([4, 8]), array([13,  0])]
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  7 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  7 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step :  8
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  8
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  8 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  8 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step :  9
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  9
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  9 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  9 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step :  10
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  10
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  10 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  10 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step :  11
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  11
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  11 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  11 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step :  12
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  12
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  12 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  12 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step :  13
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  13
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  13 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  13 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step :  14
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  14
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  14 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  14 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step :  15
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  15
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  15 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  15 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step :  16
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  16
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  16 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  16 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step :  17
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  17
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  17 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  17 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step :  18
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  18
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  18 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  18 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step :  19
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  19
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  19 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  19 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step :  20
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  20
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  20 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  20 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step :  21
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  21
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  21 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  21 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step :  22
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  22
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  22 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  22 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step :  23
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  23
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  23 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  23 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step :  24
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  24
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  24 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  24 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step :  25
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  25
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  25 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  25 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step :  26
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  26
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  26 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  26 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step :  27
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  27
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  27 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  27 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step :  28
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  28
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  28 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  28 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step :  29
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  29
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  29 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  29 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step :  30
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  30
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  30 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  30 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step :  31
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step :  31
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  31 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  31 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w67', 'w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step :  32
# task  ['G', '21', '27', 'w67'] has been done by robot  0
# The tasks left  [['E', '65', '75', 'w112'], ['G', '91', '97', 'w107'], ['E', '44', '53', 'w252', '1', 'col']]
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  32
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  32 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  32 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step :  33
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  33
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  33 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  33 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w209', 'w99']
# Step :  34
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  34
# task  ['E', '19', '27', 'w209'] has been done by robot  1
# The tasks left  [['G', '89', '95', 'w99', '0', 'meet']]
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  34 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  34 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step :  35
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  35
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  35 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  35 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step :  36
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  36
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  36 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  36 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step :  37
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  37
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  37 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  37 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step :  38
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  38
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  38 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  38 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step :  39
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step :  39
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  39 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  39 Robot 1 Task left:  ['w99']
# Step  40 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  40 Robot 1 Task left:  ['w99']
# Step  40 Robot 0 Task left:  ['w112', 'w107', 'w252']
# Step  40 Robot 1 Task left:  ['w99']
# ...
# Step  87 Robot 1 Task left:  ['w99']
# Step  87 Robot 0 Task left:  ['w107']
# Step  87 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step :  88
# Step  88 Robot 0 Task left:  ['w107']
# Step :  88
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  88 Robot 0 Task left:  ['w107']
# Step  88 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step :  89
# Step  89 Robot 0 Task left:  ['w107']
# Step :  89
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  89 Robot 0 Task left:  ['w107']
# Step  89 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step :  90
# Step  90 Robot 0 Task left:  ['w107']
# Step :  90
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  90 Robot 0 Task left:  ['w107']
# Step  90 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step :  91
# Step  91 Robot 0 Task left:  ['w107']
# Step :  91
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  91 Robot 0 Task left:  ['w107']
# Step  91 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step :  92
# Step  92 Robot 0 Task left:  ['w107']
# Step :  92
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  92 Robot 0 Task left:  ['w107']
# Step  92 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step :  93
# Step  93 Robot 0 Task left:  ['w107']
# Step :  93
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  93 Robot 0 Task left:  ['w107']
# Step  93 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step :  94
# Step  94 Robot 0 Task left:  ['w107']
# Step :  94
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  94 Robot 0 Task left:  ['w107']
# Step  94 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step :  95
# Step  95 Robot 0 Task left:  ['w107']
# Step :  95
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  95 Robot 0 Task left:  ['w107']
# Step  95 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step :  96
# Step  96 Robot 0 Task left:  ['w107']
# Step :  96
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  96 Robot 0 Task left:  ['w107']
# Step  96 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step :  97
# Step  97 Robot 0 Task left:  ['w107']
# Step :  97
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  97 Robot 0 Task left:  ['w107']
# Step  97 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step :  98
# Step  98 Robot 0 Task left:  ['w107']
# Step :  98
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  98 Robot 0 Task left:  ['w107']
# Step  98 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step :  99
# Step  99 Robot 0 Task left:  ['w107']
# Step :  99
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  99 Robot 0 Task left:  ['w107']
# Step  99 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step :  100
# Step  100 Robot 0 Task left:  ['w107']
# Step :  100
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  100 Robot 0 Task left:  ['w107']
# Step  100 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step :  101
# Step  101 Robot 0 Task left:  ['w107']
# Step :  101
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  101 Robot 0 Task left:  ['w107']
# Step  101 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step  102 Robot 0 Task left:  ['w107']
# Step  102 Robot 1 Task left:  ['w99']
# Step :  102
# task  ['G', '91', '97', 'w107'] has been done by robot  0
# The tasks left  []
# Step  102 Robot 0 Task left:  []
# Step :  102
# task  ['G', '89', '95', 'w99', '0', 'meet'] has been done by robot  1
# The tasks left  []
# Step  102 Robot 1 Task left:  []
