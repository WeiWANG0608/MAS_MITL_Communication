# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Here is an example that all the requests can be accepted.
"""
#  initial map
num_agent_heavy = 4
num_agent_light = 1
map_row, map_col = [20, 20]
#  initial agents and specifications
# agents_heavy, [agents_light] = initial_agents(map_list, num_agent_heavy, num_agent_light)
agents_heavy = [np.array([0, 0]), np.array([0, 19]), np.array([19, 19]), np.array([19, 0])]
agents_light = [0, 4]
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)
obs = [[1, 16], [2, 0], [2, 14], [2, 15], [2, 18], [2, 18], [3, 0], [3, 7],
       [3, 11], [4, 5], [4, 5], [4, 8], [4, 9], [5, 0], [5, 4], [6, 9],
       [7, 4], [7, 18], [8, 1], [9, 9], [10, 7], [10, 16], [10, 19], [11, 1],
       [11, 17], [11, 19], [12, 2], [12, 7], [12, 16], [13, 17], [13, 18], [13, 19],
       [14, 0], [14, 0], [14, 3], [14, 4], [15, 6], [15, 6], [16, 12], [16, 13],
       [17, 0], [17, 9], [17, 12], [17, 19], [18, 0], [19, 9], [19, 10], [19, 17]]
map_original = np.zeros((map_row, map_col), dtype=int)

map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs)):
    map_obstacle[obs[i][0]][obs[i][1]] = 1
states_dict_ori = total_states(map_obstacle)
work_region = [[0, 10, 0, 10], [0, 10, 10, 20], [10, 20, 10, 20], [10, 20, 0, 10]]
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

specifications = [[['G', '7', '10', 'w13'], ['E', '50', '55', 'w15', 'R3', 'meet']],
                  [['G', '12', '15', 'w4'], ['G', '30', '35', 'w8'], ['G', '67', '70', 'w15', 'R0', 'col']],
                  [['E', '8', '12', 'w43'], ['G', '25', '28', 'w75'], ['G', '60', '65', 'w55', 'R1', 'meet']],
                  [['E', '14', '30', 'w57'], ['E', '25', '30', 'w72']]]

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [array([0, 0]), array([ 0, 19]), array([19, 19]), array([19,  0])] . Init light_duty agent:  [0, 4]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 2
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2]) + h_a) * v_heavy) /
    ((2 * r_0) - h_a)) for i in range(num_agent_heavy)])

# %%
"""
--------------- Mission decomposition ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = [[] for i in range(num_agent_heavy)]
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w0
# The initial position is  w0
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 88
# Edge in WTS:  370
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 0
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w0, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w11, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=8, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w13, l1, w=9, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w13, l1, w=10, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w3, l0, w=11, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w2, l0, w=12, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w1, l0, w=13, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=15, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=21, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=25, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=27, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w11, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w12, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w13, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w14, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w15, l2, w=50, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The initial position is  w9
# The initial position is  w9
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 94
# Edge in WTS:  408
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 9
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w9, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w17, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w16, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w7, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=15, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=16, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=17, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=18, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=19, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w10, l0, w=20, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=21, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=22, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=23, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=24, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=25, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=26, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=27, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=28, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w7, l0, w=29, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w8, l2, w=30, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w8, l2, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w8, l2, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w8, l2, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l2, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w8, l2, w=35, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w7, l0, w=36, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=37, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=38, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=39, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=40, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=41, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=42, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=43, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=44, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=45, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=46, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w15, l3, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w15, l3, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=1)
#
# (w15, l3, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=2)
#
# (w15, l3, w=70, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=3)
#
# The initial position is  w85
# The initial position is  w85
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R2
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR2.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 86
# Edge in WTS:  362
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 85
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w85, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w77, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w76, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w67, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w45, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w44, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w43, l1, w=12, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w43, l1, w=13, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w43, l1, w=14, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w43, l1, w=15, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w43, l1, w=16, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w53, l0, w=17, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w61, l0, w=18, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w69, l0, w=19, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w70, l0, w=20, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w71, l0, w=21, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w72, l0, w=22, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w73, l0, w=23, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w74, l0, w=24, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w75, l2, w=25, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w75, l2, w=26, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w75, l2, w=27, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w75, l2, w=28, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w66, l0, w=29, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w57, l0, w=30, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w49, l0, w=31, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w39, l0, w=32, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w38, l0, w=33, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w31, l0, w=34, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w30, l0, w=35, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w21, l0, w=36, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w13, l0, w=37, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w5, l0, w=38, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w4, l0, w=39, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w3, l0, w=40, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w2, l0, w=41, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w1, l0, w=42, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w0, l0, w=43, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l0, w=44, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w0, l0, w=45, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l0, w=46, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w0, l0, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l0, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w0, l0, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l0, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w16, l0, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w25, l0, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w32, l0, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w33, l0, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w34, l0, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w44, l0, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w45, l0, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w46, l0, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w54, l0, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w55, l3, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w55, l3, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=1)
#
# (w55, l3, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=2)
#
# (w55, l3, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=3)
#
# (w55, l3, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=4)
#
# (w55, l3, w=65, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=5)
#
# The initial position is  w79
# The initial position is  w79
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 88
# Edge in WTS:  370
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 79
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w79, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w80, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w70, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w62, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w36, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w26, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w36, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=21, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w64, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w72, l2, w=25, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The spec to verify (before) is  [['G', '7', '10', 'w13'], ['G', '50', '55', 'w15', 'R3', 'meet']]
# The initial position is  w0
# The initial position is  w0
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 88
# Edge in WTS:  370
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 0
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w0, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w11, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=8, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w13, l1, w=9, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w13, l1, w=10, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w3, l0, w=11, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w2, l0, w=12, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w1, l0, w=13, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=15, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# ...
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 88
# Edge in WTS:  370
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 0
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w0, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w11, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l1, w=8, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w13, l1, w=9, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w13, l1, w=10, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w3, l0, w=11, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w2, l0, w=12, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w1, l0, w=13, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=15, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=21, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=25, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=27, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w10, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w11, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w12, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w13, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w14, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w15, l2, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w15, l2, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w15, l2, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w15, l2, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w15, l2, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w15, l2, w=55, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# The initial position is  w79
# The initial position is  w79
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 88
# Edge in WTS:  370
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 79
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w79, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w80, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w70, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w62, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w36, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w26, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w36, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l1, w=21, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w64, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w72, l2, w=25, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['G', '7', '10', 'w13'], ['E', '50', '55', 'w15', 'R3', 'meet']], [['G', '12', '15', 'w4'], ['G', '30', '35', 'w8'], ['G', '67', '70', 'w15', 'R0', 'col']], [['E', '8', '12', 'w43'], ['G', '25', '28', 'w75'], ['G', '60', '65', 'w55', 'R1', 'meet']], [['E', '14', '30', 'w57'], ['E', '25', '30', 'w72']]]
# ------------ If all the paths exist ------------
# [True, True, True, True]
# ---- The Independent Task Specification ----
# [[['G', '7', '10', 'w13'], ['G', '50', '55', 'w15', 'R3', 'meet']], [['G', '12', '15', 'w4'], ['G', '30', '35', 'w8']], [['E', '8', '12', 'w43'], ['G', '25', '28', 'w75'], ['G', '60', '65', 'w55']], [['E', '14', '30', 'w57'], ['E', '25', '30', 'w72']]]
# --------- The Independent Request ---------
# [[[], [], [], [['E', '50', '55', 'w15', 'R3', 'meet']]], [[['G', '67', '70', 'w15', 'R0', 'col']], [], [], []], [[], [['G', '60', '65', 'w55', 'R1', 'meet']], [], []], [[], [], [], []]]

# %%
 # save all the info of Mission Decomposition
info = ''
for i in range(num_agent_heavy):
    info = info + str(agents_heavy[i])+';' + ','.join(str(j) for j in specifications[i]) + ';' + ','.join(
        str(j) for j in independent_task[i]) + ';' + ','.join(str(j) for j in independent_request[i]) + '&'
text_file = open(file_folder + "/" + 'initialization_info' + ".txt", "w")
text_file.write(info)
text_file.close()

# %%
# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
"""
Start two round SWEEP
"""
# start sweeping
# maximum 2 rounds to guarantee the requests exchange

num_round_exchange = 2

path_detect_round, independent_path_2d, record_working_region, record_task_left = \
    collect_deliver(world, map_obs_work, num_round_exchange, num_agent_heavy, work_region, states_work_region,
                    independent_path_2d, h_a, r_0, v_light, file_folder)
# Out:
# Round  0  Region 0
# The closest start location is  [2 0]
# Step  0 Robot 0 Pos [0 0] R0 pos:  [8 0]
# Step  0 Robot 0 Pos [0 0] R0 pos:  [0 4]
# Step  0 Robot 0 Pos [0 0] R0 pos:  [0 3]
# len() 1
# kl:  0
# The heavy duty agent  0  is detected at step:  0 . Pos_heavy:  [0, 0] . Pos_light:  [0, 2] . Distance is:  2
# Stop sweep at Region 1  at position  [0 2]
# The closest start location is  [ 2 10]
# Step  1 Robot 0 Task left:  ['w13', 'w15']
# Step  1 Robot 1 Task left:  ['w4', 'w8']
# Step  1 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  1 Robot 3 Task left:  ['w57', 'w72']
# Step :  1 Light:  [0, 9] Heavy  1 :  [1, 19] Distance is:  11
# Round  0  Region 1
# The closest start location is  [ 2 10]
# Step  1 Robot 1 Pos [1, 19] R0 pos:  [ 8 10]
# Step  1 Robot 1 Pos [1, 19] R0 pos:  [ 1 10]
# Step  1 Robot 1 Pos [1, 19] R0 pos:  [ 2 10]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 11]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 12]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 13]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 14]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 15]
# Step  2 Robot 1 Pos [1, 19] R0 pos:  [ 2 16]
# Step  2 Robot 0 Task left:  ['w13', 'w15']
# Step  2 Robot 1 Task left:  ['w4', 'w8']
# Step  2 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  2 Robot 3 Task left:  ['w57', 'w72']
# Step :  2 Light:  [2, 17] Heavy 1 :  [0, 19] Distance is:  4
# Step  2 Robot 1 Pos [0, 19] R0 pos:  [ 2 17]
# Step  2 Robot 1 Pos [0, 19] R0 pos:  [ 2 18]
# len() 1
# kl:  0
# The heavy duty agent  1  is detected at step:  2 . Pos_heavy:  [0, 19] . Pos_light:  [2, 19] . Distance is:  2
# Stop sweep at Region 2  at position  [ 2 19]
# The closest start location is  [12 19]
# Step  3 Robot 0 Task left:  ['w13', 'w15']
# Step  3 Robot 1 Task left:  ['w4', 'w8']
# Step  3 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  3 Robot 3 Task left:  ['w57', 'w72']
# Step :  3 Light:  [10, 19] Heavy  2 :  [17, 18] Distance is:  8
# Round  0  Region 2
# The closest start location is  [12 19]
# Step  3 Robot 2 Pos [17, 18] R0 pos:  [18 19]
# Step  3 Robot 2 Pos [17, 18] R0 pos:  [11 19]
# Step  3 Robot 2 Pos [17, 18] R0 pos:  [12 19]
# Step  3 Robot 2 Pos [17, 18] R0 pos:  [12 18]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 17]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 16]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 15]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 14]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 13]
# Step  4 Robot 2 Pos [17, 18] R0 pos:  [12 12]
# Step  4 Robot 0 Task left:  ['w13', 'w15']
# Step  4 Robot 1 Task left:  ['w4', 'w8']
# Step  4 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  4 Robot 3 Task left:  ['w57', 'w72']
# Step :  4 Light:  [12, 11] Heavy 2 :  [16, 18] Distance is:  11
# Step  4 Robot 2 Pos [16, 18] R0 pos:  [12 11]
# Step  4 Robot 2 Pos [16, 18] R0 pos:  [12 10]
# Step  4 Robot 2 Pos [16, 18] R0 pos:  [13 10]
# Step  4 Robot 2 Pos [16, 18] R0 pos:  [14 10]
# Step  4 Robot 2 Pos [16, 18] R0 pos:  [14 11]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 12]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 13]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 14]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 15]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 16]
# Step  5 Robot 2 Pos [16, 18] R0 pos:  [14 17]
# len() 1
# kl:  0
# The heavy duty agent  2  is detected at step:  5 . Pos_heavy:  [16, 18] . Pos_light:  [14, 18] . Distance is:  2
# Stop sweep at Region 3  at position  [14 18]
# The closest start location is  [12  9]
# Step  6 Robot 0 Task left:  ['w13', 'w15']
# Step  6 Robot 1 Task left:  ['w4', 'w8']
# Step  6 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  6 Robot 3 Task left:  ['w57', 'w72']
# Step :  6 Light:  [13, 9] Heavy  3 :  [14, 1] Distance is:  9
# Round  0  Region 3
# The closest start location is  [12  9]
# Step  6 Robot 3 Pos [14, 1] R0 pos:  [18  9]
# Step  6 Robot 3 Pos [14, 1] R0 pos:  [13  9]
# Step  6 Robot 3 Pos [14, 1] R0 pos:  [12  9]
# Step  6 Robot 3 Pos [14, 1] R0 pos:  [12  8]
# Step  6 Robot 3 Pos [14, 1] R0 pos:  [12  7]
# Step  7 Robot 3 Pos [14, 1] R0 pos:  [12  6]
# Step  7 Robot 3 Pos [14, 1] R0 pos:  [12  5]
# Step  7 Robot 3 Pos [14, 1] R0 pos:  [12  4]
# Step  7 Robot 3 Pos [14, 1] R0 pos:  [12  3]
# Step  7 Robot 3 Pos [14, 1] R0 pos:  [12  2]
# The heavy duty agent  3  is detected at step:  7 . Pos_heavy:  [14, 1] . Pos_light:  [12, 1] . Distance is:  2
# Stop sweep at Region 4  at position  [12  1]
# The closest start location is  [7 0]
# Step  7 Robot 0 Task left:  ['w13', 'w15']
# Step  7 Robot 1 Task left:  ['w4', 'w8']
# Step  7 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  7 Robot 3 Task left:  ['w57', 'w72']
# Step :  7 Light:  [12, 1] Heavy  4 :  [1, 3] Distance is:  13
# Round  1  Region 0
# The closest start location is  [7 0]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [1 0]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [8 0]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 0]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 1]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 2]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 3]
# Step  8 Robot 0 Task left:  ['w13', 'w15']
# Step  8 Robot 1 Task left:  ['w4', 'w8']
# Step  8 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  8 Robot 3 Task left:  ['w57', 'w72']
# Step :  8 Light:  [7, 4] Heavy 0 :  [1, 3] Distance is:  7
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 4]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 5]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 6]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 7]
# Step  8 Robot 0 Pos [1, 3] R0 pos:  [7 8]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [7 9]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [6 9]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 9]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 8]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 7]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 6]
# Step  9 Robot 0 Task left:  ['w13', 'w15']
# Step  9 Robot 1 Task left:  ['w4', 'w8']
# Step  9 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  9 Robot 3 Task left:  ['w57', 'w72']
# Step :  9 Light:  [5, 5] Heavy 0 :  [1, 3] Distance is:  6
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 5]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 4]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 3]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 2]
# Step  9 Robot 0 Pos [1, 3] R0 pos:  [5 1]
# Step  10 Robot 0 Pos [1, 3] R0 pos:  [5 0]
# Step  10 Robot 0 Pos [1, 3] R0 pos:  [4 0]
# Step  10 Robot 0 Pos [1, 3] R0 pos:  [3 0]
# Step  10 Robot 0 Pos [1, 3] R0 pos:  [3 1]
# Step  10 Robot 0 Pos [1, 3] R0 pos:  [3 2]
# The cooperative task is in region  [1]  the needed robot is  0
# The current map contains the follow task regions  [1] 0
# The new specification without time updating is  [['G', '7', '10', 'w23'], ['G', '50', '55', 'w25', 'R3', 'meet'], ['G', '67', '70', 'w35', '1', 'col']]
# The current position before updating is  w13 after updating is  w23
# The new specification after the time update is  [['G', '40', '45', 'w25', 'R3', 'meet'], ['G', '57', '60', 'w35', '1', 'col']]
# The initial position is  w23
# The initial position is  w23
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR0
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoCR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 199
# Edge in WTS:  869
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 23
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w23, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w22, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w23, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w24, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w25, l1, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w25, l1, w=41, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w25, l1, w=42, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w25, l1, w=43, veri1=0, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w25, l1, w=44, veri1=0, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w25, l1, w=45, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w5, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w6, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w26, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w27, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w28, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w29, l0, w=51, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w30, l0, w=52, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w31, l0, w=53, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w32, l0, w=54, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w33, l0, w=55, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w34, l0, w=56, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w35, l2, w=57, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=0)
#
# (w35, l2, w=58, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=1)
#
# (w35, l2, w=59, veri1=1, veri2=0, ProcessTA.cl1=5, ProcessTA.cl2=2)
#
# (w35, l2, w=60, veri1=1, veri2=1, ProcessTA.cl1=5, ProcessTA.cl2=3)
#
# The cooperation can be achieved!
# The robot  0  is updating the path since time  10
# The heavy duty agent  0  is detected at step:  10 . Pos_heavy:  [1, 3] . Pos_light:  [3, 3] . Distance is:  2
# Stop sweep at Region 1  at position  [3 3]
# The closest start location is  [ 2 10]
# Step  10 Robot 0 Task left:  ['w25', 'w35']
# Step  10 Robot 1 Task left:  ['w4', 'w8']
# Step  10 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  10 Robot 3 Task left:  ['w57', 'w72']
# Step :  10 Light:  [3, 3] Heavy  1 :  [0, 15] Distance is:  15
# Round  1  Region 1
# The closest start location is  [ 2 10]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 8 10]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [2 9]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 2 10]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 2 11]
# Step  11 Robot 0 Task left:  ['w25', 'w35']
# Step  11 Robot 1 Task left:  ['w4', 'w8']
# Step  11 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  11 Robot 3 Task left:  ['w57', 'w72']
# Step :  11 Light:  [2, 12] Heavy 1 :  [0, 15] Distance is:  5
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 2 12]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 2 13]
# Step  11 Robot 1 Pos [0, 15] R0 pos:  [ 2 14]
# The cooperative task is in region  [2]  the needed robot is  1
# The current map contains the follow task regions  [2] 1
# The new specification without time updating is  [['G', '12', '15', 'w4'], ['G', '30', '35', 'w8'], ['G', '60', '65', 'w167', '2', 'meet']]
# The current position before updating is  w5 after updating is  w5
# The new specification after the time update is  [['G', '1', '4', 'w4'], ['G', '19', '24', 'w8'], ['G', '49', '54', 'w167', '2', 'meet']]
# The initial position is  w5
# The initial position is  w5
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR1
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoCR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 198
# Edge in WTS:  852
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 5
# Initial state in TA: 0
# , , , , ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w5, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=1, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=2, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=4, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=5, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=6, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=7, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=8, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w10, l0, w=9, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=10, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=11, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=12, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=13, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=14, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=3, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l1, w=15, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=16, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=17, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w7, l0, w=18, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w8, l2, w=19, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w8, l2, w=20, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w8, l2, w=21, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w8, l2, w=22, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w8, l2, w=23, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w8, l2, w=24, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w7, l0, w=25, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w6, l0, w=26, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=27, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w15, l0, w=28, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w5, l0, w=29, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w15, l0, w=30, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w14, l0, w=31, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w13, l0, w=32, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w22, l0, w=33, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w28, l0, w=34, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w38, l0, w=35, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w48, l0, w=36, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w58, l0, w=37, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w68, l0, w=38, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w77, l0, w=39, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w96, l0, w=40, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w115, l0, w=41, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w123, l0, w=42, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w131, l0, w=43, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w140, l0, w=44, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w147, l0, w=45, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w157, l0, w=46, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w158, l0, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w166, l0, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w167, l3, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w167, l3, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=1)
#
# (w167, l3, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=2)
#
# (w167, l3, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=3)
#
# (w167, l3, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=4)
#
# (w167, l3, w=54, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=5)
#
# The cooperation can be achieved!
# The robot  1  is updating the path since time  11
# The heavy duty agent  1  is detected at step:  11 . Pos_heavy:  [0, 15] . Pos_light:  [2, 15] . Distance is:  2
# Stop sweep at Region 2  at position  [ 2 15]
# The closest start location is  [12 19]
# Step  12 Robot 0 Task left:  ['w25', 'w35']
# Step  12 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  12 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  12 Robot 3 Task left:  ['w57', 'w72']
# Step :  12 Light:  [8, 16] Heavy  2 :  [15, 11] Distance is:  12
# Round  1  Region 2
# The closest start location is  [12 19]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [18 19]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [11 19]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 19]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 18]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 17]
# Step  13 Robot 0 Task left:  ['w25', 'w35']
# Step  13 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  13 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  13 Robot 3 Task left:  ['w57', 'w72']
# Step :  13 Light:  [12, 16] Heavy 2 :  [15, 11] Distance is:  8
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 16]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 15]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 14]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 13]
# Step  13 Robot 2 Pos [15, 11] R0 pos:  [12 12]
# Step  14 Robot 2 Pos [15, 11] R0 pos:  [12 11]
# Step  14 Robot 2 Pos [15, 11] R0 pos:  [12 10]
# Step  14 Robot 2 Pos [15, 11] R0 pos:  [13 10]
# The heavy duty agent  2  is detected at step:  13 . Pos_heavy:  [15, 11] . Pos_light:  [14, 10] . Distance is:  2
# Stop sweep at Region 3  at position  [14 10]
# The closest start location is  [12  9]
# Step  14 Robot 0 Task left:  ['w25', 'w35']
# Step  14 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  14 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  14 Robot 3 Task left:  ['w57', 'w72']
# Step :  14 Light:  [13, 9] Heavy  3 :  [14, 1] Distance is:  9
# Round  1  Region 3
# The closest start location is  [12  9]
# Step  14 Robot 3 Pos [14, 1] R0 pos:  [18  9]
# Step  14 Robot 3 Pos [14, 1] R0 pos:  [13  9]
# Step  14 Robot 3 Pos [14, 1] R0 pos:  [12  9]
# Step  14 Robot 3 Pos [14, 1] R0 pos:  [12  8]
# Step  14 Robot 3 Pos [14, 1] R0 pos:  [12  7]
# Step  15 Robot 3 Pos [14, 1] R0 pos:  [12  6]
# Step  15 Robot 3 Pos [14, 1] R0 pos:  [12  5]
# Step  15 Robot 3 Pos [14, 1] R0 pos:  [12  4]
# Step  15 Robot 3 Pos [14, 1] R0 pos:  [12  3]
# Step  15 Robot 3 Pos [14, 1] R0 pos:  [12  2]
# The cooperative task is in region  [0]  the needed robot is  3
# The current map contains the follow task regions  [0] 3
# The new specification without time updating is  [['E', '14', '30', 'w163'], ['E', '25', '30', 'w178'], ['E', '50', '55', 'w15', '0', 'meet']]
# The current position before updating is  w36 after updating is  w142
# The new specification after the time update is  [['E', '0', '15', 'w163'], ['E', '10', '15', 'w178'], ['E', '35', '40', 'w15', '0', 'meet']]
# The initial position is  w142
# The initial position is  w142
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR3
# /home/wei/PycharmProjects/MITL_communication/MITL_communication/files/2022-05-29/system_infoCR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 194
# Edge in WTS:  822
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 142
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w142, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w133, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w125, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w133, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w142, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w150, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w159, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w168, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w176, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w177, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w177, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w178, l2, w=11, veri1=0, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w170, l0, w=12, veri1=0, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w161, l0, w=13, veri1=0, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w162, l0, w=14, veri1=0, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w163, l1, w=15, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w163, l1, w=16, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w163, l1, w=17, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w163, l1, w=18, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w154, l0, w=19, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w144, l0, w=20, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w137, l0, w=21, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w128, l0, w=22, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w119, l0, w=23, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w103, l0, w=24, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w84, l0, w=25, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w74, l0, w=26, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w65, l0, w=27, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=28, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=29, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=30, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w42, l0, w=31, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w34, l0, w=32, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=33, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w16, l0, w=34, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w15, l3, w=35, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# The cooperation can be achieved!
# The robot  3  is updating the path since time  15
# The heavy duty agent  3  is detected at step:  15 . Pos_heavy:  [14, 1] . Pos_light:  [12, 1] . Distance is:  2
# Stop sweep at Region 4  at position  [12  1]
# The closest start location is  [7 0]
# Step  15 Robot 0 Task left:  ['w25', 'w35']
# Step  15 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  15 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  15 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  15 Light:  [12, 1] Heavy  4 :  [1, 0] Distance is:  12

# %%
"""
Path of agile light-duty robot
"""
path_detect_round[1] = path_detect_round[1][len(path_detect_round[0]): len(path_detect_round[1])]
for n in range(len(path_detect_round)):
    mm = copy.deepcopy(map_original)
    draw_path(mm, path_detect_round[n], fig_folder, "Trajectory of R0 Round " + str(n + 1))

# %%
"""
Get the data ready for plot and video
"""

independent_path_2d, record_working_region, record_task_left = \
    complete_path(world, v_light, independent_path_2d, states_work_region, record_working_region, record_task_left)

record_path_all = world.agents_light.path
for i in range(num_agent_heavy):
    record_path_all = np.concatenate((record_path_all, world.agents_heavy[i].path), axis=1)
    draw_path(map_obs_work, independent_path_2d[i], fig_folder, "Trajectory of heavy-duty robot R" + str(i + 1))

st = len(record_working_region[0])
for i in range(st, len(record_path_all)):
    for j in range(num_agent_heavy):
        record_working_region[j].append(record_working_region[j][-1])
        record_task_left[j].append(record_task_left[j][-1])

# animate_solution(map_obs_work, record_path_all, record_working_region, record_task_left, r_0, r_i, v_light,
#                  fig_folder, video=True)
# Out:
# The current step is  16
# The current positions are [array([1, 0]), array([ 0, 14]), array([15, 11]), array([14,  1])]
# Step  16 Robot 0 Task left:  ['w25', 'w35']
# Step  16 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  16 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  16 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  16 Robot 0 Task left:  ['w25', 'w35']
# Step  16 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  16 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  16 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  16 Robot 0 Task left:  ['w25', 'w35']
# Step  16 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  16 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  16 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  16 Robot 0 Task left:  ['w25', 'w35']
# Step  16 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  16 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  16 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  16 Robot 0 Task left:  ['w25', 'w35']
# Step  16 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  16 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  16 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  17 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  17 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  17 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  17 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w4', 'w8', 'w167']
# Step  17 Robot 2 Task left:  ['w43', 'w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  17
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step :  17
# task  ['G', '1', '4', 'w4'] has been done by robot  1
# The tasks left  [['G', '19', '24', 'w8'], ['G', '49', '54', 'w167', '2', 'meet']]
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step :  17
# task  ['E', '8', '12', 'w43'] has been done by robot  2
# The tasks left  [['G', '25', '28', 'w75'], ['G', '60', '65', 'w55']]
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step :  17
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  17 Robot 0 Task left:  ['w25', 'w35']
# Step  17 Robot 1 Task left:  ['w8', 'w167']
# Step  17 Robot 2 Task left:  ['w75', 'w55']
# Step  17 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  18
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step :  18
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step :  18
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step :  18
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  18 Robot 0 Task left:  ['w25', 'w35']
# Step  18 Robot 1 Task left:  ['w8', 'w167']
# Step  18 Robot 2 Task left:  ['w75', 'w55']
# Step  18 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  19
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step :  19
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step :  19
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step :  19
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  19 Robot 0 Task left:  ['w25', 'w35']
# Step  19 Robot 1 Task left:  ['w8', 'w167']
# Step  19 Robot 2 Task left:  ['w75', 'w55']
# Step  19 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  20
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step :  20
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step :  20
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step :  20
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  20 Robot 0 Task left:  ['w25', 'w35']
# Step  20 Robot 1 Task left:  ['w8', 'w167']
# Step  20 Robot 2 Task left:  ['w75', 'w55']
# Step  20 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  21
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step :  21
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step :  21
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step :  21
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  21 Robot 0 Task left:  ['w25', 'w35']
# Step  21 Robot 1 Task left:  ['w8', 'w167']
# Step  21 Robot 2 Task left:  ['w75', 'w55']
# Step  21 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  22
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step :  22
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step :  22
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step :  22
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  22 Robot 0 Task left:  ['w25', 'w35']
# Step  22 Robot 1 Task left:  ['w8', 'w167']
# Step  22 Robot 2 Task left:  ['w75', 'w55']
# Step  22 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  23
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step :  23
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step :  23
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step :  23
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  23 Robot 0 Task left:  ['w25', 'w35']
# Step  23 Robot 1 Task left:  ['w8', 'w167']
# Step  23 Robot 2 Task left:  ['w75', 'w55']
# Step  23 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  24
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step :  24
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step :  24
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step :  24
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  24 Robot 0 Task left:  ['w25', 'w35']
# Step  24 Robot 1 Task left:  ['w8', 'w167']
# Step  24 Robot 2 Task left:  ['w75', 'w55']
# Step  24 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  25
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step :  25
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step :  25
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step :  25
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  25 Robot 0 Task left:  ['w25', 'w35']
# Step  25 Robot 1 Task left:  ['w8', 'w167']
# Step  25 Robot 2 Task left:  ['w75', 'w55']
# Step  25 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  26
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step :  26
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step :  26
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step :  26
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  26 Robot 0 Task left:  ['w25', 'w35']
# Step  26 Robot 1 Task left:  ['w8', 'w167']
# Step  26 Robot 2 Task left:  ['w75', 'w55']
# Step  26 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w178', 'w15']
# Step :  27
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step :  27
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step :  27
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step :  27
# task  ['E', '10', '15', 'w178'] has been done by robot  3
# The tasks left  [['E', '0', '15', 'w163'], ['E', '35', '40', 'w15', '0', 'meet']]
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  27 Robot 0 Task left:  ['w25', 'w35']
# Step  27 Robot 1 Task left:  ['w8', 'w167']
# Step  27 Robot 2 Task left:  ['w75', 'w55']
# Step  27 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step :  28
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step :  28
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step :  28
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step :  28
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  28 Robot 0 Task left:  ['w25', 'w35']
# Step  28 Robot 1 Task left:  ['w8', 'w167']
# Step  28 Robot 2 Task left:  ['w75', 'w55']
# Step  28 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w75', 'w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w75', 'w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w75', 'w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w75', 'w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w75', 'w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step :  29
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step :  29
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step :  29
# task  ['G', '25', '28', 'w75'] has been done by robot  2
# The tasks left  [['G', '60', '65', 'w55']]
# Step  29 Robot 2 Task left:  ['w55']
# Step :  29
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  29 Robot 0 Task left:  ['w25', 'w35']
# Step  29 Robot 1 Task left:  ['w8', 'w167']
# Step  29 Robot 2 Task left:  ['w55']
# Step  29 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step :  30
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step :  30
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step :  30
# Step  30 Robot 2 Task left:  ['w55']
# Step :  30
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  30 Robot 0 Task left:  ['w25', 'w35']
# Step  30 Robot 1 Task left:  ['w8', 'w167']
# Step  30 Robot 2 Task left:  ['w55']
# Step  30 Robot 3 Task left:  ['w163', 'w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w163', 'w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w163', 'w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w163', 'w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w163', 'w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w163', 'w15']
# Step :  31
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step :  31
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step :  31
# Step  31 Robot 2 Task left:  ['w55']
# Step :  31
# task  ['E', '0', '15', 'w163'] has been done by robot  3
# The tasks left  [['E', '35', '40', 'w15', '0', 'meet']]
# Step  31 Robot 3 Task left:  ['w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w15']
# Step  31 Robot 0 Task left:  ['w25', 'w35']
# Step  31 Robot 1 Task left:  ['w8', 'w167']
# Step  31 Robot 2 Task left:  ['w55']
# Step  31 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step :  32
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step :  32
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step :  32
# Step  32 Robot 2 Task left:  ['w55']
# Step :  32
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  32 Robot 0 Task left:  ['w25', 'w35']
# Step  32 Robot 1 Task left:  ['w8', 'w167']
# Step  32 Robot 2 Task left:  ['w55']
# Step  32 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step :  33
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step :  33
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step :  33
# Step  33 Robot 2 Task left:  ['w55']
# Step :  33
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  33 Robot 0 Task left:  ['w25', 'w35']
# Step  33 Robot 1 Task left:  ['w8', 'w167']
# Step  33 Robot 2 Task left:  ['w55']
# Step  33 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step :  34
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step :  34
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step :  34
# Step  34 Robot 2 Task left:  ['w55']
# Step :  34
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  34 Robot 0 Task left:  ['w25', 'w35']
# Step  34 Robot 1 Task left:  ['w8', 'w167']
# Step  34 Robot 2 Task left:  ['w55']
# Step  34 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step :  35
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step :  35
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step :  35
# Step  35 Robot 2 Task left:  ['w55']
# Step :  35
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  35 Robot 0 Task left:  ['w25', 'w35']
# Step  35 Robot 1 Task left:  ['w8', 'w167']
# Step  35 Robot 2 Task left:  ['w55']
# Step  35 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w8', 'w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w8', 'w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w8', 'w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w8', 'w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w8', 'w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step :  36
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step :  36
# task  ['G', '19', '24', 'w8'] has been done by robot  1
# The tasks left  [['G', '49', '54', 'w167', '2', 'meet']]
# Step  36 Robot 1 Task left:  ['w167']
# Step :  36
# Step  36 Robot 2 Task left:  ['w55']
# Step :  36
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  36 Robot 0 Task left:  ['w25', 'w35']
# Step  36 Robot 1 Task left:  ['w167']
# Step  36 Robot 2 Task left:  ['w55']
# Step  36 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step :  37
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step :  37
# Step  37 Robot 1 Task left:  ['w167']
# Step :  37
# Step  37 Robot 2 Task left:  ['w55']
# Step :  37
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  37 Robot 0 Task left:  ['w25', 'w35']
# Step  37 Robot 1 Task left:  ['w167']
# Step  37 Robot 2 Task left:  ['w55']
# Step  37 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step :  38
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step :  38
# Step  38 Robot 1 Task left:  ['w167']
# Step :  38
# Step  38 Robot 2 Task left:  ['w55']
# Step :  38
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  38 Robot 0 Task left:  ['w25', 'w35']
# Step  38 Robot 1 Task left:  ['w167']
# Step  38 Robot 2 Task left:  ['w55']
# Step  38 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step :  39
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step :  39
# Step  39 Robot 1 Task left:  ['w167']
# Step :  39
# Step  39 Robot 2 Task left:  ['w55']
# Step :  39
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  39 Robot 0 Task left:  ['w25', 'w35']
# Step  39 Robot 1 Task left:  ['w167']
# Step  39 Robot 2 Task left:  ['w55']
# Step  39 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step :  40
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step :  40
# Step  40 Robot 1 Task left:  ['w167']
# Step :  40
# Step  40 Robot 2 Task left:  ['w55']
# Step :  40
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# Step  40 Robot 1 Task left:  ['w167']
# Step  40 Robot 2 Task left:  ['w55']
# Step  40 Robot 3 Task left:  ['w15']
# Step  40 Robot 0 Task left:  ['w25', 'w35']
# ...
# Step  61 Robot 2 Task left:  ['w55']
# Step :  61
# Step  61 Robot 3 Task left:  []
# Step  61 Robot 0 Task left:  ['w35']
# Step  61 Robot 1 Task left:  ['w167']
# Step  61 Robot 2 Task left:  ['w55']
# Step  61 Robot 3 Task left:  []
# Step  61 Robot 0 Task left:  ['w35']
# Step  61 Robot 1 Task left:  ['w167']
# Step  61 Robot 2 Task left:  ['w55']
# Step  61 Robot 3 Task left:  []
# Step  61 Robot 0 Task left:  ['w35']
# Step  61 Robot 1 Task left:  ['w167']
# Step  61 Robot 2 Task left:  ['w55']
# Step  61 Robot 3 Task left:  []
# Step  61 Robot 0 Task left:  ['w35']
# Step  61 Robot 1 Task left:  ['w167']
# Step  61 Robot 2 Task left:  ['w55']
# Step  61 Robot 3 Task left:  []
# Step  61 Robot 0 Task left:  ['w35']
# Step  61 Robot 1 Task left:  ['w167']
# Step  61 Robot 2 Task left:  ['w55']
# Step  61 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step :  62
# Step  62 Robot 0 Task left:  ['w35']
# Step :  62
# Step  62 Robot 1 Task left:  ['w167']
# Step :  62
# Step  62 Robot 2 Task left:  ['w55']
# Step :  62
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  62 Robot 0 Task left:  ['w35']
# Step  62 Robot 1 Task left:  ['w167']
# Step  62 Robot 2 Task left:  ['w55']
# Step  62 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step :  63
# Step  63 Robot 0 Task left:  ['w35']
# Step :  63
# Step  63 Robot 1 Task left:  ['w167']
# Step :  63
# Step  63 Robot 2 Task left:  ['w55']
# Step :  63
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  63 Robot 0 Task left:  ['w35']
# Step  63 Robot 1 Task left:  ['w167']
# Step  63 Robot 2 Task left:  ['w55']
# Step  63 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step :  64
# Step  64 Robot 0 Task left:  ['w35']
# Step :  64
# Step  64 Robot 1 Task left:  ['w167']
# Step :  64
# Step  64 Robot 2 Task left:  ['w55']
# Step :  64
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  64 Robot 0 Task left:  ['w35']
# Step  64 Robot 1 Task left:  ['w167']
# Step  64 Robot 2 Task left:  ['w55']
# Step  64 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step :  65
# Step  65 Robot 0 Task left:  ['w35']
# Step :  65
# Step  65 Robot 1 Task left:  ['w167']
# Step :  65
# Step  65 Robot 2 Task left:  ['w55']
# Step :  65
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  65 Robot 0 Task left:  ['w35']
# Step  65 Robot 1 Task left:  ['w167']
# Step  65 Robot 2 Task left:  ['w55']
# Step  65 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  ['w167']
# Step  66 Robot 2 Task left:  ['w55']
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  ['w167']
# Step  66 Robot 2 Task left:  ['w55']
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  ['w167']
# Step  66 Robot 2 Task left:  ['w55']
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  ['w167']
# Step  66 Robot 2 Task left:  ['w55']
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  ['w167']
# Step  66 Robot 2 Task left:  ['w55']
# Step  66 Robot 3 Task left:  []
# Step :  66
# Step  66 Robot 0 Task left:  ['w35']
# Step :  66
# task  ['G', '49', '54', 'w167', '2', 'meet'] has been done by robot  1
# The tasks left  []
# Step  66 Robot 1 Task left:  []
# Step :  66
# task  ['G', '60', '65', 'w55'] has been done by robot  2
# The tasks left  []
# Step  66 Robot 2 Task left:  []
# Step :  66
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  []
# Step  66 Robot 2 Task left:  []
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  []
# Step  66 Robot 2 Task left:  []
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  []
# Step  66 Robot 2 Task left:  []
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  []
# Step  66 Robot 2 Task left:  []
# Step  66 Robot 3 Task left:  []
# Step  66 Robot 0 Task left:  ['w35']
# Step  66 Robot 1 Task left:  []
# Step  66 Robot 2 Task left:  []
# Step  66 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step :  67
# Step  67 Robot 0 Task left:  ['w35']
# Step :  67
# Step  67 Robot 1 Task left:  []
# Step :  67
# Step  67 Robot 2 Task left:  []
# Step :  67
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  67 Robot 0 Task left:  ['w35']
# Step  67 Robot 1 Task left:  []
# Step  67 Robot 2 Task left:  []
# Step  67 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step :  68
# Step  68 Robot 0 Task left:  ['w35']
# Step :  68
# Step  68 Robot 1 Task left:  []
# Step :  68
# Step  68 Robot 2 Task left:  []
# Step :  68
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  68 Robot 0 Task left:  ['w35']
# Step  68 Robot 1 Task left:  []
# Step  68 Robot 2 Task left:  []
# Step  68 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step :  69
# Step  69 Robot 0 Task left:  ['w35']
# Step :  69
# Step  69 Robot 1 Task left:  []
# Step :  69
# Step  69 Robot 2 Task left:  []
# Step :  69
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  69 Robot 0 Task left:  ['w35']
# Step  69 Robot 1 Task left:  []
# Step  69 Robot 2 Task left:  []
# Step  69 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step :  70
# Step  70 Robot 0 Task left:  ['w35']
# Step :  70
# Step  70 Robot 1 Task left:  []
# Step :  70
# Step  70 Robot 2 Task left:  []
# Step :  70
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  70 Robot 0 Task left:  ['w35']
# Step  70 Robot 1 Task left:  []
# Step  70 Robot 2 Task left:  []
# Step  70 Robot 3 Task left:  []
# Step  71 Robot 0 Task left:  ['w35']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 2 Task left:  []
# Step  71 Robot 3 Task left:  []
# Step  71 Robot 0 Task left:  ['w35']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 2 Task left:  []
# Step  71 Robot 3 Task left:  []
# Step  71 Robot 0 Task left:  ['w35']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 2 Task left:  []
# Step  71 Robot 3 Task left:  []
# Step  71 Robot 0 Task left:  ['w35']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 2 Task left:  []
# Step  71 Robot 3 Task left:  []
# Step  71 Robot 0 Task left:  ['w35']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 2 Task left:  []
# Step  71 Robot 3 Task left:  []
# Step :  71
# task  ['G', '57', '60', 'w35', '1', 'col'] has been done by robot  0
# The tasks left  []
# Step  71 Robot 0 Task left:  []
# Step :  71
# Step  71 Robot 1 Task left:  []
# Step :  71
# Step  71 Robot 2 Task left:  []
# Step :  71
# Step  71 Robot 3 Task left:  []
