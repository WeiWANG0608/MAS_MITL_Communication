# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Initial the environment
Get the number robots: num_agent_heavy, num_agent_light
Get the size of the work region: region_row, region_col
Get the whole map with obstacles: 2*(N/2) work regions, obs_percentage, obs_list
Get the map and state space of the env: map_original, map_obstacle, states_original
Get the map and state space of work regions for each heavy-duty robot: work_region, map_work_region, states_work_region
Get initial position of all robots: agents_heavy, agents_light
"""
num_agent_heavy = random.choice([2,4,6])
num_agent_light = 1
region_row, region_col = [random.randint(10, 15), random.randint(10, 15)]
map_row, map_col = [region_row * 2, int(region_col * (num_agent_heavy / 2))]
obs_percentage = 10
obs_list = initial_env(region_row * 2, region_col * (num_agent_heavy / 2), obs_percentage)
map_original = np.zeros((map_row, map_col), dtype=int)
map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs_list)):
    map_obstacle[obs_list[i][0]][obs_list[i][1]] = 1
states_original = total_states(map_obstacle)
work_region = initial_work_region(num_agent_heavy, region_row, region_col)
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

agents_heavy, [agents_light] = initial_agents(work_region, obs_list, num_agent_heavy, num_agent_light)
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)

# get the MITL task specification
specifications = initial_specification(obs_list, agents_heavy, agents_light, work_region, states_work_region)
for i in range(num_agent_heavy):
    print("MITL Specification of R", i+1, ": ", specifications[i])

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [[5, 10], [10, 14], [21, 16], [20, 0]] . Init light_duty agent:  [7, 4]
# MITL Specification of R 1 :  [['E', '26', '27', 'w68', 'R3', 'meet'], ['E', '46', '47', 'w134'], ['E', '97', '106', 'w112']]
# MITL Specification of R 2 :  [['E', '23', '30', 'w89', 'R0', 'meet'], ['G', '64', '65', 'w22']]
# MITL Specification of R 3 :  [['E', '40', '42', 'w47', 'R3', 'col'], ['E', '62', '66', 'w6'], ['E', '107', '110', 'w131']]
# MITL Specification of R 4 :  [['E', '25', '27', 'w21', 'R0', 'meet'], ['G', '72', '80', 'w130']]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 2
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2] - 2 * r_0) + h_a) * v_heavy) /
    ((2 * r_0) - h_a)) for i in range(num_agent_heavy)])

# %%
"""
--------------- Mission decomposition ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = [[] for i in range(num_agent_heavy)]
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w65
# The initial position is  w65
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 143
# Edge in WTS:  633
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 65
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w65, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w42, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w30, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w18, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w17, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w16, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w15, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w14, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w12, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w11, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w10, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w21, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w33, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w45, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w56, l0, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w56, l0, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=27, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=28, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=29, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=30, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l1, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w79, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w90, l0, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w102, l0, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w111, l0, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w123, l0, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=74, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=75, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=76, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=77, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=78, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=79, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=80, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=81, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=82, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=83, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=84, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=85, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=86, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=87, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=88, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=89, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=90, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=91, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=92, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=93, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w134, l2, w=94, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w123, l0, w=95, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w111, l0, w=96, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w112, l3, w=97, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# The initial position is  w110
# The initial position is  w110
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 138
# Edge in WTS:  590
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 110
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w110, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w99, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w78, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w67, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w32, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w31, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w31, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w43, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w66, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w77, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w87, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=30, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=31, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=32, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=33, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=34, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=35, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=36, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=37, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=38, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=39, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=40, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=41, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=45, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=46, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w68, l0, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w57, l0, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w45, l0, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w23, l0, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w22, l2, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w22, l2, w=65, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# The initial position is  w77
# The initial position is  w77
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R2
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoR2.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 138
# Edge in WTS:  580
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 77
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w77, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w66, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w55, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w35, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w14, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=30, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=31, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w1, l0, w=32, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w13, l0, w=33, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w24, l0, w=34, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=35, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w26, l0, w=36, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w27, l0, w=37, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=38, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w37, l0, w=39, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=40, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=41, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=47, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=48, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=49, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=50, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=51, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=52, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=53, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=54, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=55, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=56, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=57, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=58, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=59, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l1, w=60, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=61, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w37, l0, w=62, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=63, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w17, l0, w=64, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=65, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=74, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=75, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=76, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=77, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=78, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=79, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=80, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=81, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=82, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=83, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=84, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=85, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=86, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=87, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=88, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=89, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=90, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w6, l2, w=91, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w5, l0, w=92, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w4, l0, w=93, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w3, l0, w=94, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w2, l0, w=95, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w14, l0, w=96, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w25, l0, w=97, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w35, l0, w=98, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=99, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w55, l0, w=100, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w66, l0, w=101, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w77, l0, w=102, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w88, l0, w=103, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w97, l0, w=104, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w108, l0, w=105, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w120, l0, w=106, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w131, l3, w=107, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# The initial position is  w66
# The initial position is  w66
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 143
# Edge in WTS:  627
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 66
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w66, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# ...
#
# (w44, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l1, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l1, w=26, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w21, l1, w=27, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=51, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=52, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=53, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w21, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w66, l0, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w67, l0, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w78, l0, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w90, l0, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w102, l0, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w113, l0, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w123, l0, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w124, l0, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w125, l0, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w126, l0, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w128, l0, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w129, l0, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w130, l2, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w130, l2, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w130, l2, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w130, l2, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w130, l2, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w130, l2, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w130, l2, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# (w130, l2, w=79, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=7)
#
# (w130, l2, w=80, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=8)
#
# The initial position is  w66
# The initial position is  w66
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 143
# Edge in WTS:  627
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 66
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w66, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l1, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l1, w=26, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w21, l1, w=27, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=37, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=38, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=39, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=40, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w0, l0, w=51, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=52, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w11, l0, w=53, veri1=1, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w21, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w54, l0, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w66, l0, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w67, l0, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w78, l0, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w79, l0, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w90, l0, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w102, l0, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w113, l0, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w123, l0, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w124, l0, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w125, l0, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w126, l0, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w128, l0, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w129, l0, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w130, l2, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w130, l2, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w130, l2, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w130, l2, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w130, l2, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w130, l2, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w130, l2, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# (w130, l2, w=79, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=7)
#
# (w130, l2, w=80, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=8)

# %%
# save all the info of Mission Decomposition
info = ''
for i in range(num_agent_heavy):
    info = info + str(agents_heavy[i])+';' + ','.join(str(j) for j in specifications[i]) + ';' + ','.join(
        str(j) for j in independent_task[i]) + ';' + ','.join(str(j) for j in independent_request[i]) + '&'
text_file = open(file_folder + "/" + 'initialization_info' + ".txt", "w")
text_file.write(info)
text_file.close()

# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['E', '26', '27', 'w68', 'R3', 'meet'], ['E', '46', '47', 'w134'], ['E', '97', '106', 'w112']], [['E', '23', '30', 'w89', 'R0', 'meet'], ['G', '64', '65', 'w22']], [['E', '40', '42', 'w47', 'R3', 'col'], ['E', '62', '66', 'w6'], ['E', '107', '110', 'w131']], [['E', '25', '27', 'w21', 'R0', 'meet'], ['G', '72', '80', 'w130']]]
# ------------ If all the paths exist ------------
# [True, True, True, True]
# ---- The Independent Task Specification ----
# [[['G', '26', '27', 'w68', 'R3', 'meet'], ['E', '46', '47', 'w134'], ['E', '97', '106', 'w112']], [['G', '23', '30', 'w89', 'R0', 'meet'], ['G', '64', '65', 'w22']], [['E', '62', '66', 'w6'], ['E', '107', '110', 'w131']], [['G', '25', '27', 'w21', 'R0', 'meet'], ['G', '72', '80', 'w130']]]
# --------- The Independent Request ---------
# [[[], [], [], [['E', '26', '27', 'w68', 'R3', 'meet']]], [[['E', '23', '30', 'w89', 'R0', 'meet']], [], [], []], [[], [], [], [['E', '40', '42', 'w47', 'R3', 'col']]], [[['E', '25', '27', 'w21', 'R0', 'meet']], [], [], []]]

# %%
# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, independent_task,
                   independent_request)

# %%
"""
Start two round SWEEP
"""
# start sweeping
# maximum 2 rounds to guarantee the requests exchange

num_round_exchange = 2

path_detect_round, independent_path_2d, record_working_region, record_task_left = \
    collect_deliver(world, map_obs_work, num_round_exchange, num_agent_heavy, work_region, states_work_region,
                    independent_path_2d, h_a, r_0, v_light, file_folder)
# Out:
# Round  0  Region 0
# The closest start location is  [10  2]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [2 9]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [7 4]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [8 4]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [8 3]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [9 3]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [9 2]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [10  2]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [10  3]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [10  4]
# Step  1 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  1 Robot 1 Task left:  ['w89', 'w22']
# Step  1 Robot 2 Task left:  ['w6', 'w131']
# Step  1 Robot 3 Task left:  ['w21', 'w130']
# Step :  1 Light:  [10, 5] Heavy 0 :  [4, 10] Distance is:  11
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [10  5]
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [10  6]
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [10  7]
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [10  8]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [10  9]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [9 9]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [8 9]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [8 8]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [8 7]
# Step  2 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  2 Robot 1 Task left:  ['w89', 'w22']
# Step  2 Robot 2 Task left:  ['w6', 'w131']
# Step  2 Robot 3 Task left:  ['w21', 'w130']
# Step :  2 Light:  [8, 6] Heavy 0 :  [3, 10] Distance is:  9
# Step  2 Robot 0 Pos [3, 10] R0 pos:  [8 6]
# Step  2 Robot 0 Pos [3, 10] R0 pos:  [8 5]
# Step  2 Robot 0 Pos [3, 10] R0 pos:  [8 4]
# Step  2 Robot 0 Pos [3, 10] R0 pos:  [8 3]
# Step  3 Robot 0 Pos [3, 10] R0 pos:  [8 2]
# Step  3 Robot 0 Pos [3, 10] R0 pos:  [7 2]
# Step  3 Robot 0 Pos [3, 10] R0 pos:  [6 2]
# Step  3 Robot 0 Pos [3, 10] R0 pos:  [6 3]
# Step  3 Robot 0 Pos [3, 10] R0 pos:  [6 4]
# Step  3 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  3 Robot 1 Task left:  ['w89', 'w22']
# Step  3 Robot 2 Task left:  ['w6', 'w131']
# Step  3 Robot 3 Task left:  ['w21', 'w130']
# Step :  3 Light:  [6, 5] Heavy 0 :  [2, 10] Distance is:  9
# Step  3 Robot 0 Pos [2, 10] R0 pos:  [6 5]
# Step  3 Robot 0 Pos [2, 10] R0 pos:  [6 6]
# Step  3 Robot 0 Pos [2, 10] R0 pos:  [6 7]
# Step  3 Robot 0 Pos [2, 10] R0 pos:  [6 8]
# Step  4 Robot 0 Pos [2, 10] R0 pos:  [6 9]
# Step  4 Robot 0 Pos [2, 10] R0 pos:  [5 9]
# len() 1
# kl:  0
# The heavy duty agent  0  is detected at step:  3 . Pos_heavy:  [2, 10] . Pos_light:  [4, 9] . Distance is:  3
# Stop sweep at Region 1  at position  [4 9]
# The closest start location is  [ 2 15]
# Step  4 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  4 Robot 1 Task left:  ['w89', 'w22']
# Step  4 Robot 2 Task left:  ['w6', 'w131']
# Step  4 Robot 3 Task left:  ['w21', 'w130']
# Step :  4 Light:  [4, 11] Heavy  1 :  [6, 14] Distance is:  5
# i:  1  ii:  1 j:  3 len(path_sweep) 4 len(path_sweep[ii]) 1
# The heavy duty agent  1  is detected at step:  4 . Pos_heavy:  [6, 14] . Pos_light:  [0, 0] . Distance is:  20
# Round  0  Region 2
# The closest start location is  [16 15]
# Step  4 Robot 2 Pos [17, 16] R0 pos:  [24 22]
# Step  4 Robot 2 Pos [17, 16] R0 pos:  [ 4 12]
# Step  4 Robot 2 Pos [17, 16] R0 pos:  [ 5 12]
# Step  5 Robot 2 Pos [17, 16] R0 pos:  [ 6 12]
# Step  5 Robot 2 Pos [17, 16] R0 pos:  [ 7 12]
# Step  5 Robot 2 Pos [17, 16] R0 pos:  [ 8 12]
# Step  5 Robot 2 Pos [17, 16] R0 pos:  [ 9 12]
# Step  5 Robot 2 Pos [17, 16] R0 pos:  [10 12]
# Step  5 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  5 Robot 1 Task left:  ['w89', 'w22']
# Step  5 Robot 2 Task left:  ['w6', 'w131']
# Step  5 Robot 3 Task left:  ['w21', 'w130']
# Step :  5 Light:  [11, 12] Heavy 2 :  [16, 16] Distance is:  9
# Step  5 Robot 2 Pos [16, 16] R0 pos:  [11 12]
# Step  5 Robot 2 Pos [16, 16] R0 pos:  [12 12]
# Step  5 Robot 2 Pos [16, 16] R0 pos:  [13 12]
# Step  5 Robot 2 Pos [16, 16] R0 pos:  [13 13]
# Step  6 Robot 2 Pos [16, 16] R0 pos:  [14 13]
# len() 1
# kl:  0
# The heavy duty agent  2  is detected at step:  5 . Pos_heavy:  [16, 16] . Pos_light:  [14, 14] . Distance is:  4
# Stop sweep at Region 3  at position  [14 14]
# The closest start location is  [16  9]
# Step  6 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  6 Robot 1 Task left:  ['w89', 'w22']
# Step  6 Robot 2 Task left:  ['w6', 'w131']
# Step  6 Robot 3 Task left:  ['w21', 'w130']
# Step :  6 Light:  [14, 11] Heavy  3 :  [18, 0] Distance is:  15
# Round  0  Region 3
# The closest start location is  [16  9]
# Step  6 Robot 3 Pos [18, 0] R0 pos:  [24  2]
# Step  7 Robot 3 Pos [18, 0] R0 pos:  [15  9]
# Step  7 Robot 3 Pos [18, 0] R0 pos:  [16  9]
# Step  7 Robot 3 Pos [18, 0] R0 pos:  [16  8]
# Step  7 Robot 3 Pos [18, 0] R0 pos:  [16  7]
# Step  7 Robot 3 Pos [18, 0] R0 pos:  [16  6]
# Step  7 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  7 Robot 1 Task left:  ['w89', 'w22']
# Step  7 Robot 2 Task left:  ['w6', 'w131']
# Step  7 Robot 3 Task left:  ['w21', 'w130']
# Step :  7 Light:  [16, 5] Heavy 3 :  [17, 0] Distance is:  6
# Step  7 Robot 3 Pos [17, 0] R0 pos:  [16  5]
# Step  7 Robot 3 Pos [17, 0] R0 pos:  [16  4]
# Step  7 Robot 3 Pos [17, 0] R0 pos:  [16  3]
# len() 1
# kl:  0
# The heavy duty agent  3  is detected at step:  7 . Pos_heavy:  [17, 0] . Pos_light:  [16, 2] . Distance is:  3
# Stop sweep at Region 4  at position  [16  2]
# The closest start location is  [10  2]
# Step  8 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  8 Robot 1 Task left:  ['w89', 'w22']
# Step  8 Robot 2 Task left:  ['w6', 'w131']
# Step  8 Robot 3 Task left:  ['w21', 'w130']
# Step :  8 Light:  [11, 2] Heavy  4 :  [1, 10] Distance is:  18
# Round  1  Region 0
# The closest start location is  [10  2]
# Step  8 Robot 0 Pos [1, 10] R0 pos:  [2 9]
# Step  8 Robot 0 Pos [1, 10] R0 pos:  [11  2]
# Step  8 Robot 0 Pos [1, 10] R0 pos:  [10  2]
# Step  8 Robot 0 Pos [1, 10] R0 pos:  [10  3]
# Step  9 Robot 0 Pos [1, 10] R0 pos:  [10  4]
# Step  9 Robot 0 Pos [1, 10] R0 pos:  [10  5]
# Step  9 Robot 0 Pos [1, 10] R0 pos:  [10  6]
# Step  9 Robot 0 Pos [1, 10] R0 pos:  [10  7]
# Step  9 Robot 0 Pos [1, 10] R0 pos:  [10  8]
# Step  9 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  9 Robot 1 Task left:  ['w89', 'w22']
# Step  9 Robot 2 Task left:  ['w6', 'w131']
# Step  9 Robot 3 Task left:  ['w21', 'w130']
# Step :  9 Light:  [10, 9] Heavy 0 :  [0, 10] Distance is:  11
# Step  9 Robot 0 Pos [0, 10] R0 pos:  [10  9]
# Step  9 Robot 0 Pos [0, 10] R0 pos:  [9 9]
# Step  9 Robot 0 Pos [0, 10] R0 pos:  [8 9]
# Step  9 Robot 0 Pos [0, 10] R0 pos:  [8 8]
# Step  10 Robot 0 Pos [0, 10] R0 pos:  [8 7]
# Step  10 Robot 0 Pos [0, 10] R0 pos:  [8 6]
# Step  10 Robot 0 Pos [0, 10] R0 pos:  [8 5]
# Step  10 Robot 0 Pos [0, 10] R0 pos:  [8 4]
# Step  10 Robot 0 Pos [0, 10] R0 pos:  [8 3]
# Step  10 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  10 Robot 1 Task left:  ['w89', 'w22']
# Step  10 Robot 2 Task left:  ['w6', 'w131']
# Step  10 Robot 3 Task left:  ['w21', 'w130']
# Step :  10 Light:  [8, 2] Heavy 0 :  [1, 10] Distance is:  15
# Step  10 Robot 0 Pos [1, 10] R0 pos:  [8 2]
# Step  10 Robot 0 Pos [1, 10] R0 pos:  [7 2]
# Step  10 Robot 0 Pos [1, 10] R0 pos:  [6 2]
# Step  10 Robot 0 Pos [1, 10] R0 pos:  [6 3]
# Step  11 Robot 0 Pos [1, 10] R0 pos:  [6 4]
# Step  11 Robot 0 Pos [1, 10] R0 pos:  [6 5]
# Step  11 Robot 0 Pos [1, 10] R0 pos:  [6 6]
# Step  11 Robot 0 Pos [1, 10] R0 pos:  [6 7]
# Step  11 Robot 0 Pos [1, 10] R0 pos:  [6 8]
# Step  11 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  11 Robot 1 Task left:  ['w89', 'w22']
# Step  11 Robot 2 Task left:  ['w6', 'w131']
# Step  11 Robot 3 Task left:  ['w21', 'w130']
# Step :  11 Light:  [6, 9] Heavy 0 :  [0, 10] Distance is:  7
# Step  11 Robot 0 Pos [0, 10] R0 pos:  [6 9]
# Step  11 Robot 0 Pos [0, 10] R0 pos:  [5 9]
# Step  11 Robot 0 Pos [0, 10] R0 pos:  [4 9]
# Step  11 Robot 0 Pos [0, 10] R0 pos:  [4 8]
# Step  12 Robot 0 Pos [0, 10] R0 pos:  [4 7]
# Step  12 Robot 0 Pos [0, 10] R0 pos:  [4 6]
# Step  12 Robot 0 Pos [0, 10] R0 pos:  [4 5]
# Step  12 Robot 0 Pos [0, 10] R0 pos:  [4 4]
# Step  12 Robot 0 Pos [0, 10] R0 pos:  [4 3]
# Step  12 Robot 0 Task left:  ['w68', 'w134', 'w112']
# Step  12 Robot 1 Task left:  ['w89', 'w22']
# Step  12 Robot 2 Task left:  ['w6', 'w131']
# Step  12 Robot 3 Task left:  ['w21', 'w130']
# Step :  12 Light:  [4, 2] Heavy 0 :  [1, 10] Distance is:  11
# Step  12 Robot 0 Pos [1, 10] R0 pos:  [4 2]
# Step  12 Robot 0 Pos [1, 10] R0 pos:  [3 2]
# Step  12 Robot 0 Pos [1, 10] R0 pos:  [2 2]
# Step  12 Robot 0 Pos [1, 10] R0 pos:  [2 3]
# Step  13 Robot 0 Pos [1, 10] R0 pos:  [2 4]
# Step  13 Robot 0 Pos [1, 10] R0 pos:  [2 5]
# Step  13 Robot 0 Pos [1, 10] R0 pos:  [2 6]
# Step  13 Robot 0 Pos [1, 10] R0 pos:  [2 7]
# The cooperative task is in region  [1, 3]  the needed robot is  0
# The current map contains the follow task regions  [1, 3] 0
# The new specification without time updating is  [['G', '26', '27', 'w145', 'R3', 'meet'], ['E', '46', '47', 'w280'], ['E', '97', '106', 'w238'], ['E', '23', '30', 'w205', '1', 'meet'], ['E', '25', '27', 'w360', '3', 'meet'], ['E', '23', '30', 'w205', '1', 'meet'], ['E', '25', '27', 'w360', '3', 'meet']]
# The current position before updating is  w18 after updating is  w30
# The new specification after the time update is  [['G', '13', '14', 'w145', 'R3', 'meet'], ['E', '33', '34', 'w280'], ['E', '84', '93', 'w238'], ['E', '0', '4', 'w205', '1', 'meet'], ['E', '0', '1', 'w360', '3', 'meet'], ['E', '0', '4', 'w205', '1', 'meet'], ['E', '0', '1', 'w360', '3', 'meet']]
# The initial position is  w30
# The initial position is  w30
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoCR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3,p4,np4,p5,np5,p6,np6,p7,np7;
# bool veri1,veri2,veri3,veri4,veri5,veri6,veri7;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3,cl4,cl5,cl6,cl7;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 528
# Edge in WTS:  2310
# State in TA:  8
# Edge in TA:   21
# ===== Initial State =====
# Initial state in WTS: 30
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3&&veri4&&veri5&&veri6&&veri7) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-29T13:28:32.343219194
# Tried, but cannot achieve cooperation
# The heavy duty agent  0  is detected at step:  13 . Pos_heavy:  [1, 10] . Pos_light:  [2, 8] . Distance is:  3
# Stop sweep at Region 1  at position  [2 8]
# The closest start location is  [ 2 15]
# Step  13 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  13 Robot 1 Task left:  ['w89', 'w22']
# Step  13 Robot 2 Task left:  ['w6', 'w131']
# Step  13 Robot 3 Task left:  ['w21', 'w130']
# Step :  13 Light:  [2, 8] Heavy  1 :  [0, 13] Distance is:  7
# i:  1  ii:  1 j:  3 len(path_sweep) 4 len(path_sweep[ii]) 1
# The heavy duty agent  1  is detected at step:  13 . Pos_heavy:  [0, 13] . Pos_light:  [0, 0] . Distance is:  13
# Round  1  Region 2
# The closest start location is  [16 15]
# Step  13 Robot 2 Pos [15, 15] R0 pos:  [24 22]
# Step  14 Robot 2 Pos [15, 15] R0 pos:  [ 2 11]
# Step  14 Robot 2 Pos [15, 15] R0 pos:  [ 3 11]
# Step  14 Robot 2 Pos [15, 15] R0 pos:  [ 4 11]
# Step  14 Robot 2 Pos [15, 15] R0 pos:  [ 5 11]
# Step  14 Robot 2 Pos [15, 15] R0 pos:  [ 6 11]
# Step  14 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  14 Robot 1 Task left:  ['w89', 'w22']
# Step  14 Robot 2 Task left:  ['w6', 'w131']
# Step  14 Robot 3 Task left:  ['w21', 'w130']
# Step :  14 Light:  [7, 11] Heavy 2 :  [14, 15] Distance is:  11
# Step  14 Robot 2 Pos [14, 15] R0 pos:  [ 7 11]
# Step  14 Robot 2 Pos [14, 15] R0 pos:  [ 8 11]
# Step  14 Robot 2 Pos [14, 15] R0 pos:  [ 9 11]
# Step  14 Robot 2 Pos [14, 15] R0 pos:  [10 11]
# Step  15 Robot 2 Pos [14, 15] R0 pos:  [11 11]
# Step  15 Robot 2 Pos [14, 15] R0 pos:  [12 11]
# Step  15 Robot 2 Pos [14, 15] R0 pos:  [12 12]
# Step  15 Robot 2 Pos [14, 15] R0 pos:  [13 12]
# The heavy duty agent  2  is detected at step:  15 . Pos_heavy:  [14, 15] . Pos_light:  [13, 13] . Distance is:  3
# Stop sweep at Region 3  at position  [13 13]
# The closest start location is  [16  9]
# Step  15 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  15 Robot 1 Task left:  ['w89', 'w22']
# Step  15 Robot 2 Task left:  ['w6', 'w131']
# Step  15 Robot 3 Task left:  ['w21', 'w130']
# Step :  15 Light:  [13, 13] Heavy  3 :  [17, 0] Distance is:  17
# Round  1  Region 3
# The closest start location is  [16  9]
# Step  16 Robot 3 Pos [17, 0] R0 pos:  [24  2]
# Step  16 Robot 3 Pos [17, 0] R0 pos:  [15  9]
# Step  16 Robot 3 Pos [17, 0] R0 pos:  [16  9]
# Step  16 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  16 Robot 1 Task left:  ['w89', 'w22']
# Step  16 Robot 2 Task left:  ['w6', 'w131']
# Step  16 Robot 3 Task left:  ['w21', 'w130']
# Step :  16 Light:  [16, 8] Heavy 3 :  [18, 0] Distance is:  10
# Step  16 Robot 3 Pos [18, 0] R0 pos:  [16  8]
# Step  16 Robot 3 Pos [18, 0] R0 pos:  [16  7]
# Step  16 Robot 3 Pos [18, 0] R0 pos:  [16  6]
# Step  16 Robot 3 Pos [18, 0] R0 pos:  [16  5]
# Step  17 Robot 3 Pos [18, 0] R0 pos:  [16  4]
# Step  17 Robot 3 Pos [18, 0] R0 pos:  [16  3]
# The cooperative task is in region  [0, 2]  the needed robot is  3
# The current map contains the follow task regions  [0, 2] 3
# The new specification without time updating is  [['G', '25', '27', 'w233', 'R0', 'meet'], ['G', '72', '80', 'w454'], ['E', '26', '27', 'w37', '0', 'meet'], ['E', '40', '42', 'w295', '2', 'col'], ['E', '26', '27', 'w37', '0', 'meet'], ['E', '40', '42', 'w295', '2', 'col']]
# The current position before updating is  w44 after updating is  w280
# The new specification after the time update is  [['G', '8', '10', 'w233', 'R0', 'meet'], ['G', '55', '63', 'w454'], ['E', '6', '8', 'w295', '2', 'col'], ['E', '6', '8', 'w295', '2', 'col']]
# The initial position is  w280
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# The initial position is  w280
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-29/system_infoCR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3,p4,np4;
# bool veri1,veri2,veri3,veri4;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3,cl4;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 517
# Edge in WTS:  2283
# State in TA:  5
# Edge in TA:   12
# ===== Initial State =====
# Initial state in WTS: 280
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3&&veri4) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-29T13:28:52.560925577
# Tried, but cannot achieve cooperation
# The heavy duty agent  3  is detected at step:  16 . Pos_heavy:  [18, 0] . Pos_light:  [16, 2] . Distance is:  4
# Stop sweep at Region 4  at position  [16  2]
# The closest start location is  [10  2]
# Step  17 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  17 Robot 1 Task left:  ['w89', 'w22']
# Step  17 Robot 2 Task left:  ['w6', 'w131']
# Step  17 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  17 Light:  [14, 2] Heavy  4 :  [1, 5] Distance is:  16
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)

# %%
"""
Path of agile light-duty robot
"""
path_detect_round[1] = path_detect_round[1][len(path_detect_round[0]): len(path_detect_round[1])]
for n in range(len(path_detect_round)):
    mm = copy.deepcopy(map_original)
    draw_path(mm, path_detect_round[n], fig_folder, "Trajectory of R0 Round " + str(n + 1))

# %%
"""
Get the data ready for plot and video
"""

independent_path_2d, record_working_region, record_task_left = \
    complete_path(world, v_light, independent_path_2d, states_work_region, record_working_region, record_task_left)

record_path_all = world.agents_light.path
for i in range(num_agent_heavy):
    record_path_all = np.concatenate((record_path_all, world.agents_heavy[i].path), axis=1)
    draw_path(map_obs_work, independent_path_2d[i], fig_folder, "Trajectory of heavy-duty robot R" + str(i + 1))

st = len(record_working_region[0])
for i in range(st, len(record_path_all)):
    for j in range(num_agent_heavy):
        record_working_region[j].append(record_working_region[j][-1])
        record_task_left[j].append(record_task_left[j][-1])

# animate_solution(map_obs_work, record_path_all, record_working_region, record_task_left, r_0, r_i, v_light,
#                  fig_folder, video=True)
# Out:
# The current step is  18
# The current positions are [array([1, 5]), array([ 4, 13]), array([15, 15]), array([17,  0])]
# Step  18 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  18 Robot 1 Task left:  ['w89', 'w22']
# Step  18 Robot 2 Task left:  ['w6', 'w131']
# Step  18 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  18 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  18 Robot 1 Task left:  ['w89', 'w22']
# Step  18 Robot 2 Task left:  ['w6', 'w131']
# Step  18 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  18 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  18 Robot 1 Task left:  ['w89', 'w22']
# Step  18 Robot 2 Task left:  ['w6', 'w131']
# Step  18 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  18 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  18 Robot 1 Task left:  ['w89', 'w22']
# Step  18 Robot 2 Task left:  ['w6', 'w131']
# Step  18 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  19
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  19
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step :  19
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step :  19
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  19 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  19 Robot 1 Task left:  ['w89', 'w22']
# Step  19 Robot 2 Task left:  ['w6', 'w131']
# Step  19 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  20
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  20
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step :  20
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step :  20
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  20 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  20 Robot 1 Task left:  ['w89', 'w22']
# Step  20 Robot 2 Task left:  ['w6', 'w131']
# Step  20 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  21
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  21
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step :  21
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step :  21
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  21 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  21 Robot 1 Task left:  ['w89', 'w22']
# Step  21 Robot 2 Task left:  ['w6', 'w131']
# Step  21 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  22
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  22
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step :  22
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step :  22
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  22 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  22 Robot 1 Task left:  ['w89', 'w22']
# Step  22 Robot 2 Task left:  ['w6', 'w131']
# Step  22 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  23
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  23
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step :  23
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step :  23
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  23 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  23 Robot 1 Task left:  ['w89', 'w22']
# Step  23 Robot 2 Task left:  ['w6', 'w131']
# Step  23 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  24
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  24
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step :  24
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step :  24
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  24 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  24 Robot 1 Task left:  ['w89', 'w22']
# Step  24 Robot 2 Task left:  ['w6', 'w131']
# Step  24 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  25
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  25
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step :  25
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step :  25
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  25 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  25 Robot 1 Task left:  ['w89', 'w22']
# Step  25 Robot 2 Task left:  ['w6', 'w131']
# Step  25 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  26
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  26
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step :  26
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step :  26
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  26 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  26 Robot 1 Task left:  ['w89', 'w22']
# Step  26 Robot 2 Task left:  ['w6', 'w131']
# Step  26 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  27
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  27
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step :  27
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step :  27
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  27 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  27 Robot 1 Task left:  ['w89', 'w22']
# Step  27 Robot 2 Task left:  ['w6', 'w131']
# Step  27 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w145', 'w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w233', 'w454', 'w295', 'w295']
# Step :  28
# task  ['G', '13', '14', 'w145', 'R3', 'meet'] has been done by robot  0
# The tasks left  [['E', '33', '34', 'w280'], ['E', '84', '93', 'w238'], ['E', '0', '4', 'w205', '1', 'meet'], ['E', '0', '1', 'w360', '3', 'meet'], ['E', '0', '4', 'w205', '1', 'meet'], ['E', '0', '1', 'w360', '3', 'meet']]
# Step  28 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  28
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step :  28
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step :  28
# task  ['G', '8', '10', 'w233', 'R0', 'meet'] has been done by robot  3
# The tasks left  [['G', '55', '63', 'w454'], ['E', '6', '8', 'w295', '2', 'col'], ['E', '6', '8', 'w295', '2', 'col']]
# Step  28 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  28 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  28 Robot 1 Task left:  ['w89', 'w22']
# Step  28 Robot 2 Task left:  ['w6', 'w131']
# Step  28 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  29
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  29
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step :  29
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step :  29
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  29 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  29 Robot 1 Task left:  ['w89', 'w22']
# Step  29 Robot 2 Task left:  ['w6', 'w131']
# Step  29 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  30
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  30
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step :  30
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step :  30
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  30 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  30 Robot 1 Task left:  ['w89', 'w22']
# Step  30 Robot 2 Task left:  ['w6', 'w131']
# Step  30 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w89', 'w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w89', 'w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w89', 'w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w89', 'w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  31
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  31
# task  ['G', '23', '30', 'w89', 'R0', 'meet'] has been done by robot  1
# The tasks left  [['G', '64', '65', 'w22']]
# Step  31 Robot 1 Task left:  ['w22']
# Step :  31
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step :  31
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  31 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  31 Robot 1 Task left:  ['w22']
# Step  31 Robot 2 Task left:  ['w6', 'w131']
# Step  31 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  32
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  32
# Step  32 Robot 1 Task left:  ['w22']
# Step :  32
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step :  32
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  32 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  32 Robot 1 Task left:  ['w22']
# Step  32 Robot 2 Task left:  ['w6', 'w131']
# Step  32 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  33
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  33
# Step  33 Robot 1 Task left:  ['w22']
# Step :  33
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step :  33
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  33 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  33 Robot 1 Task left:  ['w22']
# Step  33 Robot 2 Task left:  ['w6', 'w131']
# Step  33 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  34
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  34
# Step  34 Robot 1 Task left:  ['w22']
# Step :  34
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step :  34
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  34 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  34 Robot 1 Task left:  ['w22']
# Step  34 Robot 2 Task left:  ['w6', 'w131']
# Step  34 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  35
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  35
# Step  35 Robot 1 Task left:  ['w22']
# Step :  35
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step :  35
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  35 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  35 Robot 1 Task left:  ['w22']
# Step  35 Robot 2 Task left:  ['w6', 'w131']
# Step  35 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  36
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  36
# Step  36 Robot 1 Task left:  ['w22']
# Step :  36
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step :  36
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  36 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  36 Robot 1 Task left:  ['w22']
# Step  36 Robot 2 Task left:  ['w6', 'w131']
# Step  36 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  37
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  37
# Step  37 Robot 1 Task left:  ['w22']
# Step :  37
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step :  37
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  37 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  37 Robot 1 Task left:  ['w22']
# Step  37 Robot 2 Task left:  ['w6', 'w131']
# Step  37 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  38
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  38
# Step  38 Robot 1 Task left:  ['w22']
# Step :  38
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step :  38
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  38 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  38 Robot 1 Task left:  ['w22']
# Step  38 Robot 2 Task left:  ['w6', 'w131']
# Step  38 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  39
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  39
# Step  39 Robot 1 Task left:  ['w22']
# Step :  39
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step :  39
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  39 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  39 Robot 1 Task left:  ['w22']
# Step  39 Robot 2 Task left:  ['w6', 'w131']
# Step  39 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  40
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  40
# Step  40 Robot 1 Task left:  ['w22']
# Step :  40
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step :  40
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  40 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  40 Robot 1 Task left:  ['w22']
# Step  40 Robot 2 Task left:  ['w6', 'w131']
# Step  40 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  41 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  41 Robot 1 Task left:  ['w22']
# Step  41 Robot 2 Task left:  ['w6', 'w131']
# Step  41 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  41 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  41 Robot 1 Task left:  ['w22']
# Step  41 Robot 2 Task left:  ['w6', 'w131']
# Step  41 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  41 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  41 Robot 1 Task left:  ['w22']
# Step  41 Robot 2 Task left:  ['w6', 'w131']
# Step  41 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step  41 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step  41 Robot 1 Task left:  ['w22']
# Step  41 Robot 2 Task left:  ['w6', 'w131']
# Step  41 Robot 3 Task left:  ['w454', 'w295', 'w295']
# Step :  41
# Step  41 Robot 0 Task left:  ['w280', 'w238', 'w205', 'w360', 'w205', 'w360']
# Step :  41
# Step  41 Robot 1 Task left:  ['w22']
# Step :  41
# Step  41 Robot 2 Task left:  ['w6', 'w131']
# Step :  41
# ...
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step :  99
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  99
# Step  99 Robot 1 Task left:  []
# Step :  99
# Step  99 Robot 2 Task left:  ['w131']
# Step :  99
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  99 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  99 Robot 1 Task left:  []
# Step  99 Robot 2 Task left:  ['w131']
# Step  99 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step :  100
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  100
# Step  100 Robot 1 Task left:  []
# Step :  100
# Step  100 Robot 2 Task left:  ['w131']
# Step :  100
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  100 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  100 Robot 1 Task left:  []
# Step  100 Robot 2 Task left:  ['w131']
# Step  100 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step :  101
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  101
# Step  101 Robot 1 Task left:  []
# Step :  101
# Step  101 Robot 2 Task left:  ['w131']
# Step :  101
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  101 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  101 Robot 1 Task left:  []
# Step  101 Robot 2 Task left:  ['w131']
# Step  101 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step :  102
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  102
# Step  102 Robot 1 Task left:  []
# Step :  102
# Step  102 Robot 2 Task left:  ['w131']
# Step :  102
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  102 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  102 Robot 1 Task left:  []
# Step  102 Robot 2 Task left:  ['w131']
# Step  102 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step :  103
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  103
# Step  103 Robot 1 Task left:  []
# Step :  103
# Step  103 Robot 2 Task left:  ['w131']
# Step :  103
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  103 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  103 Robot 1 Task left:  []
# Step  103 Robot 2 Task left:  ['w131']
# Step  103 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step :  104
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  104
# Step  104 Robot 1 Task left:  []
# Step :  104
# Step  104 Robot 2 Task left:  ['w131']
# Step :  104
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  104 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  104 Robot 1 Task left:  []
# Step  104 Robot 2 Task left:  ['w131']
# Step  104 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step :  105
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  105
# Step  105 Robot 1 Task left:  []
# Step :  105
# Step  105 Robot 2 Task left:  ['w131']
# Step :  105
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  105 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  105 Robot 1 Task left:  []
# Step  105 Robot 2 Task left:  ['w131']
# Step  105 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step :  106
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  106
# Step  106 Robot 1 Task left:  []
# Step :  106
# Step  106 Robot 2 Task left:  ['w131']
# Step :  106
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  106 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  106 Robot 1 Task left:  []
# Step  106 Robot 2 Task left:  ['w131']
# Step  106 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step :  107
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  107
# Step  107 Robot 1 Task left:  []
# Step :  107
# Step  107 Robot 2 Task left:  ['w131']
# Step :  107
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  107 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  107 Robot 1 Task left:  []
# Step  107 Robot 2 Task left:  ['w131']
# Step  107 Robot 3 Task left:  ['w295', 'w295']
# Step  108 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  108 Robot 1 Task left:  []
# Step  108 Robot 2 Task left:  ['w131']
# Step  108 Robot 3 Task left:  ['w295', 'w295']
# Step  108 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  108 Robot 1 Task left:  []
# Step  108 Robot 2 Task left:  ['w131']
# Step  108 Robot 3 Task left:  ['w295', 'w295']
# Step  108 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  108 Robot 1 Task left:  []
# Step  108 Robot 2 Task left:  ['w131']
# Step  108 Robot 3 Task left:  ['w295', 'w295']
# Step  108 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step  108 Robot 1 Task left:  []
# Step  108 Robot 2 Task left:  ['w131']
# Step  108 Robot 3 Task left:  ['w295', 'w295']
# Step :  108
# Step  108 Robot 0 Task left:  ['w205', 'w360', 'w205', 'w360']
# Step :  108
# Step  108 Robot 1 Task left:  []
# Step :  108
# task  ['E', '107', '110', 'w131'] has been done by robot  2
# The tasks left  []
# Step  108 Robot 2 Task left:  []
# Step :  108
# Step  108 Robot 3 Task left:  ['w295', 'w295']

# %%
"As shown in CELL 14, the requests to R0 and R3 are not accepted by them."
