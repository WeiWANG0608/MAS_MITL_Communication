# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Initial the environment
Get the number robots: num_agent_heavy, num_agent_light
Get the size of the work region: region_row, region_col
Get the whole map with obstacles: 2*(N/2) work regions, obs_percentage, obs_list
Get the map and state space of the env: map_original, map_obstacle, states_original
Get the map and state space of work regions for each heavy-duty robot: work_region, map_work_region, states_work_region
Get initial position of all robots: agents_heavy, agents_light
"""
num_agent_heavy = random.choice([2,4,6])
num_agent_light = 1
region_row, region_col = [random.randint(10, 15), random.randint(10, 15)]
map_row, map_col = [region_row * 2, int(region_col * (num_agent_heavy / 2))]
obs_percentage = 10
obs_list = initial_env(region_row * 2, region_col * (num_agent_heavy / 2), obs_percentage)
map_original = np.zeros((map_row, map_col), dtype=int)
map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs_list)):
    map_obstacle[obs_list[i][0]][obs_list[i][1]] = 1
states_original = total_states(map_obstacle)
work_region = initial_work_region(num_agent_heavy, region_row, region_col)
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

agents_heavy, [agents_light] = initial_agents(work_region, obs_list, num_agent_heavy, num_agent_light)
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)

# get the MITL task specification
specifications = initial_specification(obs_list, agents_heavy, agents_light, work_region, states_work_region)
for i in range(num_agent_heavy):
    print("MITL Specification of R", i+1, ": ", specifications[i])

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [[5, 10], [6, 12], [26, 20], [23, 0]] . Init light_duty agent:  [6, 4]
# MITL Specification of R 1 :  [['E', '27', '36', 'w98'], ['E', '45', '50', 'w87']]
# MITL Specification of R 2 :  [['E', '30', '40', 'w52', 'R2', 'meet'], ['G', '62', '69', 'w48'], ['E', '70', '78', 'w54', 'R3', 'col']]
# MITL Specification of R 3 :  [['E', '8', '12', 'w49'], ['E', '43', '47', 'w54', 'R3', 'meet'], ['G', '72', '75', 'w39']]
# MITL Specification of R 4 :  [['G', '11', '15', 'w12'], ['G', '37', '42', 'w20', 'R1', 'meet']]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
u_size = 1
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 1
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2] - 2 * r_0 - u_size) + h_a) *
     v_heavy) / ((2 * r_0) - (h_a - u_size))) for i in range(num_agent_heavy)])

# %%
"""
--------------- Pre-computation ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = []
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w61
# The initial position is  w61
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 133
# Edge in WTS:  581
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 61
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w61, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w50, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w40, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w29, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w8, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w16, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w38, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w48, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w59, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w69, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w80, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=36, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=37, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=38, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=39, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=40, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=41, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w98, l1, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w89, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w87, l2, w=45, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The initial position is  w57
# The initial position is  w57
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 126
# Edge in WTS:  530
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 57
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w57, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w46, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w39, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w19, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=25, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=27, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=29, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w19, l0, w=30, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w28, l0, w=31, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w29, l0, w=32, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w30, l0, w=33, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w31, l0, w=34, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w32, l0, w=35, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w41, l0, w=36, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=37, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=38, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=39, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=47, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=48, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=49, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=50, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=51, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=52, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=53, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=54, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=55, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=56, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=57, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w52, l1, w=58, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=59, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=60, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l0, w=61, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l2, w=62, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l2, w=63, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w48, l2, w=64, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w48, l2, w=65, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w48, l2, w=66, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w48, l2, w=67, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w48, l2, w=68, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=6, ProcessTA.cl3=0)
#
# (w48, l2, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w59, l0, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w60, l0, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w61, l0, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w62, l0, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w63, l0, w=74, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w64, l0, w=75, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w53, l0, w=76, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w54, l3, w=77, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# The initial position is  w128
# The initial position is  w128
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R2
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR2.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 131
# Edge in WTS:  571
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 128
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w128, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w119, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w108, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w98, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w88, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w78, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w38, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=12, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=13, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=14, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=15, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=16, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=17, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=18, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=19, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=20, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=21, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=22, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=23, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=24, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=25, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=26, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=27, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=28, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=29, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=30, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w56, l0, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w55, l0, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w45, l0, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w34, l0, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w35, l0, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w36, l0, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w37, l0, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w38, l0, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w39, l3, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w39, l3, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=1)
#
# (w39, l3, w=74, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=2)
#
# (w39, l3, w=75, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=3)
#
# The initial position is  w87
# The initial position is  w87
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 123
# Edge in WTS:  513
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 87
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w87, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w77, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w67, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w49, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w39, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w31, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w11, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l1, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l1, w=12, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w12, l1, w=13, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w12, l1, w=14, veri1=0, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w12, l1, w=15, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w2, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w1, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=21, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=25, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=27, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w9, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w20, l2, w=37, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w20, l2, w=38, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=1)
#
# (w20, l2, w=39, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=2)
#
# (w20, l2, w=40, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=3)
#
# (w20, l2, w=41, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=4)
#
# (w20, l2, w=42, veri1=1, veri2=1, ProcessTA.cl1=4, ProcessTA.cl2=5)
#
# The spec to verify (before) is  [['G', '30', '40', 'w52', 'R2', 'meet'], ['G', '62', '69', 'w48'], ['E', '70', '78', 'w54', 'R3', 'col']]
# The initial position is  w57
# The initial position is  w57
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
# ...
# Initial state in WTS: 128
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w128, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w119, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w108, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w98, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w88, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w78, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w68, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w58, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w38, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=12, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=13, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=14, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=15, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=16, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=17, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=18, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=19, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=20, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=21, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=22, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=23, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=24, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=25, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=26, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=27, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=28, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=29, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=30, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=31, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=32, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=33, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=34, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=35, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=36, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w49, l1, w=37, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w48, l0, w=38, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w47, l0, w=39, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w57, l0, w=40, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w56, l0, w=41, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w55, l0, w=42, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=43, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w54, l2, w=44, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w54, l2, w=45, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w54, l2, w=46, veri1=1, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w54, l2, w=47, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w45, l0, w=48, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=49, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=50, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=51, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=52, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=53, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=54, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=55, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=56, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=57, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=58, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=59, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=60, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=61, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=62, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=63, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=64, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=65, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w23, l0, w=66, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w34, l0, w=67, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w35, l0, w=68, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w36, l0, w=69, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w37, l0, w=70, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w38, l0, w=71, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w39, l3, w=72, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w39, l3, w=73, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=1)
#
# (w39, l3, w=74, veri1=1, veri2=1, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=2)
#
# (w39, l3, w=75, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=3)
#
# The initial position is  w87
# The initial position is  w87
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 123
# Edge in WTS:  513
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 87
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w87, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w88, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w77, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w67, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w56, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w49, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w39, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w31, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w10, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w11, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l1, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l1, w=12, veri1=0, veri2=0, ProcessTA.cl1=1, ProcessTA.cl2=0)
#
# (w12, l1, w=13, veri1=0, veri2=0, ProcessTA.cl1=2, ProcessTA.cl2=0)
#
# (w12, l1, w=14, veri1=0, veri2=0, ProcessTA.cl1=3, ProcessTA.cl2=0)
#
# (w12, l1, w=15, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w2, l0, w=16, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w1, l0, w=17, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=19, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=21, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=23, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=25, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=27, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=29, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=31, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=33, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w10, l0, w=35, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w9, l0, w=36, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w20, l2, w=37, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=0)
#
# (w20, l2, w=38, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=1)
#
# (w20, l2, w=39, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=2)
#
# (w20, l2, w=40, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=3)
#
# (w20, l2, w=41, veri1=1, veri2=0, ProcessTA.cl1=4, ProcessTA.cl2=4)
#
# (w20, l2, w=42, veri1=1, veri2=1, ProcessTA.cl1=4, ProcessTA.cl2=5)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['E', '27', '36', 'w98'], ['E', '45', '50', 'w87']], [['E', '30', '40', 'w52', 'R2', 'meet'], ['G', '62', '69', 'w48'], ['E', '70', '78', 'w54', 'R3', 'col']], [['E', '8', '12', 'w49'], ['E', '43', '47', 'w54', 'R3', 'meet'], ['G', '72', '75', 'w39']], [['G', '11', '15', 'w12'], ['G', '37', '42', 'w20', 'R1', 'meet']]]
# ------------ If all the paths exist ------------
# [True, True, True, True]
# ---- The Independent Task Specification ----
# [[['E', '27', '36', 'w98'], ['E', '45', '50', 'w87']], [['G', '30', '40', 'w52', 'R2', 'meet'], ['G', '62', '69', 'w48']], [['E', '8', '12', 'w49'], ['G', '43', '47', 'w54', 'R3', 'meet'], ['G', '72', '75', 'w39']], [['G', '11', '15', 'w12'], ['G', '37', '42', 'w20']]]
# --------- The Independent Request ---------
# [[[], [], [], []], [[], [], [['E', '30', '40', 'w52', 'R2', 'meet']], [['E', '70', '78', 'w54', 'R3', 'col']]], [[], [], [], [['E', '43', '47', 'w54', 'R3', 'meet']]], [[], [['G', '37', '42', 'w20', 'R1', 'meet']], [], []]]

# %%
 # make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, u_size, independent_task,
                   independent_request)

# %%
"""
Start two round SWEEP
"""
# start sweeping
# maximum 2 rounds to guarantee the requests exchange
from request_exchange import collect_deliver
num_round_exchange = 2

path_detect_round, independent_path_2d, record_working_region, record_task_left = \
    collect_deliver(world, map_obs_work, num_round_exchange, num_agent_heavy, work_region, states_work_region,
                    independent_path_2d, h_a, r_0, v_light, file_folder)
# Out:
# Round  0  Region 0
# The closest start location is  [2 2]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [11  2]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [6 4]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [5 4]
# Step  0 Robot 0 Pos [ 5 10] R0 pos:  [4 4]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [4 3]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [3 3]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [3 2]
# Step  1 Robot 0 Pos [ 5 10] R0 pos:  [2 2]
# Step  1 Robot 0 Task left:  ['w98', 'w87']
# Step  1 Robot 1 Task left:  ['w52', 'w48']
# Step  1 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  1 Robot 3 Task left:  ['w12', 'w20']
# Step :  1 Light:  [2, 3] Heavy 0 :  [4, 10] Distance is:  9
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [2 3]
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [2 4]
# Step  1 Robot 0 Pos [4, 10] R0 pos:  [2 5]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [2 6]
# Step  2 Robot 0 Pos [4, 10] R0 pos:  [2 7]
# The heavy duty agent  0  is detected at step:  1 . Pos_heavy:  [4, 10] . Pos_light:  [2, 8] . Distance is:  4
# Stop sweep at Region 1  at position  [2 8]
# The closest start location is  [ 2 14]
# Step  2 Robot 0 Task left:  ['w98', 'w87']
# Step  2 Robot 1 Task left:  ['w52', 'w48']
# Step  2 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  2 Robot 3 Task left:  ['w12', 'w20']
# Step :  2 Light:  [2, 10] Heavy  1 :  [4, 12] Distance is:  4
# i:  1  ii:  1 j:  3 len(path_sweep) 4 len(path_sweep[ii]) 1
# The heavy duty agent  1  is detected at step:  2 . Pos_heavy:  [4, 12] . Pos_light:  [0, 0] . Distance is:  16
# Round  0  Region 1
# The closest start location is  [ 2 14]
# Step  2 Robot 1 Pos [4, 12] R0 pos:  [11 14]
# Step  2 Robot 1 Pos [4, 12] R0 pos:  [ 2 11]
# Step  2 Robot 1 Pos [4, 12] R0 pos:  [ 2 12]
# Step  3 Robot 1 Pos [4, 12] R0 pos:  [ 2 13]
# Step  3 Robot 1 Pos [4, 12] R0 pos:  [ 2 14]
# Step  3 Robot 1 Pos [4, 12] R0 pos:  [ 2 15]
# Step  3 Robot 1 Pos [4, 12] R0 pos:  [ 2 16]
# Step  3 Robot 0 Task left:  ['w98', 'w87']
# Step  3 Robot 1 Task left:  ['w52', 'w48']
# Step  3 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  3 Robot 3 Task left:  ['w12', 'w20']
# Step :  3 Light:  [2, 17] Heavy 1 :  [3, 12] Distance is:  6
# Step  3 Robot 1 Pos [3, 12] R0 pos:  [ 2 17]
# Step  3 Robot 1 Pos [3, 12] R0 pos:  [ 2 18]
# Step  3 Robot 1 Pos [3, 12] R0 pos:  [ 2 19]
# Step  4 Robot 1 Pos [3, 12] R0 pos:  [ 2 20]
# Step  4 Robot 1 Pos [3, 12] R0 pos:  [ 3 20]
# Step  4 Robot 1 Pos [3, 12] R0 pos:  [ 4 20]
# Step  4 Robot 1 Pos [3, 12] R0 pos:  [ 5 20]
# Step  4 Robot 1 Pos [3, 12] R0 pos:  [ 5 19]
# Step  4 Robot 0 Task left:  ['w98', 'w87']
# Step  4 Robot 1 Task left:  ['w52', 'w48']
# Step  4 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  4 Robot 3 Task left:  ['w12', 'w20']
# Step :  4 Light:  [5, 18] Heavy 1 :  [2, 12] Distance is:  9
# Step  4 Robot 1 Pos [2, 12] R0 pos:  [ 5 18]
# Step  4 Robot 1 Pos [2, 12] R0 pos:  [ 5 17]
# Step  4 Robot 1 Pos [2, 12] R0 pos:  [ 5 16]
# Step  4 Robot 1 Pos [2, 12] R0 pos:  [ 5 15]
# Step  5 Robot 1 Pos [2, 12] R0 pos:  [ 5 14]
# Step  5 Robot 1 Pos [2, 12] R0 pos:  [ 6 14]
# Step  5 Robot 1 Pos [2, 12] R0 pos:  [ 7 14]
# Step  5 Robot 1 Pos [2, 12] R0 pos:  [ 8 14]
# Step  5 Robot 0 Task left:  ['w98', 'w87']
# Step  5 Robot 1 Task left:  ['w52', 'w48']
# Step  5 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  5 Robot 3 Task left:  ['w12', 'w20']
# Step :  5 Light:  [8, 15] Heavy 1 :  [1, 12] Distance is:  10
# Step  5 Robot 1 Pos [1, 12] R0 pos:  [ 8 15]
# Step  5 Robot 1 Pos [1, 12] R0 pos:  [ 8 16]
# Step  5 Robot 1 Pos [1, 12] R0 pos:  [ 8 17]
# Step  6 Robot 1 Pos [1, 12] R0 pos:  [ 8 18]
# Step  6 Robot 1 Pos [1, 12] R0 pos:  [ 8 19]
# Step  6 Robot 1 Pos [1, 12] R0 pos:  [ 8 20]
# Step  6 Robot 1 Pos [1, 12] R0 pos:  [ 9 20]
# Step  6 Robot 1 Pos [1, 12] R0 pos:  [10 20]
# Step  6 Robot 0 Task left:  ['w98', 'w87']
# Step  6 Robot 1 Task left:  ['w52', 'w48']
# Step  6 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  6 Robot 3 Task left:  ['w12', 'w20']
# Step :  6 Light:  [11, 20] Heavy 1 :  [0, 12] Distance is:  19
# Step  6 Robot 1 Pos [0, 12] R0 pos:  [11 20]
# Step  6 Robot 1 Pos [0, 12] R0 pos:  [11 19]
# Step  6 Robot 1 Pos [0, 12] R0 pos:  [11 18]
# Step  6 Robot 1 Pos [0, 12] R0 pos:  [11 17]
# Step  7 Robot 1 Pos [0, 12] R0 pos:  [11 16]
# Step  7 Robot 1 Pos [0, 12] R0 pos:  [11 15]
# Stop sweep at Region 1  at position  [11 14]
# The closest start location is  [10 14]
# Round  0  Region 2
# The closest start location is  [16 14]
# Step  7 Robot 2 Pos [20, 20] R0 pos:  [25 14]
# Step  7 Robot 0 Task left:  ['w98', 'w87']
# Step  7 Robot 1 Task left:  ['w52', 'w48']
# Step  7 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  7 Robot 3 Task left:  ['w12', 'w20']
# Step :  7 Light:  [11, 14] Heavy 2 :  [19, 20] Distance is:  14
# Step  7 Robot 2 Pos [19, 20] R0 pos:  [11 14]
# Step  7 Robot 2 Pos [19, 20] R0 pos:  [12 14]
# Step  7 Robot 2 Pos [19, 20] R0 pos:  [13 14]
# Step  8 Robot 2 Pos [19, 20] R0 pos:  [14 14]
# Step  8 Robot 2 Pos [19, 20] R0 pos:  [15 14]
# Step  8 Robot 2 Pos [19, 20] R0 pos:  [16 14]
# Step  8 Robot 2 Pos [19, 20] R0 pos:  [16 15]
# Step  8 Robot 2 Pos [19, 20] R0 pos:  [16 16]
# Step  8 Robot 0 Task left:  ['w98', 'w87']
# Step  8 Robot 1 Task left:  ['w52', 'w48']
# Step  8 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  8 Robot 3 Task left:  ['w12', 'w20']
# Step :  8 Light:  [16, 17] Heavy 2 :  [18, 20] Distance is:  5
# Step  8 Robot 2 Pos [18, 20] R0 pos:  [16 17]
# len() 1
# kl:  0
# The heavy duty agent  2  is detected at step:  8 . Pos_heavy:  [18, 20] . Pos_light:  [16, 18] . Distance is:  4
# Stop sweep at Region 3  at position  [16 18]
# The closest start location is  [16  8]
# Step  9 Robot 0 Task left:  ['w98', 'w87']
# Step  9 Robot 1 Task left:  ['w52', 'w48']
# Step  9 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  9 Robot 3 Task left:  ['w12', 'w20']
# Step :  9 Light:  [16, 12] Heavy  3 :  [15, 1] Distance is:  12
# Round  0  Region 3
# The closest start location is  [16  8]
# Step  10 Robot 3 Pos [15, 1] R0 pos:  [25  8]
# Step  10 Robot 3 Pos [15, 1] R0 pos:  [16  9]
# Step  10 Robot 3 Pos [15, 1] R0 pos:  [16  8]
# Step  10 Robot 3 Pos [15, 1] R0 pos:  [16  7]
# Step  10 Robot 3 Pos [15, 1] R0 pos:  [16  6]
# Step  10 Robot 0 Task left:  ['w98', 'w87']
# Step  10 Robot 1 Task left:  ['w52', 'w48']
# Step  10 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  10 Robot 3 Task left:  ['w12', 'w20']
# Step :  10 Light:  [16, 5] Heavy 3 :  [15, 2] Distance is:  4
# Step  10 Robot 3 Pos [15, 2] R0 pos:  [16  5]
# len() 1
# kl:  0
# The heavy duty agent  3  is detected at step:  10 . Pos_heavy:  [15, 2] . Pos_light:  [16, 4] . Distance is:  3
# Stop sweep at Region 4  at position  [16  4]
# The closest start location is  [10  2]
# Step  11 Robot 0 Task left:  ['w98', 'w87']
# Step  11 Robot 1 Task left:  ['w52', 'w48']
# Step  11 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  11 Robot 3 Task left:  ['w12', 'w20']
# Step :  11 Light:  [11, 3] Heavy  4 :  [0, 8] Distance is:  16
# Round  1  Region 0
# The closest start location is  [10  2]
# Step  11 Robot 0 Pos [0, 8] R0 pos:  [1 2]
# Step  11 Robot 0 Pos [0, 8] R0 pos:  [11  2]
# Step  12 Robot 0 Pos [0, 8] R0 pos:  [10  2]
# Step  12 Robot 0 Pos [0, 8] R0 pos:  [10  3]
# Step  12 Robot 0 Pos [0, 8] R0 pos:  [10  4]
# Step  12 Robot 0 Pos [0, 8] R0 pos:  [10  5]
# Step  12 Robot 0 Pos [0, 8] R0 pos:  [10  6]
# Step  12 Robot 0 Task left:  ['w98', 'w87']
# Step  12 Robot 1 Task left:  ['w52', 'w48']
# Step  12 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  12 Robot 3 Task left:  ['w12', 'w20']
# Step :  12 Light:  [10, 7] Heavy 0 :  [1, 8] Distance is:  10
# Step  12 Robot 0 Pos [1, 8] R0 pos:  [10  7]
# Step  12 Robot 0 Pos [1, 8] R0 pos:  [10  8]
# Step  12 Robot 0 Pos [1, 8] R0 pos:  [9 8]
# Step  12 Robot 0 Pos [1, 8] R0 pos:  [8 8]
# Step  13 Robot 0 Pos [1, 8] R0 pos:  [7 8]
# Step  13 Robot 0 Pos [1, 8] R0 pos:  [7 7]
# Step  13 Robot 0 Pos [1, 8] R0 pos:  [7 6]
# Step  13 Robot 0 Pos [1, 8] R0 pos:  [7 5]
# Step  13 Robot 0 Task left:  ['w98', 'w87']
# Step  13 Robot 1 Task left:  ['w52', 'w48']
# Step  13 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  13 Robot 3 Task left:  ['w12', 'w20']
# Step :  13 Light:  [7, 4] Heavy 0 :  [0, 8] Distance is:  11
# Step  13 Robot 0 Pos [0, 8] R0 pos:  [7 4]
# Step  13 Robot 0 Pos [0, 8] R0 pos:  [7 3]
# Step  13 Robot 0 Pos [0, 8] R0 pos:  [7 2]
# Step  14 Robot 0 Pos [0, 8] R0 pos:  [6 2]
# Step  14 Robot 0 Pos [0, 8] R0 pos:  [5 2]
# Step  14 Robot 0 Pos [0, 8] R0 pos:  [4 2]
# Step  14 Robot 0 Pos [0, 8] R0 pos:  [4 3]
# Step  14 Robot 0 Pos [0, 8] R0 pos:  [4 4]
# Step  14 Robot 0 Task left:  ['w98', 'w87']
# Step  14 Robot 1 Task left:  ['w52', 'w48']
# Step  14 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  14 Robot 3 Task left:  ['w12', 'w20']
# Step :  14 Light:  [4, 5] Heavy 0 :  [1, 8] Distance is:  6
# Step  14 Robot 0 Pos [1, 8] R0 pos:  [4 5]
# Step  14 Robot 0 Pos [1, 8] R0 pos:  [4 6]
# Step  14 Robot 0 Pos [1, 8] R0 pos:  [4 7]
# Step  14 Robot 0 Pos [1, 8] R0 pos:  [4 8]
# The heavy duty agent  0  is detected at step:  14 . Pos_heavy:  [1, 8] . Pos_light:  [3, 8] . Distance is:  2
# Stop sweep at Region 1  at position  [3 8]
# The closest start location is  [ 2 14]
# Step  15 Robot 0 Task left:  ['w98', 'w87']
# Step  15 Robot 1 Task left:  ['w52', 'w48']
# Step  15 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  15 Robot 3 Task left:  ['w12', 'w20']
# Step :  15 Light:  [3, 11] Heavy  1 :  [1, 12] Distance is:  3
# The cooperative task is in region  [3]  the needed robot is  1
# The current map contains the follow task regions  [3] 1
# The new specification without time updating is  [['G', '30', '40', 'w62', 'R2', 'meet'], ['G', '62', '69', 'w58'], ['G', '37', '42', 'w208', '3', 'meet']]
# The current position before updating is  w9 after updating is  w12
# The new specification after the time update is  [['G', '15', '25', 'w62', 'R2', 'meet'], ['G', '47', '54', 'w58'], ['G', '22', '27', 'w208', '3', 'meet']]
# The initial position is  w12
# The initial position is  w12
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoCR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 351
# Edge in WTS:  1467
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 12
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-11T18:56:54.080120312
# Tried, but cannot achieve cooperation
# i:  1  ii:  1 j:  4 len(path_sweep) 4 len(path_sweep[ii]) 37
# The heavy duty agent  1  is detected at step:  15 . Pos_heavy:  [1, 12] . Pos_light:  [11, 14] . Distance is:  12
# Round  1  Region 1
# The closest start location is  [ 2 14]
# Step  15 Robot 1 Pos [1, 12] R0 pos:  [11 14]
# Step  15 Robot 1 Pos [1, 12] R0 pos:  [ 3 12]
# Step  16 Robot 1 Pos [1, 12] R0 pos:  [ 3 13]
# Step  16 Robot 1 Pos [1, 12] R0 pos:  [ 2 13]
# Step  16 Robot 1 Pos [1, 12] R0 pos:  [ 2 14]
# Step  16 Robot 1 Pos [1, 12] R0 pos:  [ 2 15]
# Step  16 Robot 1 Pos [1, 12] R0 pos:  [ 2 16]
# Step  16 Robot 0 Task left:  ['w98', 'w87']
# Step  16 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  16 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  16 Robot 3 Task left:  ['w12', 'w20']
# Step :  16 Light:  [2, 17] Heavy 1 :  [0, 12] Distance is:  7
# Step  16 Robot 1 Pos [0, 12] R0 pos:  [ 2 17]
# Step  16 Robot 1 Pos [0, 12] R0 pos:  [ 2 18]
# Step  16 Robot 1 Pos [0, 12] R0 pos:  [ 2 19]
# Step  16 Robot 1 Pos [0, 12] R0 pos:  [ 2 20]
# Step  17 Robot 1 Pos [0, 12] R0 pos:  [ 3 20]
# Step  17 Robot 1 Pos [0, 12] R0 pos:  [ 4 20]
# Step  17 Robot 1 Pos [0, 12] R0 pos:  [ 5 20]
# Step  17 Robot 1 Pos [0, 12] R0 pos:  [ 5 19]
# Step  17 Robot 0 Task left:  ['w98', 'w87']
# Step  17 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  17 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  17 Robot 3 Task left:  ['w12', 'w20']
# Step :  17 Light:  [5, 18] Heavy 1 :  [1, 12] Distance is:  10
# Step  17 Robot 1 Pos [1, 12] R0 pos:  [ 5 18]
# Step  17 Robot 1 Pos [1, 12] R0 pos:  [ 5 17]
# Step  17 Robot 1 Pos [1, 12] R0 pos:  [ 5 16]
# Step  18 Robot 1 Pos [1, 12] R0 pos:  [ 5 15]
# Step  18 Robot 1 Pos [1, 12] R0 pos:  [ 5 14]
# Step  18 Robot 1 Pos [1, 12] R0 pos:  [ 6 14]
# Step  18 Robot 1 Pos [1, 12] R0 pos:  [ 7 14]
# Step  18 Robot 1 Pos [1, 12] R0 pos:  [ 8 14]
# Step  18 Robot 0 Task left:  ['w98', 'w87']
# Step  18 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  18 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  18 Robot 3 Task left:  ['w12', 'w20']
# Step :  18 Light:  [8, 15] Heavy 1 :  [0, 12] Distance is:  11
# Step  18 Robot 1 Pos [0, 12] R0 pos:  [ 8 15]
# Step  18 Robot 1 Pos [0, 12] R0 pos:  [ 8 16]
# Step  18 Robot 1 Pos [0, 12] R0 pos:  [ 8 17]
# Step  18 Robot 1 Pos [0, 12] R0 pos:  [ 8 18]
# Step  19 Robot 1 Pos [0, 12] R0 pos:  [ 8 19]
# Step  19 Robot 1 Pos [0, 12] R0 pos:  [ 8 20]
# Step  19 Robot 1 Pos [0, 12] R0 pos:  [ 9 20]
# Step  19 Robot 1 Pos [0, 12] R0 pos:  [10 20]
# Step  19 Robot 0 Task left:  ['w98', 'w87']
# Step  19 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  19 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  19 Robot 3 Task left:  ['w12', 'w20']
# Step :  19 Light:  [11, 20] Heavy 1 :  [1, 12] Distance is:  18
# Step  19 Robot 1 Pos [1, 12] R0 pos:  [11 20]
# Step  19 Robot 1 Pos [1, 12] R0 pos:  [11 19]
# Step  19 Robot 1 Pos [1, 12] R0 pos:  [11 18]
# Step  20 Robot 1 Pos [1, 12] R0 pos:  [11 17]
# Step  20 Robot 1 Pos [1, 12] R0 pos:  [11 16]
# Step  20 Robot 1 Pos [1, 12] R0 pos:  [11 15]
# Stop sweep at Region 1  at position  [11 14]
# The closest start location is  [10 14]
# Round  1  Region 2
# The closest start location is  [16 14]
# Step  20 Robot 2 Pos [18, 21] R0 pos:  [25 14]
# Step  20 Robot 0 Task left:  ['w98', 'w87']
# Step  20 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  20 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  20 Robot 3 Task left:  ['w12', 'w20']
# Step :  20 Light:  [11, 14] Heavy 2 :  [18, 21] Distance is:  14
# Step  20 Robot 2 Pos [18, 21] R0 pos:  [11 14]
# Step  20 Robot 2 Pos [18, 21] R0 pos:  [12 14]
# Step  20 Robot 2 Pos [18, 21] R0 pos:  [13 14]
# Step  20 Robot 2 Pos [18, 21] R0 pos:  [14 14]
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [15 14]
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [16 14]
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [16 15]
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [16 16]
# Step  21 Robot 0 Task left:  ['w98', 'w87']
# Step  21 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  21 Robot 2 Task left:  ['w49', 'w54', 'w39']
# Step  21 Robot 3 Task left:  ['w12', 'w20']
# Step :  21 Light:  [16, 17] Heavy 2 :  [18, 21] Distance is:  6
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [16 17]
# Step  21 Robot 2 Pos [18, 21] R0 pos:  [16 18]
# The cooperative task is in region  [1]  the needed robot is  2
# The current map contains the follow task regions  [1] 2
# The new specification without time updating is  [['E', '8', '12', 'w239'], ['G', '43', '47', 'w246', 'R3', 'meet'], ['G', '72', '75', 'w227'], ['E', '30', '40', 'w52', '1', 'meet']]
# The current position before updating is  w49 after updating is  w239
# The new specification after the time update is  [['G', '22', '26', 'w246', 'R3', 'meet'], ['G', '51', '54', 'w227'], ['E', '9', '19', 'w52', '1', 'meet']]
# The initial position is  w239
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# The initial position is  w239
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR2
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoCR2.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 358
# Edge in WTS:  1546
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 239
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-11T18:57:06.151233398
# Tried, but cannot achieve cooperation
# The heavy duty agent  2  is detected at step:  21 . Pos_heavy:  [18, 21] . Pos_light:  [16, 19] . Distance is:  4
# Stop sweep at Region 3  at position  [16 19]
# The closest start location is  [16  8]
# Step  22 Robot 0 Task left:  ['w98', 'w87']
# Step  22 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  22 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  22 Robot 3 Task left:  ['w12', 'w20']
# Step :  22 Light:  [16, 14] Heavy  3 :  [14, 1] Distance is:  15
# Round  1  Region 3
# The closest start location is  [16  8]
# Step  23 Robot 3 Pos [14, 1] R0 pos:  [25  8]
# Step  23 Robot 3 Pos [14, 1] R0 pos:  [16  9]
# Step  23 Robot 3 Pos [14, 1] R0 pos:  [16  8]
# Step  23 Robot 0 Task left:  ['w98', 'w87']
# Step  23 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  23 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  23 Robot 3 Task left:  ['w12', 'w20']
# Step :  23 Light:  [16, 7] Heavy 3 :  [15, 1] Distance is:  7
# Step  23 Robot 3 Pos [15, 1] R0 pos:  [16  7]
# Step  23 Robot 3 Pos [15, 1] R0 pos:  [16  6]
# Step  23 Robot 3 Pos [15, 1] R0 pos:  [16  5]
# Step  24 Robot 3 Pos [15, 1] R0 pos:  [16  4]
# The cooperative task is in region  [1, 2]  the needed robot is  3
# The current map contains the follow task regions  [1, 2] 3
# The new specification without time updating is  [['G', '11', '15', 'w198'], ['G', '37', '42', 'w218'], ['E', '70', '78', 'w54', '1', 'col'], ['E', '43', '47', 'w54', '2', 'meet'], ['E', '70', '78', 'w54', '1', 'col'], ['E', '43', '47', 'w54', '2', 'meet']]
# The current position before updating is  w10 after updating is  w196
# The new specification after the time update is  [['G', '13', '18', 'w218'], ['E', '22', '30', 'w54', '1', 'col'], ['E', '0', '0', 'w54', '2', 'meet'], ['E', '22', '30', 'w54', '1', 'col'], ['E', '0', '0', 'w54', '2', 'meet']]
# The initial position is  w196
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# The initial position is  w196
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# CR3
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoCR3.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3,p4,np4,p5,np5;
# bool veri1,veri2,veri3,veri4,veri5;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3,cl4,cl5;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 472
# Edge in WTS:  2066
# State in TA:  6
# Edge in TA:   15
# ===== Initial State =====
# Initial state in WTS: 196
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3&&veri4&&veri5) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: null
# (null trace)
# Java time 2022-05-11T18:57:23.325337990
# Tried, but cannot achieve cooperation
# The heavy duty agent  3  is detected at step:  23 . Pos_heavy:  [15, 1] . Pos_light:  [16, 3] . Distance is:  3
# Stop sweep at Region 4  at position  [16  3]
# The closest start location is  [10  2]
# Step  24 Robot 0 Task left:  ['w98', 'w87']
# Step  24 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  24 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  24 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  24 Light:  [13, 3] Heavy  4 :  [1, 8] Distance is:  17
# java.io.IOException: Server connection lost
# 	at com.uppaal.engine.LexicalAnalyser.nextToken(LexicalAnalyser.java:223)
# 	at com.uppaal.engine.Parser.parseId(Parser.java:65)
# 	at com.uppaal.engine.DotProtocol.processQueryFeedback(DotProtocol.java:332)
# 	at com.uppaal.engine.DotProtocol.query(DotProtocol.java:181)
# 	at com.uppaal.engine.EngineStub.query(EngineStub.java:861)
# 	at com.uppaal.engine.Engine.query(Engine.java:476)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)
# IOException: Server connection lost
# 	at com.uppaal.engine.Engine.query(Engine.java:480)
# 	at FooVeri.run(MITL_verification.java:844)
# 	at java.base/java.lang.Thread.run(Thread.java:833)

# %%
"""
Path of agile light-duty robot
"""
path_detect_round[1] = path_detect_round[1][len(path_detect_round[0]): len(path_detect_round[1])]
for n in range(len(path_detect_round)):
    mm = copy.deepcopy(map_original)
    draw_path(mm, path_detect_round[n], fig_folder, "Trajectory of R0 Round " + str(n + 1))

# %%
"""
Get the data ready for plot and video
"""

independent_path_2d, record_working_region, record_task_left = \
    complete_path(world, v_light, independent_path_2d, states_work_region, record_working_region, record_task_left)

record_path_all = world.agents_light.path
for i in range(num_agent_heavy):
    record_path_all = np.concatenate((record_path_all, world.agents_heavy[i].path), axis=1)
    draw_path(map_obs_work, independent_path_2d[i], fig_folder, "Trajectory of heavy-duty robot R" + str(i + 1))

st = len(record_working_region[0])
for i in range(st, len(record_path_all)):
    for j in range(num_agent_heavy):
        record_working_region[j].append(record_working_region[j][-1])
        record_task_left[j].append(record_task_left[j][-1])

# animate_solution(map_obs_work, record_path_all, record_working_region, record_task_left, r_0, r_i, v_light,
#                  fig_folder, video=True)
# Out:
# Step  25 Robot 0 Task left:  ['w98', 'w87']
# Step  25 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  25 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  25 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  25 Robot 0 Task left:  ['w98', 'w87']
# Step  25 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  25 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  25 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  25 Robot 0 Task left:  ['w98', 'w87']
# Step  25 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  25 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  25 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  26
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step :  26
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  26
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  26
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  26 Robot 0 Task left:  ['w98', 'w87']
# Step  26 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  26 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  26 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  27
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step :  27
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  27
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  27
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  27 Robot 0 Task left:  ['w98', 'w87']
# Step  27 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  27 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  27 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  28
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step :  28
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  28
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  28
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  28 Robot 0 Task left:  ['w98', 'w87']
# Step  28 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  28 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  28 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  29
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step :  29
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  29
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  29
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  29 Robot 0 Task left:  ['w98', 'w87']
# Step  29 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  29 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  29 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  30
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step :  30
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  30
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  30
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  30 Robot 0 Task left:  ['w98', 'w87']
# Step  30 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  30 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  30 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  31
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step :  31
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  31
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  31
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  31 Robot 0 Task left:  ['w98', 'w87']
# Step  31 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  31 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  31 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  32
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step :  32
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  32
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  32
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  32 Robot 0 Task left:  ['w98', 'w87']
# Step  32 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  32 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  32 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  33
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step :  33
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  33
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  33
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  33 Robot 0 Task left:  ['w98', 'w87']
# Step  33 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  33 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  33 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  34
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step :  34
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  34
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  34
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  34 Robot 0 Task left:  ['w98', 'w87']
# Step  34 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  34 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  34 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  35
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step :  35
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  35
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  35
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  35 Robot 0 Task left:  ['w98', 'w87']
# Step  35 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  35 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  35 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  36
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step :  36
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  36
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  36
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  36 Robot 0 Task left:  ['w98', 'w87']
# Step  36 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  36 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  36 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w98', 'w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w98', 'w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w98', 'w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  37
# task  ['E', '27', '36', 'w98'] has been done by robot  0
# The tasks left  [['E', '45', '50', 'w87']]
# Step  37 Robot 0 Task left:  ['w87']
# Step :  37
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  37
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  37
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  37 Robot 0 Task left:  ['w87']
# Step  37 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  37 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  37 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  38
# Step  38 Robot 0 Task left:  ['w87']
# Step :  38
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  38
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  38
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  38 Robot 0 Task left:  ['w87']
# Step  38 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  38 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  38 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  39
# Step  39 Robot 0 Task left:  ['w87']
# Step :  39
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  39
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  39
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  39 Robot 0 Task left:  ['w87']
# Step  39 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  39 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  39 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  40
# Step  40 Robot 0 Task left:  ['w87']
# Step :  40
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step :  40
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  40
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  40 Robot 0 Task left:  ['w87']
# Step  40 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  40 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  40 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w62', 'w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  41
# Step  41 Robot 0 Task left:  ['w87']
# Step :  41
# task  ['G', '15', '25', 'w62', 'R2', 'meet'] has been done by robot  1
# The tasks left  [['G', '47', '54', 'w58'], ['G', '22', '27', 'w208', '3', 'meet']]
# Step  41 Robot 1 Task left:  ['w58', 'w208']
# Step :  41
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  41
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  41 Robot 0 Task left:  ['w87']
# Step  41 Robot 1 Task left:  ['w58', 'w208']
# Step  41 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  41 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  42
# Step  42 Robot 0 Task left:  ['w87']
# Step :  42
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step :  42
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  42
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  42 Robot 0 Task left:  ['w87']
# Step  42 Robot 1 Task left:  ['w58', 'w208']
# Step  42 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  42 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w218', 'w54', 'w54', 'w54', 'w54']
# Step :  43
# Step  43 Robot 0 Task left:  ['w87']
# Step :  43
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step :  43
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  43
# task  ['G', '13', '18', 'w218'] has been done by robot  3
# The tasks left  [['E', '22', '30', 'w54', '1', 'col'], ['E', '0', '0', 'w54', '2', 'meet'], ['E', '22', '30', 'w54', '1', 'col'], ['E', '0', '0', 'w54', '2', 'meet']]
# Step  43 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  43 Robot 0 Task left:  ['w87']
# Step  43 Robot 1 Task left:  ['w58', 'w208']
# Step  43 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  43 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  44
# Step  44 Robot 0 Task left:  ['w87']
# Step :  44
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step :  44
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  44
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  44 Robot 0 Task left:  ['w87']
# Step  44 Robot 1 Task left:  ['w58', 'w208']
# Step  44 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  44 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  45
# Step  45 Robot 0 Task left:  ['w87']
# Step :  45
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step :  45
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  45
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  45 Robot 0 Task left:  ['w87']
# Step  45 Robot 1 Task left:  ['w58', 'w208']
# Step  45 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  45 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  ['w87']
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  ['w87']
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  ['w87']
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  ['w87']
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  46
# task  ['E', '45', '50', 'w87'] has been done by robot  0
# The tasks left  []
# Step  46 Robot 0 Task left:  []
# Step :  46
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step :  46
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  46
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  []
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  []
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  []
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  46 Robot 0 Task left:  []
# Step  46 Robot 1 Task left:  ['w58', 'w208']
# Step  46 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  46 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  47
# Step  47 Robot 0 Task left:  []
# Step :  47
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step :  47
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step :  47
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  47 Robot 0 Task left:  []
# Step  47 Robot 1 Task left:  ['w58', 'w208']
# Step  47 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  47 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w246', 'w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  48
# Step  48 Robot 0 Task left:  []
# Step :  48
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step :  48
# task  ['G', '22', '26', 'w246', 'R3', 'meet'] has been done by robot  2
# The tasks left  [['G', '51', '54', 'w227'], ['E', '9', '19', 'w52', '1', 'meet']]
# Step  48 Robot 2 Task left:  ['w227', 'w52']
# Step :  48
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  48 Robot 0 Task left:  []
# Step  48 Robot 1 Task left:  ['w58', 'w208']
# Step  48 Robot 2 Task left:  ['w227', 'w52']
# Step  48 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  49
# Step  49 Robot 0 Task left:  []
# Step :  49
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step :  49
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step :  49
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  49 Robot 0 Task left:  []
# Step  49 Robot 1 Task left:  ['w58', 'w208']
# Step  49 Robot 2 Task left:  ['w227', 'w52']
# Step  49 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  50
# Step  50 Robot 0 Task left:  []
# Step :  50
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step :  50
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step :  50
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  50 Robot 0 Task left:  []
# Step  50 Robot 1 Task left:  ['w58', 'w208']
# Step  50 Robot 2 Task left:  ['w227', 'w52']
# Step  50 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  51
# Step  51 Robot 0 Task left:  []
# Step :  51
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step :  51
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step :  51
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  51 Robot 0 Task left:  []
# Step  51 Robot 1 Task left:  ['w58', 'w208']
# Step  51 Robot 2 Task left:  ['w227', 'w52']
# Step  51 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  52
# Step  52 Robot 0 Task left:  []
# Step :  52
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step :  52
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step :  52
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  52 Robot 0 Task left:  []
# Step  52 Robot 1 Task left:  ['w58', 'w208']
# Step  52 Robot 2 Task left:  ['w227', 'w52']
# Step  52 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  53
# Step  53 Robot 0 Task left:  []
# Step :  53
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step :  53
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step :  53
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  53 Robot 0 Task left:  []
# Step  53 Robot 1 Task left:  ['w58', 'w208']
# Step  53 Robot 2 Task left:  ['w227', 'w52']
# Step  53 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  54 Robot 0 Task left:  []
# Step  54 Robot 1 Task left:  ['w58', 'w208']
# Step  54 Robot 2 Task left:  ['w227', 'w52']
# Step  54 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# ...
# Step  65 Robot 1 Task left:  ['w58', 'w208']
# Step  65 Robot 2 Task left:  ['w227', 'w52']
# Step  65 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  65 Robot 0 Task left:  []
# Step  65 Robot 1 Task left:  ['w58', 'w208']
# Step  65 Robot 2 Task left:  ['w227', 'w52']
# Step  65 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  66
# Step  66 Robot 0 Task left:  []
# Step :  66
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step :  66
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step :  66
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  66 Robot 0 Task left:  []
# Step  66 Robot 1 Task left:  ['w58', 'w208']
# Step  66 Robot 2 Task left:  ['w227', 'w52']
# Step  66 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  67
# Step  67 Robot 0 Task left:  []
# Step :  67
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step :  67
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step :  67
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  67 Robot 0 Task left:  []
# Step  67 Robot 1 Task left:  ['w58', 'w208']
# Step  67 Robot 2 Task left:  ['w227', 'w52']
# Step  67 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  68
# Step  68 Robot 0 Task left:  []
# Step :  68
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step :  68
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step :  68
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  68 Robot 0 Task left:  []
# Step  68 Robot 1 Task left:  ['w58', 'w208']
# Step  68 Robot 2 Task left:  ['w227', 'w52']
# Step  68 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  69
# Step  69 Robot 0 Task left:  []
# Step :  69
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step :  69
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step :  69
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  69 Robot 0 Task left:  []
# Step  69 Robot 1 Task left:  ['w58', 'w208']
# Step  69 Robot 2 Task left:  ['w227', 'w52']
# Step  69 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w58', 'w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w58', 'w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w58', 'w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w58', 'w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  70
# Step  70 Robot 0 Task left:  []
# Step :  70
# task  ['G', '47', '54', 'w58'] has been done by robot  1
# The tasks left  [['G', '22', '27', 'w208', '3', 'meet']]
# Step  70 Robot 1 Task left:  ['w208']
# Step :  70
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step :  70
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  70 Robot 0 Task left:  []
# Step  70 Robot 1 Task left:  ['w208']
# Step  70 Robot 2 Task left:  ['w227', 'w52']
# Step  70 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  71
# Step  71 Robot 0 Task left:  []
# Step :  71
# Step  71 Robot 1 Task left:  ['w208']
# Step :  71
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step :  71
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  71 Robot 0 Task left:  []
# Step  71 Robot 1 Task left:  ['w208']
# Step  71 Robot 2 Task left:  ['w227', 'w52']
# Step  71 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  72
# Step  72 Robot 0 Task left:  []
# Step :  72
# Step  72 Robot 1 Task left:  ['w208']
# Step :  72
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step :  72
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  72 Robot 0 Task left:  []
# Step  72 Robot 1 Task left:  ['w208']
# Step  72 Robot 2 Task left:  ['w227', 'w52']
# Step  72 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  73
# Step  73 Robot 0 Task left:  []
# Step :  73
# Step  73 Robot 1 Task left:  ['w208']
# Step :  73
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step :  73
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  73 Robot 0 Task left:  []
# Step  73 Robot 1 Task left:  ['w208']
# Step  73 Robot 2 Task left:  ['w227', 'w52']
# Step  73 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  74
# Step  74 Robot 0 Task left:  []
# Step :  74
# Step  74 Robot 1 Task left:  ['w208']
# Step :  74
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step :  74
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  74 Robot 0 Task left:  []
# Step  74 Robot 1 Task left:  ['w208']
# Step  74 Robot 2 Task left:  ['w227', 'w52']
# Step  74 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  75
# Step  75 Robot 0 Task left:  []
# Step :  75
# Step  75 Robot 1 Task left:  ['w208']
# Step :  75
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step :  75
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  75 Robot 0 Task left:  []
# Step  75 Robot 1 Task left:  ['w208']
# Step  75 Robot 2 Task left:  ['w227', 'w52']
# Step  75 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  76 Robot 0 Task left:  []
# Step  76 Robot 1 Task left:  ['w208']
# Step  76 Robot 2 Task left:  ['w227', 'w52']
# Step  76 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  76 Robot 0 Task left:  []
# Step  76 Robot 1 Task left:  ['w208']
# Step  76 Robot 2 Task left:  ['w227', 'w52']
# Step  76 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  76 Robot 0 Task left:  []
# Step  76 Robot 1 Task left:  ['w208']
# Step  76 Robot 2 Task left:  ['w227', 'w52']
# Step  76 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step  76 Robot 0 Task left:  []
# Step  76 Robot 1 Task left:  ['w208']
# Step  76 Robot 2 Task left:  ['w227', 'w52']
# Step  76 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
# Step :  76
# Step  76 Robot 0 Task left:  []
# Step :  76
# Step  76 Robot 1 Task left:  ['w208']
# Step :  76
# task  ['G', '51', '54', 'w227'] has been done by robot  2
# The tasks left  [['E', '9', '19', 'w52', '1', 'meet']]
# Step  76 Robot 2 Task left:  ['w52']
# Step :  76
# Step  76 Robot 3 Task left:  ['w54', 'w54', 'w54', 'w54']
