# %%
from datetime import datetime
import numpy as np
import math
import copy
import os
import random
from initialization import make_world, get_tasks, initial_env, initial_agents, initial_work_region, initial_specification
from visualization import draw_path, draw_map, animate_solution
from heavy_WTS import total_states
from heavy_path_generation import heavy_path, get_work_map, get_path_cell2coord, get_independent_requests_tasks
from request_exchange import collect_deliver, complete_path


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    UNDERLINE = '\033[4m'

# %%
# dirname = os.path.dirname
# ABPATH = os.path.join(dirname(dirname(__file__)))

ABPATH = os.path.dirname(os.getcwd())

"""create the folder for the fig, file, output(video)"""
now = datetime.today().strftime('%Y-%m-%d')
fig_folder = ABPATH + '/figures/' + str(now)
file_folder = ABPATH + '/files/' + str(now)
output_folder = ABPATH + '/files/' + str(now) + '/output'
if not (os.path.exists(fig_folder)):
    os.makedirs(fig_folder)
if not (os.path.exists(file_folder)):
    os.makedirs(file_folder)
if not (os.path.exists(output_folder)):
    os.makedirs(output_folder)

# %%
"""
Initial the environment
Get the number robots: num_agent_heavy, num_agent_light
Get the size of the work region: region_row, region_col
Get the whole map with obstacles: 2*(N/2) work regions, obs_percentage, obs_list
Get the map and state space of the env: map_original, map_obstacle, states_original
Get the map and state space of work regions for each heavy-duty robot: work_region, map_work_region, states_work_region
Get initial position of all robots: agents_heavy, agents_light
"""
num_agent_heavy = random.choice([2,4,6])
num_agent_light = 1
region_row, region_col = [random.randint(10, 15), random.randint(10, 15)]
map_row, map_col = [region_row * 2, int(region_col * (num_agent_heavy / 2))]
obs_percentage = 10
obs_list = initial_env(region_row * 2, region_col * (num_agent_heavy / 2), obs_percentage)
map_original = np.zeros((map_row, map_col), dtype=int)
map_obstacle = copy.deepcopy(map_original)
for i in range(len(obs_list)):
    map_obstacle[obs_list[i][0]][obs_list[i][1]] = 1
states_original = total_states(map_obstacle)
work_region = initial_work_region(num_agent_heavy, region_row, region_col)
map_work_region = [get_work_map(map_obstacle, work_region, i) for i in range(num_agent_heavy)]
states_work_region = [total_states(map_work_region[i]) for i in range(num_agent_heavy)]

agents_heavy, [agents_light] = initial_agents(work_region, obs_list, num_agent_heavy, num_agent_light)
print("Init heavy_duty agents: ", agents_heavy, ". Init light_duty agent: ", agents_light)

# get the MITL task specification
specifications = initial_specification(obs_list, agents_heavy, agents_light, work_region, states_work_region)
for i in range(num_agent_heavy):
    print("MITL Specification of R", i+1, ": ", specifications[i])

task_type = get_tasks(specifications, states_work_region)
map_obs_work = copy.deepcopy(map_obstacle)
draw_map(map_obs_work, task_type, num_agent_heavy, fig_folder)
# Out:
# Init heavy_duty agents:  [[1, 1], [12, 9]] . Init light_duty agent:  [3, 1]
# MITL Specification of R 1 :  [['E', '38', '47', 'w19'], ['E', '70', '79', 'w21', 'R1', 'meet']]
# MITL Specification of R 2 :  [['E', '12', '22', 'w2', 'R0', 'col'], ['E', '48', '50', 'w27']]

# %%
"""
--------------- light-duty robot module ---------------
"""
# initial the parameters of agents
u_size = 1
r_i = 1
r_0 = 2
# hatch distance
h_a = 2 * r_0 - 1
# velocity / transition weight constraints
v_heavy = 1
v_light = max([math.ceil(
    ((2 * (work_region[i][3] - work_region[i][2] - 2 * r_0 - u_size) + h_a) *
     v_heavy) / ((2 * r_0) - (h_a - u_size))) for i in range(num_agent_heavy)])

# %%
"""
--------------- Pre-computation ---------------
"""
path_existence = [[] for i in range(num_agent_heavy)]
initial_path = [[] for i in range(num_agent_heavy)]
independent_path = [[] for i in range(num_agent_heavy)]
independent_task = [[] for i in range(num_agent_heavy)]
independent_request = [[] for i in range(num_agent_heavy)]
independent_path_2d = [[] for i in range(num_agent_heavy)]

for i in range(num_agent_heavy):
    flag = "R" + str(i)
    # check if the initial specifications are satisfied
    initial_path[i] = heavy_path(map_work_region[i], specifications[i], file_folder, flag,
                                 agents_heavy[i]).get_path()
    # check if robot need to cooperate and provide best promise.  (bool) coop, promise
    if len(initial_path[i]) == 0:
        path_existence[i] = False
        print(path_existence[i])
        print("========There is no path satisfying the specification!========")
    else:
        path_existence[i] = True
if all(item is True for item in path_existence):
    for i in range(num_agent_heavy):
        independent_task, independent_request = get_independent_requests_tasks(specifications, map_work_region,
                                                                               agents_heavy, file_folder)
        independent_path[i] = heavy_path(map_work_region[i], independent_task[i], file_folder, flag,
                                         agents_heavy[i]).get_path()
        independent_path_2d[i] = get_path_cell2coord(independent_path[i], states_work_region[i])
# Out:
# The initial position is  w10
# The initial position is  w10
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 80
# Edge in WTS:  336
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 10
# Initial state in TA: 0
# , , ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w10, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=41, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=43, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=45, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=46, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=70, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The initial position is  w28
# The initial position is  w28
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 81
# Edge in WTS:  337
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 28
# Initial state in TA: 0
# , , ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w28, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w18, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w8, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w7, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w6, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w5, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w4, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w13, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=22, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=23, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=24, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=25, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=26, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=27, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=28, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=29, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=30, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=31, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=32, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=33, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=34, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=35, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=36, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=37, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=38, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=39, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l1, w=40, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=41, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l0, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w22, l0, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w23, l0, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w24, l0, w=45, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w25, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w26, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w27, l2, w=48, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The spec to verify (before) is  [['E', '38', '47', 'w19'], ['G', '70', '79', 'w21', 'R1', 'meet']]
# The initial position is  w10
# The initial position is  w10
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 80
# Edge in WTS:  336
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 10
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w10, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=41, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=43, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=45, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=46, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w21, l2, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w21, l2, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w21, l2, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w21, l2, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w21, l2, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# (w21, l2, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=7)
#
# (w21, l2, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=8)
#
# (w21, l2, w=79, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=9)
#
# The initial position is  w10
# The initial position is  w10
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 80
# Edge in WTS:  336
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 10
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w10, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=41, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=43, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=45, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=46, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w21, l2, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w21, l2, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w21, l2, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w21, l2, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w21, l2, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# (w21, l2, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=7)
#
# (w21, l2, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=8)
#
# (w21, l2, w=79, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=9)
#
# The spec to verify (before) is  [['E', '38', '47', 'w19'], ['G', '70', '79', 'w21', 'R1', 'meet']]
# The initial position is  w10
# The initial position is  w10
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# R0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 80
# Edge in WTS:  336
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 10
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w10, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=41, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=42, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=43, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=44, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=45, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=46, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=62, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=63, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=64, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=65, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=66, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=67, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w19, l1, w=68, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=69, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=70, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=71, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=1)
#
# (w21, l2, w=72, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=2)
#
# (w21, l2, w=73, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=3)
#
# (w21, l2, w=74, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=4)
#
# (w21, l2, w=75, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=5)
#
# (w21, l2, w=76, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=6)
#
# (w21, l2, w=77, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=7)
#
# (w21, l2, w=78, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=8)
#
# (w21, l2, w=79, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=9)
#
# The initial position is  w28
# The initial position is  w28
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 1 second
# ===== Flag =====
# R1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1;
# bool veri1;
# ===== Templates declarations =====
# null
# int cl1;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 81
# Edge in WTS:  337
# State in TA:  2
# Edge in TA:   3
# ===== Initial State =====
# Initial state in WTS: 28
# Initial state in TA: 0
# , ===== Symbolic Verification: E<>(veri1) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w28, l0, w=0, veri1=0, ProcessTA.cl1=0)
#
# (w18, l0, w=1, veri1=0, ProcessTA.cl1=0)
#
# (w9, l0, w=2, veri1=0, ProcessTA.cl1=0)
#
# (w8, l0, w=3, veri1=0, ProcessTA.cl1=0)
#
# (w7, l0, w=4, veri1=0, ProcessTA.cl1=0)
#
# (w6, l0, w=5, veri1=0, ProcessTA.cl1=0)
#
# (w5, l0, w=6, veri1=0, ProcessTA.cl1=0)
#
# (w4, l0, w=7, veri1=0, ProcessTA.cl1=0)
#
# (w3, l0, w=8, veri1=0, ProcessTA.cl1=0)
#
# (w2, l0, w=9, veri1=0, ProcessTA.cl1=0)
#
# (w1, l0, w=10, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=11, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=12, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=13, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=14, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=15, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=16, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=17, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=18, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=19, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=20, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=21, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=22, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=23, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=24, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=25, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=26, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=27, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=28, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=29, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=30, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=31, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=32, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=33, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=34, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=35, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=36, veri1=0, ProcessTA.cl1=0)
#
# (w0, l0, w=37, veri1=0, ProcessTA.cl1=0)
#
# (w10, l0, w=38, veri1=0, ProcessTA.cl1=0)
#
# (w19, l0, w=39, veri1=0, ProcessTA.cl1=0)
#
# (w20, l0, w=40, veri1=0, ProcessTA.cl1=0)
#
# (w21, l0, w=41, veri1=0, ProcessTA.cl1=0)
#
# (w22, l0, w=42, veri1=0, ProcessTA.cl1=0)
#
# (w23, l0, w=43, veri1=0, ProcessTA.cl1=0)
#
# (w24, l0, w=44, veri1=0, ProcessTA.cl1=0)
#
# (w25, l0, w=45, veri1=0, ProcessTA.cl1=0)
#
# (w26, l0, w=46, veri1=0, ProcessTA.cl1=0)
#
# (w26, l0, w=47, veri1=0, ProcessTA.cl1=0)
#
# (w27, l1, w=48, veri1=1, ProcessTA.cl1=0)

# %%
print(f"{bcolors.HEADER}======== ***** The Pre-computation Result ****** ========")
print(f"{bcolors.HEADER}------- The Original Task Specification -------")
print(specifications)
print(f"{bcolors.HEADER}------------ If all the paths exist ------------")
print(path_existence)
if all(item is True for item in path_existence):
    print(f"{bcolors.HEADER}---- The Independent Task Specification ----")
    print(independent_task)
    print(f"{bcolors.HEADER}--------- The Independent Request ---------")
    print(independent_request)
# Out:
# ======== ***** The Pre-computation Result ****** ========
# ------- The Original Task Specification -------
# [[['E', '38', '47', 'w19'], ['E', '70', '79', 'w21', 'R1', 'meet']], [['E', '12', '22', 'w2', 'R0', 'col'], ['E', '48', '50', 'w27']]]
# ------------ If all the paths exist ------------
# [True, True]
# ---- The Independent Task Specification ----
# [[['E', '38', '47', 'w19'], ['G', '70', '79', 'w21', 'R1', 'meet']], [['E', '48', '50', 'w27']]]
# --------- The Independent Request ---------
# [[[], [['E', '70', '79', 'w21', 'R1', 'meet']]], [[['E', '12', '22', 'w2', 'R0', 'col']], []]]

# %%
# make the world (core.py)
world = make_world(agents_heavy, agents_light, r_i, r_0, v_heavy, v_light, u_size, independent_task,
                   independent_request)

# %%
"""
Start two round SWEEP
"""
# start sweeping
# maximum 2 rounds to guarantee the requests exchange

num_round_exchange = 2

path_detect_round, independent_path_2d, record_working_region, record_task_left = \
    collect_deliver(world, map_obs_work, num_round_exchange, num_agent_heavy, work_region, states_work_region,
                    independent_path_2d, h_a, r_0, v_light, file_folder)
# Out:
# Round  0  Region 0
# The closest start location is  [2 2]
# Step  0 Robot 0 Pos [1 1] R0 pos:  [8 7]
# The heavy duty agent  0  is detected at step:  0 . Pos_heavy:  [1, 1] . Pos_light:  [3, 1] . Distance is:  2
# Stop sweep at Region 1  at position  [3 1]
# The closest start location is  [12  2]
# Step  1 Robot 0 Task left:  ['w19', 'w21']
# Step  1 Robot 1 Task left:  ['w27']
# Step :  1 Light:  [8, 1] Heavy  1 :  [11, 9] Distance is:  11
# Round  0  Region 1
# The closest start location is  [12  2]
# Step  2 Robot 1 Pos [11, 9] R0 pos:  [18  7]
# Step  2 Robot 1 Pos [11, 9] R0 pos:  [11  2]
# Step  2 Robot 1 Pos [11, 9] R0 pos:  [12  2]
# Step  2 Robot 0 Task left:  ['w19', 'w21']
# Step  2 Robot 1 Task left:  ['w27']
# Step :  2 Light:  [12, 3] Heavy 1 :  [10, 9] Distance is:  8
# Step  2 Robot 1 Pos [10, 9] R0 pos:  [12  3]
# Step  2 Robot 1 Pos [10, 9] R0 pos:  [12  4]
# Step  2 Robot 1 Pos [10, 9] R0 pos:  [12  5]
# Step  3 Robot 1 Pos [10, 9] R0 pos:  [12  6]
# The heavy duty agent  1  is detected at step:  2 . Pos_heavy:  [10, 9] . Pos_light:  [12, 7] . Distance is:  4
# Stop sweep at Region 2  at position  [12  7]
# The closest start location is  [6 7]
# Step  3 Robot 0 Task left:  ['w19', 'w21']
# Step  3 Robot 1 Task left:  ['w27']
# Step :  3 Light:  [10, 7] Heavy  2 :  [1, 0] Distance is:  16
# Round  1  Region 0
# The closest start location is  [6 7]
# Step  4 Robot 0 Pos [1, 0] R0 pos:  [0 2]
# Step  4 Robot 0 Pos [1, 0] R0 pos:  [7 7]
# Step  4 Robot 0 Pos [1, 0] R0 pos:  [6 7]
# Step  4 Robot 0 Pos [1, 0] R0 pos:  [6 6]
# Step  4 Robot 0 Task left:  ['w19', 'w21']
# Step  4 Robot 1 Task left:  ['w27']
# Step :  4 Light:  [6, 5] Heavy 0 :  [0, 0] Distance is:  11
# Step  4 Robot 0 Pos [0, 0] R0 pos:  [6 5]
# Step  4 Robot 0 Pos [0, 0] R0 pos:  [6 4]
# Step  4 Robot 0 Pos [0, 0] R0 pos:  [6 3]
# Step  5 Robot 0 Pos [0, 0] R0 pos:  [6 2]
# Step  5 Robot 0 Pos [0, 0] R0 pos:  [5 2]
# Step  5 Robot 0 Pos [0, 0] R0 pos:  [4 2]
# Step  5 Robot 0 Pos [0, 0] R0 pos:  [3 2]
# Step  5 Robot 0 Task left:  ['w19', 'w21']
# Step  5 Robot 1 Task left:  ['w27']
# Step :  5 Light:  [3, 3] Heavy 0 :  [1, 0] Distance is:  5
# Step  5 Robot 0 Pos [1, 0] R0 pos:  [3 3]
# Step  5 Robot 0 Pos [1, 0] R0 pos:  [3 4]
# Step  5 Robot 0 Pos [1, 0] R0 pos:  [3 5]
# Step  6 Robot 0 Pos [1, 0] R0 pos:  [3 6]
# Step  6 Robot 0 Pos [1, 0] R0 pos:  [3 7]
# Step  6 Robot 0 Pos [1, 0] R0 pos:  [2 7]
# Step  6 Robot 0 Pos [1, 0] R0 pos:  [1 7]
# Step  6 Robot 0 Task left:  ['w19', 'w21']
# Step  6 Robot 1 Task left:  ['w27']
# Step :  6 Light:  [0, 7] Heavy 0 :  [0, 0] Distance is:  7
# Step  6 Robot 0 Pos [0, 0] R0 pos:  [0 7]
# Step  6 Robot 0 Pos [0, 0] R0 pos:  [0 6]
# Step  6 Robot 0 Pos [0, 0] R0 pos:  [0 5]
# Step  7 Robot 0 Pos [0, 0] R0 pos:  [0 4]
# Step  7 Robot 0 Pos [0, 0] R0 pos:  [0 3]
# The cooperative task is in region  [1]  the needed robot is  0
# The current map contains the follow task regions  [1] 0
# The new specification without time updating is  [['E', '38', '47', 'w20'], ['G', '70', '79', 'w22', 'R1', 'meet'], ['E', '12', '22', 'w100', '1', 'col']]
# The current position before updating is  w0 after updating is  w0
# The new specification after the time update is  [['E', '31', '40', 'w20'], ['G', '63', '72', 'w22', 'R1', 'meet'], ['E', '5', '15', 'w100', '1', 'col']]
# The initial position is  w0
# The initial position is  w0
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR0
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoCR0.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2,p3,np3;
# bool veri1,veri2,veri3;
# ===== Templates declarations =====
# null
# int cl1,cl2,cl3;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 198
# Edge in WTS:  862
# State in TA:  4
# Edge in TA:   9
# ===== Initial State =====
# Initial state in WTS: 0
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2&&veri3) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w0, l0, w=0, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w9, l0, w=1, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w10, l0, w=2, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w21, l0, w=3, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w31, l0, w=4, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w41, l0, w=5, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w50, l0, w=6, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=7, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w61, l0, w=8, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w70, l0, w=9, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w69, l0, w=10, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w80, l0, w=11, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w89, l0, w=12, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l0, w=13, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w99, l0, w=14, veri1=0, veri2=0, veri3=0, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=15, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=16, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=17, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=18, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=19, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=20, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=21, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=22, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=23, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=24, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=25, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=26, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=27, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w100, l3, w=28, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w90, l0, w=29, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w89, l0, w=30, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w80, l0, w=31, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w69, l0, w=32, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w70, l0, w=33, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w61, l0, w=34, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w51, l0, w=35, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w42, l0, w=36, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w32, l0, w=37, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w31, l0, w=38, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w21, l0, w=39, veri1=0, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=40, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=41, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=42, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=43, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=44, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=45, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=46, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=47, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=48, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=49, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=50, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=51, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=52, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=53, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=54, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=55, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=56, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=57, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=58, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=59, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=60, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w20, l1, w=61, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w21, l0, w=62, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w22, l2, w=63, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=0, ProcessTA.cl3=0)
#
# (w22, l2, w=64, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=1, ProcessTA.cl3=0)
#
# (w22, l2, w=65, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=2, ProcessTA.cl3=0)
#
# (w22, l2, w=66, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=3, ProcessTA.cl3=0)
#
# (w22, l2, w=67, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=4, ProcessTA.cl3=0)
#
# (w22, l2, w=68, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=5, ProcessTA.cl3=0)
#
# (w22, l2, w=69, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=6, ProcessTA.cl3=0)
#
# (w22, l2, w=70, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=7, ProcessTA.cl3=0)
#
# (w22, l2, w=71, veri1=1, veri2=0, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=8, ProcessTA.cl3=0)
#
# (w22, l2, w=72, veri1=1, veri2=1, veri3=1, ProcessTA.cl1=0, ProcessTA.cl2=9, ProcessTA.cl3=0)
#
# The cooperation can be achieved!
# The robot  0  is updating the path since time  7
# The heavy duty agent  0  is detected at step:  6 . Pos_heavy:  [0, 0] . Pos_light:  [0, 2] . Distance is:  2
# Stop sweep at Region 1  at position  [0 2]
# The closest start location is  [12  2]
# Step  7 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  7 Robot 1 Task left:  ['w27']
# Step :  7 Light:  [1, 2] Heavy  1 :  [10, 4] Distance is:  11
# The cooperative task is in region  [0]  the needed robot is  1
# The current map contains the follow task regions  [0] 1
# The new specification without time updating is  [['E', '48', '50', 'w127'], ['E', '70', '79', 'w21', '0', 'meet']]
# The current position before updating is  w4 after updating is  w102
# The new specification after the time update is  [['E', '40', '42', 'w127'], ['E', '62', '71', 'w21', '0', 'meet']]
# The initial position is  w102
# The initial position is  w102
# Buildfile: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build.xml
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-clean-init:
#
# deps-clean:
#
# -warn-already-built-clean:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-clean.properties
#
# -do-clean:
#    [delete] Deleting directory /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -post-clean:
#
# clean:
#
# -pre-init:
#
# -init-private:
#
# -init-user:
#
# -init-project:
#
# -init-macrodef-property:
#
# -init-modules-supported:
#
# -do-init:
#
# -post-init:
#
# -init-check:
#
# -init-ap-cmdline-properties:
#
# -init-macrodef-modulename:
#
# -init-source-module-properties:
#
# -init-macrodef-javac-with-module:
#
# -init-macrodef-javac-with-processors:
#
# -init-macrodef-javac-without-processors:
#
# -init-macrodef-javac:
#
# -init-macrodef-test-impl:
#
# -init-macrodef-junit-init:
#
# -init-test-properties:
#
# -init-macrodef-junit-prototype-with-module:
#
# -init-macrodef-junit-prototype-without-module:
#
# -init-macrodef-junit-single:
#
# -init-macrodef-junit-batch:
#
# -init-macrodef-junit:
#
# -init-macrodef-junit-impl:
#
# -init-macrodef-testng:
#
# -init-macrodef-testng-impl:
#
# -init-macrodef-test:
#
# -init-macrodef-junit-debug-impl:
#
# -init-macrodef-test-debug-junit:
#
# -init-macrodef-testng-debug:
#
# -init-macrodef-testng-debug-impl:
#
# -init-macrodef-test-debug-testng:
#
# -init-macrodef-test-debug:
#
# -init-debug-args:
#
# -init-macrodef-nbjpda:
#
# -init-macrodef-debug:
#
# -init-macrodef-java-with-module:
#
# -init-macrodef-java-with-unnamed-module:
#
# -init-macrodef-java-without-module:
#
# -init-macrodef-java:
#
# -init-presetdef-jar:
#
# -init-ap-cmdline-supported:
#
# -init-ap-cmdline:
#
# init:
#
# -deps-jar-init:
#
# deps-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -warn-already-built-jar:
# [propertyfile] Updating property file: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/built-jar.properties
#
# -check-automatic-build:
#
# -clean-after-automatic-build:
#
# -verify-automatic-build:
#
# -pre-pre-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -pre-compile:
#
# -copy-persistence-xml:
#
# -compile-depend:
#
# -do-compile:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/empty
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/generated-sources/ap-source-output
#     [javac] Compiling 8 source files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#     [javac] warning: [options] bootstrap class path not set in conjunction with -source 8
#     [javac] 1 warning
#      [copy] Copying 5 files to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#      [copy] Copied 5 empty directories to 3 empty directories under /home/wei/uppaal64-4.1.26/demo/ModelDemo/build/classes
#
# -post-compile:
#
# compile:
#
# -pre-jar:
#
# -check-module-main-class:
#
# -set-module-main-class:
#
# -pre-pre-jar:
#     [mkdir] Created dir: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist
#
# -do-jar-create-manifest:
#
# -do-jar-copy-manifest:
#      [copy] Copying 1 file to /home/wei/uppaal64-4.1.26/demo/ModelDemo/build
#
# -do-jar-set-mainclass:
#
# -do-jar-set-profile:
#
# -do-jar-set-splashscreen:
#
# -check-do-mkdist:
#
# -do-jar-jar:
# [j2seproject1:jar] Building jar: /home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar
#      [echo] To run this application from the command line without Ant, try:
#      [echo] /usr/lib/jvm/java-17-oracle/bin/java -cp /home/wei/uppaal64-4.1.26/lib/model.jar:/home/wei/uppaal64-4.1.26/lib/json-simple-1.1.1.jar:/home/wei/uppaal64-4.1.26/uppaal.jar:/home/wei/uppaal64-4.1.26/demo/ModelDemo/dist/ModelDemo.jar ModelDemo
#
# -init-macrodef-copylibs:
#
# -do-jar-copylibs:
#
# -do-jar-delete-manifest:
#
# -do-jar-without-libraries:
#
# -do-jar-with-libraries:
#
# -post-jar:
#
# -do-jar:
#
# -pre-deploy:
#
# -check-jlink:
#
# -do-deploy:
#
# -post-deploy:
#
# deploy:
#
# jar:
#
# BUILD SUCCESSFUL
# Total time: 2 seconds
# ===== Flag =====
# CR1
# /home/wei/PycharmProjects/MAS_search_rescue/MAS_search_rescue/files/2022-05-11/system_infoCR1.txt
# ===== System =====
# ProcessWTS() = WTS();
# ProcessTA() = TA();
# system ProcessWTS, ProcessTA;
# ===== Declarations =====
# int w;
# chan p1,np1,p2,np2;
# bool veri1,veri2;
# ===== Templates declarations =====
# null
# int cl1,cl2;
#
# ===== Templates =====
# WTS TA
#
# ===== System Size =====
# State in WTS: 198
# Edge in WTS:  862
# State in TA:  3
# Edge in TA:   6
# ===== Initial State =====
# Initial state in WTS: 102
# Initial state in TA: 0
# ===== Symbolic Verification: E<>(veri1&&veri2) =====
# create FooVeri
# create thread
# starting thread
# getvalue
# Result from thread: OK
# (w102, l0, w=0, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w92, l0, w=1, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w82, l0, w=2, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w72, l0, w=3, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w62, l0, w=4, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w53, l0, w=5, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w44, l0, w=6, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w34, l0, w=7, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=8, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w23, l0, w=9, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w12, l0, w=10, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w3, l0, w=11, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w2, l0, w=12, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w1, l0, w=13, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=14, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=15, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=16, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=17, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=18, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=19, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=20, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=21, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w0, l0, w=22, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w9, l0, w=23, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w20, l0, w=24, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w30, l0, w=25, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w31, l0, w=26, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w41, l0, w=27, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w50, l0, w=28, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w51, l0, w=29, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w61, l0, w=30, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w70, l0, w=31, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w71, l0, w=32, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w81, l0, w=33, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w91, l0, w=34, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w101, l0, w=35, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w112, l0, w=36, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w122, l0, w=37, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w123, l0, w=38, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w124, l0, w=39, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w125, l0, w=40, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w126, l0, w=41, veri1=0, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l1, w=42, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l1, w=43, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l1, w=44, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w127, l1, w=45, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w126, l0, w=46, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w116, l0, w=47, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w105, l0, w=48, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w95, l0, w=49, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w94, l0, w=50, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w84, l0, w=51, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w74, l0, w=52, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w64, l0, w=53, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w55, l0, w=54, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w45, l0, w=55, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w36, l0, w=56, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w35, l0, w=57, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w34, l0, w=58, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w33, l0, w=59, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w23, l0, w=60, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w22, l0, w=61, veri1=1, veri2=0, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# (w21, l2, w=62, veri1=1, veri2=1, ProcessTA.cl1=0, ProcessTA.cl2=0)
#
# The cooperation can be achieved!
# The robot  1  is updating the path since time  8
# i:  1  ii:  1 j:  8 len(path_sweep) 2 len(path_sweep[ii]) 23
# The heavy duty agent  1  is detected at step:  8 . Pos_heavy:  [10, 4] . Pos_light:  [18, 7] . Distance is:  11
# Round  1  Region 1
# The closest start location is  [12  2]
# Step  8 Robot 1 Pos [10, 4] R0 pos:  [18  7]
# Step  8 Robot 1 Pos [10, 4] R0 pos:  [8 2]
# Step  8 Robot 1 Pos [10, 4] R0 pos:  [9 2]
# Step  9 Robot 1 Pos [10, 4] R0 pos:  [10  2]
# Step  9 Robot 1 Pos [10, 4] R0 pos:  [11  2]
# Step  9 Robot 1 Pos [10, 4] R0 pos:  [12  2]
# Step  9 Robot 1 Pos [10, 4] R0 pos:  [12  3]
# Step  9 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  9 Robot 1 Task left:  ['w127', 'w21']
# Step :  9 Light:  [12, 4] Heavy 1 :  [9, 4] Distance is:  3
# Step  9 Robot 1 Pos [9, 4] R0 pos:  [12  4]
# Step  9 Robot 1 Pos [9, 4] R0 pos:  [12  5]
# Step  9 Robot 1 Pos [9, 4] R0 pos:  [12  6]
# Step  10 Robot 1 Pos [9, 4] R0 pos:  [12  7]
# Step  10 Robot 1 Pos [9, 4] R0 pos:  [13  7]
# Step  10 Robot 1 Pos [9, 4] R0 pos:  [14  7]
# Step  10 Robot 1 Pos [9, 4] R0 pos:  [15  7]
# Step  10 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  10 Robot 1 Task left:  ['w127', 'w21']
# Step :  10 Light:  [15, 6] Heavy 1 :  [8, 4] Distance is:  9
# Step  10 Robot 1 Pos [8, 4] R0 pos:  [15  6]
# Step  10 Robot 1 Pos [8, 4] R0 pos:  [15  5]
# Step  10 Robot 1 Pos [8, 4] R0 pos:  [15  4]
# Step  11 Robot 1 Pos [8, 4] R0 pos:  [15  3]
# Step  11 Robot 1 Pos [8, 4] R0 pos:  [15  2]
# Step  11 Robot 1 Pos [8, 4] R0 pos:  [16  2]
# Step  11 Robot 1 Pos [8, 4] R0 pos:  [17  2]
# Step  11 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  11 Robot 1 Task left:  ['w127', 'w21']
# Step :  11 Light:  [18, 2] Heavy 1 :  [7, 4] Distance is:  13
# Step  11 Robot 1 Pos [7, 4] R0 pos:  [18  2]
# Step  11 Robot 1 Pos [7, 4] R0 pos:  [18  3]
# Step  11 Robot 1 Pos [7, 4] R0 pos:  [18  4]
# Step  12 Robot 1 Pos [7, 4] R0 pos:  [18  5]
# Step  12 Robot 1 Pos [7, 4] R0 pos:  [18  6]
# Stop sweep at Region 1  at position  [18  7]
# The closest start location is  [16  7]
# Step  12 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  12 Robot 1 Task left:  ['w127', 'w21']
# Step :  12 Light:  [17, 7] Heavy  1 :  [6, 4] Distance is:  14

# %%
"""
Path of agile light-duty robot
"""
path_detect_round[1] = path_detect_round[1][len(path_detect_round[0]): len(path_detect_round[1])]
for n in range(len(path_detect_round)):
    mm = copy.deepcopy(map_original)
    draw_path(mm, path_detect_round[n], fig_folder, "Trajectory of R0 Round " + str(n + 1))

# %%
"""
Get the data ready for plot and video
"""

independent_path_2d, record_working_region, record_task_left = \
    complete_path(world, v_light, independent_path_2d, states_work_region, record_working_region, record_task_left)

record_path_all = world.agents_light.path
for i in range(num_agent_heavy):
    record_path_all = np.concatenate((record_path_all, world.agents_heavy[i].path), axis=1)
    draw_path(map_obs_work, independent_path_2d[i], fig_folder, "Trajectory of heavy-duty robot R" + str(i + 1))

st = len(record_working_region[0])
for i in range(st, len(record_path_all)):
    for j in range(num_agent_heavy):
        record_working_region[j].append(record_working_region[j][-1])
        record_task_left[j].append(record_task_left[j][-1])

# animate_solution(map_obs_work, record_path_all, record_working_region, record_task_left, r_0, r_i, v_light,
#                  fig_folder, video=True)
# Out:
# Step  13 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  13 Robot 1 Task left:  ['w127', 'w21']
# Step  13 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  13 Robot 1 Task left:  ['w127', 'w21']
# Step  13 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  13 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step :  14
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  14
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  14 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  14 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step :  15
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  15
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  15 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  15 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step :  16
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  16
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  16 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  16 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step :  17
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  17
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  17 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  17 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step :  18
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  18
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  18 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  18 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step :  19
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  19
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  19 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  19 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step :  20
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  20
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  20 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  20 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step :  21
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  21
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  21 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  21 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step :  22
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step :  22
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  22 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  22 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22', 'w100']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step :  23
# task  ['E', '5', '15', 'w100', '1', 'col'] has been done by robot  0
# The tasks left  [['E', '31', '40', 'w20'], ['G', '63', '72', 'w22', 'R1', 'meet']]
# Step  23 Robot 0 Task left:  ['w20', 'w22']
# Step :  23
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  23 Robot 0 Task left:  ['w20', 'w22']
# Step  23 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step :  24
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step :  24
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  24 Robot 0 Task left:  ['w20', 'w22']
# Step  24 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step :  25
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step :  25
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  25 Robot 0 Task left:  ['w20', 'w22']
# Step  25 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step :  26
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step :  26
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  26 Robot 0 Task left:  ['w20', 'w22']
# Step  26 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step :  27
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step :  27
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  27 Robot 0 Task left:  ['w20', 'w22']
# Step  27 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step :  28
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step :  28
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  28 Robot 0 Task left:  ['w20', 'w22']
# Step  28 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step :  29
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step :  29
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  29 Robot 0 Task left:  ['w20', 'w22']
# Step  29 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step :  30
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step :  30
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  30 Robot 0 Task left:  ['w20', 'w22']
# Step  30 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step :  31
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step :  31
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  31 Robot 0 Task left:  ['w20', 'w22']
# Step  31 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step :  32
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step :  32
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  32 Robot 0 Task left:  ['w20', 'w22']
# Step  32 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step :  33
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step :  33
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  33 Robot 0 Task left:  ['w20', 'w22']
# Step  33 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step :  34
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step :  34
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  34 Robot 0 Task left:  ['w20', 'w22']
# Step  34 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step :  35
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step :  35
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  35 Robot 0 Task left:  ['w20', 'w22']
# Step  35 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step :  36
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step :  36
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  36 Robot 0 Task left:  ['w20', 'w22']
# Step  36 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step :  37
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step :  37
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  37 Robot 0 Task left:  ['w20', 'w22']
# Step  37 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step :  38
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step :  38
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  38 Robot 0 Task left:  ['w20', 'w22']
# Step  38 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step :  39
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step :  39
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  39 Robot 0 Task left:  ['w20', 'w22']
# Step  39 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step :  40
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step :  40
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  40 Robot 0 Task left:  ['w20', 'w22']
# Step  40 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step :  41
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step :  41
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  41 Robot 0 Task left:  ['w20', 'w22']
# Step  41 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step :  42
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step :  42
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  42 Robot 0 Task left:  ['w20', 'w22']
# Step  42 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step :  43
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step :  43
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  43 Robot 0 Task left:  ['w20', 'w22']
# Step  43 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step :  44
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step :  44
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  44 Robot 0 Task left:  ['w20', 'w22']
# Step  44 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step :  45
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step :  45
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  45 Robot 0 Task left:  ['w20', 'w22']
# Step  45 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step :  46
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step :  46
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  46 Robot 0 Task left:  ['w20', 'w22']
# Step  46 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step :  47
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step :  47
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  47 Robot 0 Task left:  ['w20', 'w22']
# Step  47 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w20', 'w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w20', 'w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w20', 'w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step :  48
# task  ['E', '31', '40', 'w20'] has been done by robot  0
# The tasks left  [['G', '63', '72', 'w22', 'R1', 'meet']]
# Step  48 Robot 0 Task left:  ['w22']
# Step :  48
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  48 Robot 0 Task left:  ['w22']
# Step  48 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step :  49
# Step  49 Robot 0 Task left:  ['w22']
# Step :  49
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  49 Robot 0 Task left:  ['w22']
# Step  49 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step :  50
# Step  50 Robot 0 Task left:  ['w22']
# Step :  50
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  50 Robot 0 Task left:  ['w22']
# Step  50 Robot 1 Task left:  ['w127', 'w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w127', 'w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w127', 'w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w127', 'w21']
# Step :  51
# Step  51 Robot 0 Task left:  ['w22']
# Step :  51
# task  ['E', '40', '42', 'w127'] has been done by robot  1
# The tasks left  [['E', '62', '71', 'w21', '0', 'meet']]
# Step  51 Robot 1 Task left:  ['w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w21']
# Step  51 Robot 0 Task left:  ['w22']
# Step  51 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step :  52
# Step  52 Robot 0 Task left:  ['w22']
# Step :  52
# Step  52 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step  52 Robot 0 Task left:  ['w22']
# Step  52 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step :  53
# Step  53 Robot 0 Task left:  ['w22']
# Step :  53
# Step  53 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step  53 Robot 0 Task left:  ['w22']
# Step  53 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step :  54
# Step  54 Robot 0 Task left:  ['w22']
# Step :  54
# Step  54 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step  54 Robot 0 Task left:  ['w22']
# Step  54 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step :  55
# Step  55 Robot 0 Task left:  ['w22']
# Step :  55
# Step  55 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step  55 Robot 0 Task left:  ['w22']
# Step  55 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step :  56
# Step  56 Robot 0 Task left:  ['w22']
# Step :  56
# Step  56 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step  56 Robot 0 Task left:  ['w22']
# Step  56 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step :  57
# Step  57 Robot 0 Task left:  ['w22']
# Step :  57
# Step  57 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step  57 Robot 0 Task left:  ['w22']
# Step  57 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step :  58
# Step  58 Robot 0 Task left:  ['w22']
# Step :  58
# Step  58 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step  58 Robot 0 Task left:  ['w22']
# Step  58 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step :  59
# Step  59 Robot 0 Task left:  ['w22']
# Step :  59
# Step  59 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step  59 Robot 0 Task left:  ['w22']
# Step  59 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step :  60
# Step  60 Robot 0 Task left:  ['w22']
# Step :  60
# Step  60 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step  60 Robot 0 Task left:  ['w22']
# Step  60 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step :  61
# Step  61 Robot 0 Task left:  ['w22']
# Step :  61
# Step  61 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step  61 Robot 0 Task left:  ['w22']
# Step  61 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step :  62
# Step  62 Robot 0 Task left:  ['w22']
# Step :  62
# Step  62 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step  62 Robot 0 Task left:  ['w22']
# Step  62 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step :  63
# Step  63 Robot 0 Task left:  ['w22']
# Step :  63
# Step  63 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step  63 Robot 0 Task left:  ['w22']
# Step  63 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step :  64
# Step  64 Robot 0 Task left:  ['w22']
# Step :  64
# Step  64 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step  64 Robot 0 Task left:  ['w22']
# Step  64 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step :  65
# Step  65 Robot 0 Task left:  ['w22']
# Step :  65
# Step  65 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step  65 Robot 0 Task left:  ['w22']
# Step  65 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step :  66
# Step  66 Robot 0 Task left:  ['w22']
# Step :  66
# Step  66 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step  66 Robot 0 Task left:  ['w22']
# Step  66 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step :  67
# Step  67 Robot 0 Task left:  ['w22']
# Step :  67
# Step  67 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step  67 Robot 0 Task left:  ['w22']
# Step  67 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step :  68
# Step  68 Robot 0 Task left:  ['w22']
# Step :  68
# Step  68 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step  68 Robot 0 Task left:  ['w22']
# Step  68 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step :  69
# Step  69 Robot 0 Task left:  ['w22']
# Step :  69
# Step  69 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step  69 Robot 0 Task left:  ['w22']
# Step  69 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step :  70
# Step  70 Robot 0 Task left:  ['w22']
# Step :  70
# Step  70 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step  70 Robot 0 Task left:  ['w22']
# Step  70 Robot 1 Task left:  ['w21']
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  ['w21']
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  ['w21']
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  ['w21']
# Step :  71
# Step  71 Robot 0 Task left:  ['w22']
# Step :  71
# task  ['E', '62', '71', 'w21', '0', 'meet'] has been done by robot  1
# The tasks left  []
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  []
# Step  71 Robot 0 Task left:  ['w22']
# Step  71 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step :  72
# Step  72 Robot 0 Task left:  ['w22']
# Step :  72
# Step  72 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step  72 Robot 0 Task left:  ['w22']
# Step  72 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step :  73
# Step  73 Robot 0 Task left:  ['w22']
# Step :  73
# Step  73 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step  73 Robot 0 Task left:  ['w22']
# Step  73 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step :  74
# Step  74 Robot 0 Task left:  ['w22']
# Step :  74
# Step  74 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step  74 Robot 0 Task left:  ['w22']
# Step  74 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step :  75
# Step  75 Robot 0 Task left:  ['w22']
# Step :  75
# Step  75 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step  75 Robot 0 Task left:  ['w22']
# Step  75 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step :  76
# Step  76 Robot 0 Task left:  ['w22']
# Step :  76
# Step  76 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step  76 Robot 0 Task left:  ['w22']
# Step  76 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step :  77
# Step  77 Robot 0 Task left:  ['w22']
# Step :  77
# Step  77 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step  77 Robot 0 Task left:  ['w22']
# Step  77 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step :  78
# Step  78 Robot 0 Task left:  ['w22']
# Step :  78
# Step  78 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step  78 Robot 0 Task left:  ['w22']
# Step  78 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step :  79
# Step  79 Robot 0 Task left:  ['w22']
# Step :  79
# Step  79 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step  79 Robot 0 Task left:  ['w22']
# Step  79 Robot 1 Task left:  []
# Step  80 Robot 0 Task left:  ['w22']
# Step  80 Robot 1 Task left:  []
# Step  80 Robot 0 Task left:  ['w22']
# Step  80 Robot 1 Task left:  []
# Step  80 Robot 0 Task left:  ['w22']
# Step  80 Robot 1 Task left:  []
# Step :  80
# task  ['G', '63', '72', 'w22', 'R1', 'meet'] has been done by robot  0
# The tasks left  []
# Step  80 Robot 0 Task left:  []
# Step :  80
# Step  80 Robot 1 Task left:  []
